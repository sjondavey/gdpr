# %%
import logging

from abc import ABC, abstractmethod

from regulations_rag.corpus_index import DataFrameCorpusIndex
from regulations_rag.rerank import RerankAlgos, rerank

# Create a logger for this module
logger = logging.getLogger(__name__)
DEV_LEVEL = 15
logging.addLevelName(DEV_LEVEL, 'DEV')       


import os
from regulations_rag.embeddings import get_closest_nodes, num_tokens_from_string
from regulations_rag.file_tools import load_parquet_data

from gdpr_rag.gdpr_corpus import GDPRCorpus
import pandas as pd

required_columns_workflow = ["workflow", "text", "embedding"]
key = os.getenv('encryption_key_gdpr')

# %%
corpus = GDPRCorpus("./gdpr_rag/documents/")
index_folder = "./inputs/index/"
index_df = pd.DataFrame()
for filename in os.listdir(index_folder):
    if filename.endswith(".parquet"):  
        filepath = os.path.join(index_folder, filename)
        df = load_parquet_data(filepath, key)
        index_df = pd.concat([index_df, df], ignore_index = True)

user_type = "a Controller"
corpus_description = "the General Data Protection Regulation (GDPR)"

definitions = index_df[index_df['source'] == 'definitions'].copy(deep=True)
index = index_df[index_df['source'] != 'definitions'].copy(deep=True)
workflow = pd.DataFrame([], columns = required_columns_workflow)

# %%
doc = corpus.get_document("GDPR")

definitions['definition'] = definitions['section_reference'].apply(lambda x: doc.get_text(section_reference = x, add_markdown_decorators = False, add_headings = False))
# Function to remove the leading number, full stop, and space
definitions['definition'] = definitions['definition'].str.replace(r'^\s*\d+\.\s*', '', regex=True)

#definitions['definition'].str.replace(r'^\d{1,2}\. ', '', regex=True)
definitions
# Out:
#      section_reference                                      text       source  \
# 1005              4(1)                    What is personal data?  definitions
# 1006              4(2)                       What is processing?  definitions
# 1007              4(3)        What is restriction of processing?  definitions
# 1008              4(4)                        What is profiling?  definitions
# 1009              4(5)                 What is pseudonymisation?  definitions
# 1010              4(6)                  What is a filing system?  definitions
# 1011              4(7)                     What is a controller?  definitions
# 1012              4(8)                      What is a processor?  definitions
# 1013              4(9)                      What is a recipient?  definitions
# 1014             4(10)                    What is a third party?  definitions
# 1015             4(11)                          What is consent?  definitions
# 1016             4(12)           What is a personal data breach?  definitions
# 1017             4(13)                     What is genetic data?  definitions
# 1018             4(14)                   What is biometric data?  definitions
# 1019             4(15)           What is data concerning health?  definitions
# 1020             4(16)             What is a main establishment?  definitions
# 1021             4(17)                 What is a representative?  definitions
# 1022             4(18)                    What is an enterprise?  definitions
# 1023             4(19)          What is a group of undertakings?  definitions
# 1024             4(20)         What are binding corporate rules?  definitions
# 1025             4(21)            What is supervisory authority?  definitions
# 1026             4(22)  What is supervisory authority concerned?  definitions
# 1027             4(23)          What is cross-border processing?  definitions
# 1028             4(24)  What is relevant and reasoned objection?  definitions
# 1029             4(25)      What is information society service?  definitions
# 1030             4(26)       What is international organisation?  definitions
#
#                                               embedding document  \
# 1005  [-0.03953353688120842, 0.04642977565526962, -0...     GDPR
# 1006  [-0.03899864852428436, 0.04007093608379364, -0...     GDPR
# 1007  [-0.052392441779375076, -0.03844074532389641, ...     GDPR
# 1008  [-0.03238030523061752, -0.04825564846396446, -...     GDPR
# 1009  [-0.04147166386246681, -0.031792495399713516, ...     GDPR
# 1010  [-0.035739850252866745, 0.048365894705057144, ...     GDPR
# 1011  [-0.022157778963446617, 0.011915236711502075, ...     GDPR
# 1012  [-0.020444175228476524, 0.019522828981280327, ...     GDPR
# 1013  [-0.021122010424733162, 0.010544460266828537, ...     GDPR
# 1014  [-0.011242421343922615, -0.06827251613140106, ...     GDPR
# 1015  [-0.009799059480428696, 0.005497628822922707, ...     GDPR
# 1016  [-0.06777520477771759, 0.006689939647912979, 0...     GDPR
# 1017  [-0.05639044940471649, -0.004552354104816914, ...     GDPR
# 1018  [0.0013306067558005452, 0.0017988799372687936,...     GDPR
# 1019  [-0.019604289904236794, 0.056598830968141556, ...     GDPR
# 1020  [0.016890862956643105, 0.07781259715557098, -0...     GDPR
# 1021  [0.001012207823805511, -0.019404491409659386, ...     GDPR
# 1022  [-0.05415717139840126, 0.04461687058210373, -0...     GDPR
# 1023  [0.029480112716555595, 0.0445149727165699, -0....     GDPR
# 1024  [-0.013419119641184807, -0.07803943753242493, ...     GDPR
# 1025  [-0.02389775589108467, -0.02977169118821621, -...     GDPR
# 1026  [-0.016888560727238655, 0.003025628859177232, ...     GDPR
# 1027  [-0.03551863506436348, -3.7787705764458224e-07...     GDPR
# 1028  [-0.01737261191010475, -0.005801921710371971, ...     GDPR
# 1029  [-0.04533061757683754, 0.06807615607976913, -0...     GDPR
# 1030  [-0.05958525463938713, -0.022743836045265198, ...     GDPR
#
#                                              definition
# 1005  'personal data' means any information relating...
# 1006  'processing' means any operation or set of ope...
# 1007  'restriction of processing' means the marking ...
# 1008  'profiling' means any form of automated proces...
# 1009  'pseudonymisation' means the processing of per...
# 1010  'filing system' means any structured set of pe...
# 1011  'controller' means the natural or legal person...
# 1012  'processor' means a natural or legal person, p...
# 1013  'recipient' means a natural or legal person, p...
# 1014  'third party' means a natural or legal person,...
# 1015  'consent' of the data subject means any freely...
# 1016  'personal data breach' means a breach of secur...
# 1017  'genetic data' means personal data relating to...
# 1018  'biometric data' means personal data resulting...
# 1019  'data concerning health' means personal data r...
# 1020  'main establishment' means:\n(a) as regards a ...
# 1021  'representative' means a natural or legal pers...
# 1022  'enterprise' means a natural or legal person e...
# 1023  'group of undertakings' means a controlling un...
# 1024  'binding corporate rules' means personal data ...
# 1025  'supervisory authority' means an independent p...
# 1026  'supervisory authority concerned' means a supe...
# 1027  'cross-border processing' means either:\n(a) p...
# 1028  'relevant and reasoned objection' means an obj...
# 1029  'information society service' means a service ...
# 1030  'international organisation' means an organisa...

# %%
definitions.iloc[0]['definition']
# Out:
# "    1. 'personal data' means any information relating to an identified or identifiable natural person ('data subject'); an identifiable natural person is one who can be identified, directly or indirectly, in particular by reference to an identifier such as a name, an identification number, location data, an online identifier or to one or more factors specific to the physical, physiological, genetic, mental, economic, cultural or social identity of that natural person;\n"

# %%
import pandas as pd

# Sample dataframe
data = {'definition': ['1. This is a definition', '12. Another definition']}
definitions = pd.DataFrame(data)

# Function to remove the leading number, full stop, and space
definitions['definition'] = definitions['definition'].str.replace(r'^\d{1,2}\. ', '', regex=True)

print(definitions)
# Out:
#              definition
# 0  This is a definition
# 1    Another definition

# %%
columns_in_dfns = ["embedding", "document", "section_reference", "text"]
for column in columns_in_dfns:
    if column not in definitions.columns.to_list():
        print(column)

# %%
columns_in_sections = ["embedding", "document", "section_reference", "source", "text"]
for column in columns_in_sections:
    if column not in index.columns.to_list():
        print(column)
