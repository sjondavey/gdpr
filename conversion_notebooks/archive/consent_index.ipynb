# %%
import logging
log_level = 25
logging.basicConfig(level=log_level) # root logger

# %%
class_name = "Concent"
prefix = "consent"
summary_file = f"../tmp/{prefix}_summary.csv"
question_file = f"../tmp/{prefix}_services_question.csv"

path_to_manual_as_csv_file = f"../inputs/documents/{prefix}.parquet"
index_file = f"../inputs/index/{prefix}.parquet"

# %%
import re
import pandas as pd

import sys
sys.path.append('E:/Code/chat/gdpr')

import importlib
import gdpr_rag.documents.consent
importlib.reload(gdpr_rag.documents.consent)

from gdpr_rag.documents.consent import Consent
path_to_manual_as_csv_file = "../inputs/documents/consent.parquet"

doc = Consent(path_to_manual_as_csv_file)

# %%
# from regulations_rag.regulation_table_of_content import StandardTableOfContent
# reference_checker = doc.reference_checker
# df = pd.read_parquet(path_to_manual_as_csv_file, engine='pyarrow')
# toc = StandardTableOfContent(root_node_name = "transparency", reference_checker = reference_checker, regulation_df = df)
toc = doc.get_toc()

# %%
toc.print_tree()
# Out:
# Guidelines 05/2020 on consent under Regulation 2016/679 []
# |-- 0 [PREFACE]
# |-- 1 [INTRODUCTION]
# |-- 2 [CONSENT IN ARTICLE 4(11) OF THE GDPR]
# |-- 3 [ELEMENTS OF VALID CONSENT]
# |   |-- .1 [Free / freely given]
# |   |   |-- .1 [Imbalance of power]
# |   |   |-- .2 [Conditionality]
# |   |   |-- .3 [Granularity]
# |   |   +-- .4 [Detriment]
# |   |-- .2 [Specific]
# |   |-- .3 [Informed]
# |   |   |-- .1 [Minimum content requirements for consent to be 'informed']
# |   |   +-- .2 [How to provide information]
# |   +-- .4 [Unambiguous indication of wishes]
# |-- 4 [OBTAINING EXPLICIT CONSENT]
# |-- 5 [ADDITIONAL CONDITIONS FOR OBTAINING VALID CONSENT]
# |   |-- .1 [Demonstrate consent]
# |   +-- .2 [Withdrawal of consent]
# |-- 6 [INTERACTION BETWEEN CONSENT AND OTHER LAWFUL GROUNDS IN ARTICLE 6 GDPR]
# |-- 7 [SPECIFIC AREAS OF CONCERN IN THE GDPR]
# |   |-- .1 [Children (Article 8)]
# |   |   |-- .1 [Information society service]
# |   |   |-- .2 [Offered directly to a child]
# |   |   |-- .3 [Age]
# |   |   +-- .4 [Children's consent and parental responsibility]
# |   |-- .2 [Scientific research]
# |   +-- .3 [Data subject's rights]
# +-- 8 [CONSENT OBTAINED UNDER DIRECTIVE 95/46/EC]

# %%
sys.path.append('E:/Code/chat/gdpr')

from anytree import Node, PreOrderIter
from regulations_rag.embeddings import num_tokens_from_string

all_nodes = list(PreOrderIter(toc.root))
all_node_names = [node.full_node_name for node in all_nodes if node.full_node_name != ""]
split_df = pd.DataFrame(all_node_names, columns = ["section_reference"])
for index, row in split_df.iterrows():
    text = doc.get_text(row['section_reference'])
    split_df.at[index, 'text'] = text
    split_df.at[index, 'token_count'] = num_tokens_from_string(text)
split_df["token_count"] = split_df["token_count"].astype(int)

split_df = split_df.drop([0, 1]) # preface and Introduction
split_df = split_df[split_df["token_count"] > 115] 
split_df.reset_index(drop=True, inplace=True)
split_df
# Out:
#    section_reference                                               text  \
# 0                  2  2 CONSENT IN ARTICLE 4(11) OF THE GDPR \n8. Ar...
# 1                  3  3 ELEMENTS OF VALID CONSENT \n11. Article 4(11...
# 2                3.1  3 ELEMENTS OF VALID CONSENT \n\n3.1 Free / fre...
# 3              3.1.1  3 ELEMENTS OF VALID CONSENT \n3.1 Free / freel...
# 4              3.1.2  3 ELEMENTS OF VALID CONSENT \n3.1 Free / freel...
# 5              3.1.3  3 ELEMENTS OF VALID CONSENT \n3.1 Free / freel...
# 6              3.1.4  3 ELEMENTS OF VALID CONSENT \n3.1 Free / freel...
# 7                3.2  3 ELEMENTS OF VALID CONSENT \n\n3.2 Specific \...
# 8                3.3  3 ELEMENTS OF VALID CONSENT \n\n3.3 Informed \...
# 9              3.3.1  3 ELEMENTS OF VALID CONSENT \n3.3 Informed \n\...
# 10             3.3.2  3 ELEMENTS OF VALID CONSENT \n3.3 Informed \n\...
# 11               3.4  3 ELEMENTS OF VALID CONSENT \n\n3.4 Unambiguou...
# 12                 4  4 OBTAINING EXPLICIT CONSENT \n91. Explicit co...
# 13                 5  5 ADDITIONAL CONDITIONS FOR OBTAINING VALID CO...
# 14               5.1  5 ADDITIONAL CONDITIONS FOR OBTAINING VALID CO...
# 15               5.2  5 ADDITIONAL CONDITIONS FOR OBTAINING VALID CO...
# 16                 6  6 INTERACTION BETWEEN CONSENT AND OTHER LAWFUL...
# 17               7.1  7 SPECIFIC AREAS OF CONCERN IN THE GDPR \n\n7....
# 18             7.1.1  7 SPECIFIC AREAS OF CONCERN IN THE GDPR \n7.1 ...
# 19             7.1.2  7 SPECIFIC AREAS OF CONCERN IN THE GDPR \n7.1 ...
# 20             7.1.3  7 SPECIFIC AREAS OF CONCERN IN THE GDPR \n7.1 ...
# 21             7.1.4  7 SPECIFIC AREAS OF CONCERN IN THE GDPR \n7.1 ...
# 22               7.2  7 SPECIFIC AREAS OF CONCERN IN THE GDPR \n\n7....
# 23               7.3  7 SPECIFIC AREAS OF CONCERN IN THE GDPR \n\n7....
# 24                 8  8 CONSENT OBTAINED UNDER DIRECTIVE 95/46/EC \n...
#
#     token_count
# 0           432
# 1           166
# 2           658
# 3          1496
# 4          2094
# 5           609
# 6           784
# 7           954
# 8           158
# 9           566
# 10         1302
# 11         1719
# 12         1576
# 13          115
# 14          765
# 15         1298
# 16          275
# 17          867
# 18          341
# 19          144
# 20          559
# 21         1262
# 22         1637
# 23          189
# 24          799

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')
#index_df = load_parquet_data("../inputs/index_gdpr.parquet", key)

# %%
from openai import OpenAI
openai_client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),)

import sys
sys.path.append('E:/Code/chat/gdpr')
import importlib
import src.summarise_and_question
importlib.reload(src.summarise_and_question)
from src.summarise_and_question import get_summary_and_questions_for

# %%
if os.path.exists(summary_file):
    df_summary = pd.read_csv(summary_file, sep="|", encoding = "utf-8")
else:
    df_summary = pd.DataFrame([], columns = ["section_reference", "text", "source", "embedding", "document"])
    df_summary["section_reference"] = split_df["section_reference"]
    # df_summary["text"] = split_df["text"]
    df_summary["source"] = "summary"
    df_summary["document"] = class_name

first_empty_index = df_summary[df_summary['text'].isna()].index.min()

if pd.isna(first_empty_index):
    #print("No empty embeddings found.")
    first_empty_index = 0
index = first_empty_index

if os.path.exists(question_file):
    df_questions = pd.read_csv(question_file, sep="|", encoding = "utf-8")
else:
    df_questions = pd.DataFrame([], columns = ["section_reference", "text", "source", "embedding", "document"])
    df_questions["section_reference"] = split_df["section_reference"]
    # df_questions["text"] = split_df["text"]
    df_questions["source"] = "question"
    df_questions["document"] = class_name

first_empty_index = df_questions[df_questions['text'].isna()].index.min()

if pd.isna(first_empty_index):
    #print("No empty embeddings found.")
    first_empty_index = 0

if index != first_empty_index:
    print("The index in the summary and questions files do not match. This needs to be fixed")
else:
    [print(f"Picking up at index {index}")]
# Out:
# Picking up at index 0

# %%
model = "gpt-4o"

reference = df_summary.iloc[index]["section_reference"]

reg_text = doc.get_text(reference)
print("##############")
print(reg_text)
print("##############")

model_summary, model_questions = get_summary_and_questions_for(openai_client = openai_client, text = reg_text, model = model)

#format output
print(f'# index: {index}, section_reference: {df_summary.iloc[index]["section_reference"]}')
print()
model_summary = model_summary.replace('"', '\\"')
print(f'df_summary.loc[index, "text"] = "{model_summary}"')
print()
model_questions = model_questions.replace('"', '\\"')
print(f'df_questions.loc[index, "text"] = "{model_questions}"')
# Out:
# ##############
# 8 CONSENT OBTAINED UNDER DIRECTIVE 95/46/EC
# 166. Controllers that currently process data on the basis of consent in compliance with national data protection law are not automatically required to completely refresh all existing consent relations with data subjects in preparation for the GDPR. Consent, which has been obtained, to date continues to be valid in so far as it is in line with the conditions laid down in the GDPR.
# 167. It is important for controllers to review current work processes and records in detail, before 25 May 2018, to be sure existing consents meet the GDPR standard (see Recital 171 of the GDPR[^78]). In practice, the GDPR raises the bar with regard to implementing consent mechanisms and introduces several new requirements that require controllers to alter consent mechanisms, rather than rewriting privacy policies alone.[^79]
# 168. For example, as the GDPR requires that a controller must be able to demonstrate that valid consent was obtained, all presumed consents of which no references are kept will automatically be below the consent standard of the GDPR and will need to be renewed. Likewise as the GDPR requires a "statement or a clear affirmative action", all presumed consents that were based on a more implied form of action by the data subject (e.g. a pre-ticked opt-in box) will also not be apt to the GDPR standard of consent.
# 169. Furthermore, to be able to demonstrate that consent was obtained or to allow for more granular indications of the data subject's wishes, operations and IT systems may need revision. Also, mechanisms for data subjects to withdraw their consent easily must be available and information about how to withdraw consent must be provided. If existing procedures for obtaining and managing consent do not meet the GDPR's standards, controllers will need to obtain fresh GDPR compliant consent.
# 170. On the other hand, as not all elements named in Articles 13 and 14 must always be present as a condition for informed consent, the extended information obligations under the GDPR do not necessarily oppose the continuity of consent, which has been granted before the GDPR enters into force (see page 15 above). Under Directive 95/46/EC, there was no requirement to inform data subjects of the basis upon which the processing was being conducted.
# 171. If a controller finds that the consent previously obtained under the old legislation will not meet the standard of GDPR consent, then controllers must undertake action to comply with these standards, for example by refreshing consent in a GDPR-compliant way. Under the GDPR, it is not possible to swap between one lawful basis and another. If a controller is unable to renew consent in a compliant way and is also unable -as a one off situation- to make the transition to GDPR compliance by basing data processing on a different lawful basis while ensuring that continued processing is fair and accounted for, the processing activities must be stopped. In any event, the controller needs to observe the principles of lawful, fair and transparent processing.
#
# [^78] Recital 171 GDPR states: "Directive 95/46/EC should be repealed by this Regulation. Processing already under way on the date of application of this Regulation should be brought into conformity with this Regulation within the period of two years after which this Regulation enters into force. Where processing is based on consent pursuant to Directive 95/46/EC, it is not necessary for the data subject to give his or her consent again if the manner in which the consent has been given is in line with the conditions of this Regulation, so as to allow the controller to continue such processing after the date of application of this Regulation. Commission decisions adopted and authorisations by supervisory authorities based on Directive 95/46/EC remain in force until amended, replaced or repealed."
# [^79] As indicated in the introduction, the GDPR provides further clarification and specification of the requirements for obtaining and demonstrating valid consent. Many of the new requirements build upon Opinion 15/2011 on consent.
# ##############
# # index: 23, section_reference: 8
#
# df_summary.loc[index, "text"] = "Current data processing based on previously obtained consent under national law remains valid if it aligns with GDPR conditions. Review consents before 25 May 2018 to ensure they meet GDPR standards, which include stricter requirements for consent mechanisms beyond merely updating privacy policies.
#
# Demonstrating valid consent is necessary; consents without records or those obtained through implied actions, like pre-ticked boxes, need renewing. Update operations and IT systems to facilitate granular indications of consent and easy withdrawal mechanisms. Provide information on how individuals can withdraw consent. If existing procedures don't comply, obtain new consent.
#
# Some requirements under Articles 13 and 14 of GDPR do not need to be present for informed consent, meaning the extended information obligations do not necessarily invalidate previously granted consent.
#
# If previous consent does not meet GDPR standards, take action to comply, potentially by refreshing consent. GDPR prohibits switching from one lawful basis to another. If compliant consent cannot be renewed, or another lawful basis cannot be justified, stop the processing activities. Ensure all processing follows principles of lawful, fair, and transparent processing."
#
# df_questions.loc[index, "text"] = "|Is it necessary to obtain fresh consent from individuals if we already have their consent?|How should existing consents be reviewed to ensure they meet the new standards?|What happens if the current consent mechanisms do not align with GDPR requirements?|What specific changes to consent mechanisms might be needed under GDPR?|How should we demonstrate that valid consent has been obtained?|What are the new requirements for consent introduced by GDPR?|How can individuals withdraw their consent, and what information should we provide about this process?|Under what circumstances might we need to obtain new GDPR-compliant consent from individuals?|Can we swap between different lawful bases for processing data under GDPR?|What actions should be taken if existing consents do not meet GDPR standards?"

# %%
model_summary
# Out:
# "Current data processing based on previously obtained consent under national law remains valid if it aligns with GDPR conditions. Review consents before 25 May 2018 to ensure they meet GDPR standards, which include stricter requirements for consent mechanisms beyond merely updating privacy policies.\n\nDemonstrating valid consent is necessary; consents without records or those obtained through implied actions, like pre-ticked boxes, need renewing. Update operations and IT systems to facilitate granular indications of consent and easy withdrawal mechanisms. Provide information on how individuals can withdraw consent. If existing procedures don't comply, obtain new consent.\n\nSome requirements under Articles 13 and 14 of GDPR do not need to be present for informed consent, meaning the extended information obligations do not necessarily invalidate previously granted consent.\n\nIf previous consent does not meet GDPR standards, take action to comply, potentially by refreshing consent. GDPR prohibits switching from one lawful basis to another. If compliant consent cannot be renewed, or another lawful basis cannot be justified, stop the processing activities. Ensure all processing follows principles of lawful, fair, and transparent processing."

# %%
# index: 23, section_reference: 8

df_summary.loc[index, "text"] = "Current data processing based on previously obtained consent under national law remains valid if it aligns with GDPR conditions. Review consents before 25 May 2018 to ensure they meet GDPR standards, which include stricter requirements for consent mechanisms beyond merely updating privacy policies.\n\nDemonstrating valid consent is necessary; consents without records or those obtained through implied actions, like pre-ticked boxes, need renewing. Update operations and IT systems to facilitate granular indications of consent and easy withdrawal mechanisms. Provide information on how individuals can withdraw consent. If existing procedures don't comply, obtain new consent.\n\nSome requirements under Articles 13 and 14 of GDPR do not need to be present for informed consent, meaning the extended information obligations do not necessarily invalidate previously granted consent.\n\nIf previous consent does not meet GDPR standards, take action to comply, potentially by refreshing consent. GDPR prohibits switching from one lawful basis to another. If compliant consent cannot be renewed, or another lawful basis cannot be justified, stop the processing activities. Ensure all processing follows principles of lawful, fair, and transparent processing."

df_questions.loc[index, "text"] = "How should existing consents be reviewed to ensure they meet the new standards?|What happens if the current consent mechanisms do not align with GDPR requirements?"


index = index + 1
print(f"You have completed {(index / len(df_summary) * 100):.2f}% of the work")
if index < len(df_summary):
    print(f"The next section is:\n{doc.get_text(df_summary.iloc[index]['section_reference'])}")
else:
    print("All done")
# Out:
# You have completed 100.00% of the work
# All done

# %%
df_questions
# Out:
#    section_reference    source  embedding document  \
# 0                  2  question        NaN  Concent
# 1                  2  question        NaN  Concent
# 2                  2  question        NaN  Concent
# 3                  3  question        NaN  Concent
# 4                3.1  question        NaN  Concent
# ..               ...       ...        ...      ...
# 68               7.3  question        NaN  Concent
# 69               7.3  question        NaN  Concent
# 70               7.3  question        NaN  Concent
# 71                 8  question        NaN  Concent
# 72                 8  question        NaN  Concent
#
#                                                  text
# 0                         What is meant by 'consent'?
# 1           What is required for consent to be valid?
# 2   What provisions explain the requirements for g...
# 3   What elements are necessary for consent to be ...
# 4              What constitutes freely given consent?
# ..                                                ...
# 68  What rights does an individual have when proce...
# 69  What rights to data does an individual have if...
# 70  How does withdrawing consent affect an individ...
# 71  How should existing consents be reviewed to en...
# 72  What happens if the current consent mechanisms...
#
# [73 rows x 5 columns]

# %%
df_summary.to_csv(summary_file, sep = "|", encoding = "utf-8", index = False, na_rep="")

df_questions.to_csv(question_file, sep = "|", encoding = "utf-8", index = False, na_rep="")

# %%
import pandas as pd
df_summary = pd.read_csv(summary_file, sep = "|", encoding = "utf-8")

df_questions = pd.read_csv(question_file, sep = "|", encoding = "utf-8")

# %%
df_questions = df_questions.drop("text", axis=1).join(df_questions["text"].str.split("|", expand=True).stack().reset_index(level=1, drop=True).rename("text"))
df_questions = df_questions[df_questions["text"] != ""]
df_questions.reset_index(drop=True, inplace=True)

# %%
df_index = pd.concat([df_summary, df_questions], ignore_index = True)
df_index
# Out:
#    section_reference                                               text  \
# 0                  2  Consent must be freely given, specific, inform...
# 1                  3  Consent must meet four criteria: freely given,...
# 2                3.1  To be valid, consent must be given freely. Thi...
# 3              3.1.1  Freely given consent requires a genuine choice...
# 4              3.1.2  Consent must be freely given. Bundling consent...
# ..               ...                                                ...
# 92               7.3  What rights does an individual have when proce...
# 93               7.3  What rights to data does an individual have if...
# 94               7.3  How does withdrawing consent affect an individ...
# 95                 8  How should existing consents be reviewed to en...
# 96                 8  What happens if the current consent mechanisms...
#
#       source  embedding document
# 0    summary        NaN  Concent
# 1    summary        NaN  Concent
# 2    summary        NaN  Concent
# 3    summary        NaN  Concent
# 4    summary        NaN  Concent
# ..       ...        ...      ...
# 92  question        NaN  Concent
# 93  question        NaN  Concent
# 94  question        NaN  Concent
# 95  question        NaN  Concent
# 96  question        NaN  Concent
#
# [97 rows x 5 columns]

# %%
from regulations_rag.embeddings import get_ada_embedding
model = "text-embedding-3-large"
dimensions = 1024

#df_index = df_questions
df_index['embedding'] = pd.NA  # Initialize the column to hold NA values
df_index['embedding'] = df_index['embedding'].astype(object)  # Ensure the column type is object
increment = 10
for i in range(0, len(df_index), increment):
    chunk = df_index.iloc[i:i+increment].copy()
    chunk["embedding"] = chunk["text"].apply(lambda x: get_ada_embedding(openai_client, x, model, dimensions))
    df_index.loc[chunk.index, "embedding"] = chunk["embedding"]
    print(f"Completed {i+increment} lines")
# Out:
# Completed 10 lines
# Completed 20 lines
# Completed 30 lines
# Completed 40 lines
# Completed 50 lines
# Completed 60 lines
# Completed 70 lines
# Completed 80 lines
# Completed 90 lines
# Completed 100 lines

# %%
concent_index['document'] = 'Consent'

# %%
concent_index
save_parquet_data(concent_index, index_file, key)

# %%
df_index.to_parquet(index_file, engine = "pyarrow")
save_parquet_data(df_index, index_file, key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_index.to_parquet(index_file, engine = "pyarrow")
#       2 save_parquet_data(df_index, index_file, key)
#
# NameError: name 'df_index' is not defined

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')


gdpr_index = load_parquet_data("../inputs/index/gdpr.parquet", key)
concent_index = load_parquet_data("../inputs/index/consent.parquet", key)

for index, row in gdpr_index[gdpr_index['section_reference'].str.startswith('4')].iterrows():
    print(f"-- {row['text']}")


# for index, row in gdpr_index.iterrows():
#     if 'concent' in row['text'].lower():
#         print(f"* {row['text']}")
# Out:
# -- What is personal data?
# -- What is processing?
# -- What is restriction of processing?
# -- What is profiling?
# -- What is pseudonymisation?
# -- What is a filing system?
# -- What is a controller?
# -- What is a processor?
# -- What is a recipient?
# -- What is a third party?
# -- What is consent?
# -- What is a personal data breach?
# -- What is genetic data?
# -- What is biometric data?
# -- What is data concerning health?
# -- What is a main establishment?
# -- What is a representative?
# -- What is an enterprise?
# -- What is a group of undertakings?
# -- What are binding corporate rules?
# -- What is supervisory authority?
# -- What is supervisory authority concerned?
# -- What is cross-border processing?
# -- What is relevant and reasoned objection?
# -- What is information society service?
# -- What is international organisation?
# -- Who is encouraged to create codes of conduct for GDPR compliance?
# -- What purposes do codes of conduct serve?
# -- Can codes of conduct address the protection of children's data?
# -- How can codes of conduct assist with personal data breaches?
# -- Can organisations outside the EU adhere to codes of conduct?
# -- What requirements must a code of conduct meet for approval?
# -- Who approves codes of conduct for local purposes?
# -- How are codes of conduct evaluated for processing activities across multiple Member States?
# -- What role does the Commission play in the validity of codes of conduct?
# -- How is the public informed about approved codes of conduct?
# -- Where can one find a register of approved codes of conduct?
# -- Who can monitor compliance with a code of conduct?
# -- What qualifications must a body meet to monitor compliance with a code of conduct?
# -- How does a body become accredited to monitor a code of conduct?
# -- What responsibilities does an accredited body have when a code of conduct is breached?
# -- What actions can an accredited monitoring body take if a code of conduct is infringed?
# -- Under what circumstances can an accreditation be revoked?
# -- What is the purpose of data protection certifications?
# -- Can organisations outside the EU show they have appropriate data safeguards?
# -- Is getting certified mandatory for companies?
# -- Does having a certification mean a company is fully compliant with GDPR?
# -- Who can issue certifications?
# -- What must you do to get certified?
# -- How long is a certification valid?
# -- What happens if the certification requirements are no longer met?
# -- Where can one find information on different certifications available?
# -- Who can issue and renew data protection certification?
# -- What are the requirements for a body to be accredited as a certification body?
# -- How do certification bodies demonstrate their independence and expertise?
# -- What procedures must certification bodies establish?
# -- How is the accreditation of certification bodies handled?
# -- What responsibilities do certification bodies have in assessing and withdrawing certifications?
# -- How long is the accreditation of a certification body valid for?
# -- How are the reasons for granting or withdrawing certifications communicated to supervisory authorities?
# -- How is information about certification requirements and criteria made available to the public?
# -- What happens if a certification body does not meet accreditation conditions or infringes GDPR?
# -- How can the Commission influence data protection certification mechanisms?
# -- What conditions must be met for international transfers of personal data?
# -- What does the GDPR require from you before transferring personal data to a third country?
# -- How does GDPR protect individuals' data during international transfers?
# -- Can personal data be transferred internationally for processing?
# -- What ensures that international data transfers don't compromise data protection?
# -- How can personal data be transferred to a third country or international organisation?
# -- What criteria does the Commission consider when assessing if a third country offers adequate protection?
# -- What happens after the Commission decides a third country has adequate protection?
# -- How often does the Commission review third country adequacy decisions?
# -- What actions does the Commission take if a third country no longer ensures an adequate level of protection?
# -- Can the Commission take immediate action against a third country not ensuring adequate protection?
# -- How does the Commission handle negotiations with a third country no longer providing adequate protection?
# -- Where can the list of countries with an adequate level of data protection be found?
# -- When can you transfer personal data to another country or international organisation?
# -- What safeguards can you put in place for transferring personal data without needing specific authorisation?
# -- Can the transfer of personal data be based on binding corporate rules?
# -- How can standard data protection clauses help in transferring personal data?
# -- What role do codes of conduct and certification mechanisms play in data transfer?
# -- Under what conditions can contractual clauses facilitate data transfer to third countries?
# -- What are the requirements for administrative arrangements between public bodies for data transfer?
# -- How does the consistency mechanism apply to data transfer authorisations?
# -- What are binding corporate rules?
# -- How do binding corporate rules become approved?
# -- What requirements must binding corporate rules meet?
# -- What details must be spelled out in binding corporate rules?
# -- What rights do individuals have under binding corporate rules?
# -- Who is liable if binding corporate rules are breached?
# -- How are individuals informed about their rights under binding corporate rules?
# -- What is the role of a data protection officer within a group adopting binding corporate rules?
# -- What mechanisms ensure compliance with binding corporate rules?
# -- How is the effectiveness of binding corporate rules verified?
# -- What is the process for reporting changes in binding corporate rules?
# -- How do groups cooperate with supervisory authorities under binding corporate rules?
# -- What happens if local laws conflict with the standards of binding corporate rules?
# -- What kind of training is required for employees with access to personal data under binding corporate rules?
# -- When can a non-EU country's court judgement or administrative decision compel you to transfer or disclose personal data?
# -- What conditions must be met for you to recognise a data request from a non-EU country's authority?
# -- Is it possible to transfer or disclose personal data based on a foreign judgement or decision without an international agreement?
# -- What kind of international agreements allow for the transfer or disclosure of personal data to a third country?
# -- What are the conditions for transferring personal data to another country or international organisation?
# -- When is an individual's consent required for data transfer?
# -- How does a contract affect the transfer of personal data?
# -- What constitutes an important reason of public interest for transferring personal data?
# -- When can data be transferred for the establishment, exercise, or defence of legal claims?
# -- Under what circumstances can personal data be transferred to protect someone's vital interests?
# -- What are the rules for transferring data from public registers?
# -- What are the requirements for a non-repetitive transfer based on compelling legitimate interests?
# -- When are public authorities exempt from certain transfer conditions?
# -- How does the law recognise public interest for data transfers?
# -- What documentation is required for assessing data transfers?
# -- You are encouraged to develop or adopt codes of conduct to help apply GDPR effectively, considering your specific processing activities and the needs if you're a micro, small, or medium-sized enterprise. These codes can address various aspects such as fair processing, legitimate interests, data collection, pseudonymisation, informing individuals, their rights, children's data and consent, security measures, breach notifications, data transfers, and dispute resolution.
# If you're outside the EU but handle data transfers from the EU, adhering to an approved code of conduct can help ensure you provide the necessary safeguards, even making binding commitments to apply these safeguards.
# For a code of conduct to be recognized, it must include enforcement mechanisms overseen by an approved monitoring body, without affecting the supervisory authorities' powers.
# If you're drafting a code of conduct or intending to amend or extend one, you must submit it to the relevant supervisory authority for approval, ensuring it complies with the GDPR and provides sufficient safeguards.
# Approved codes that are specific to one Member State will be registered and published by the supervisory authority. If the code covers multiple Member States, it undergoes a review process by the Board and, if found compliant, is forwarded to the Commission for potential Union-wide validity.
# The Commission is responsible for making codes with general validity widely known while the Board compiles and publishes all approved codes.
# -- You may choose to follow a code of conduct to help comply with GDPR. A specific body, which must be accredited by the supervisory authority, will monitor your compliance with this code. This body has to prove its independence, expertise, and have mechanisms for assessing compliance, handling complaints, and ensuring no conflicts of interest. The supervisory authority will establish the criteria for accrediting these bodies and can revoke accreditation if the body fails to meet standards or breaches GDPR. This body can take actions against you, including suspension or exclusion from the code if you infringe on its rules, and must inform the authority about such actions. However, public authorities and bodies are not subject to these monitoring requirements.
# -- You are encouraged to seek data protection certification, seals or marks to demonstrate your compliance with the GDPR. This is particularly suggested for micro, small, and medium-sized enterprises. Certifications can also be used to show you have appropriate safeguards for transferring personal data to countries or international organisations outside the EU. Certification is voluntary and should be transparent. Holding a certification does not exempt you from your compliance obligations under the GDPR. Certifications are issued by authorised bodies based on approved criteria and are valid for up to three years, with the possibility of renewal if compliance is maintained. If you fail to meet the certification requirements, your certification can be withdrawn. You must provide all necessary information and access to your processing activities for the certification process. A register of all certifications will be made publicly available.
# -- Certification bodies with data protection expertise can issue and renew certifications after informing the supervisory authority. These bodies must be accredited either by the supervisory authority or the national accreditation body following specific standards and additional requirements.
# To be accredited, these bodies must prove their independence and expertise, commit to approved certification criteria, have procedures for issuing, reviewing, and withdrawing certifications, handle complaints transparently, and ensure no conflicts of interest. Accreditation is based on criteria approved by the supervisory authority or the Board and lasts up to five years, renewable if the body continues to meet requirements.
# Certification bodies must explain their reasons for granting or withdrawing certifications to the supervisory authorities. Accreditation criteria and certification requirements must be publicly available, and violations by certification bodies can lead to revocation of their accreditation.
# The European Commission has the power to define more specific requirements for data protection certification and to adopt technical standards for such mechanisms, aiming to promote and recognize data protection certifications, seals, and marks.
# -- You can only transfer personal data to a non-EU country or international organisation if it meets GDPR requirements, ensuring protection levels are not reduced. This also applies to any further transfer from that third country or organisation to another.
# -- You can transfer personal data to a third country or international organisation without specific authorisation if the European Commission has recognised that location as providing an adequate level of protection. The Commission evaluates adequacy based on the rule of law, human rights respect, relevant legislation, data protection measures, the existence of supervisory authorities, and international commitments related to data protection.
# After assessing the protection level, the Commission may declare that a third country, specific territory, or organisation ensures adequate protection, subject to a review at least every four years. This decision will outline its application scope and identify any supervisory authority involved.
# The Commission continuously monitors changes that could impact the validity of its adequacy decisions, and if it finds a country or organisation no longer provides adequate protection, it can repeal, amend, or suspend the decision without retroactive effect. In urgent cases, immediate actions can be taken.
# The Commission will try to remedy any situations leading to an inadequacy decision by consulting with the affected country or organisation. Despite such decisions, personal data may still be transferred under specific conditions.
# A list of countries, territories, and organisations deemed to provide or not provide adequate protection will be published in the Official Journal of the European Union and on the Commission's website. Previous decisions made under Directive 95/46/EC remain effective until they are updated or repealed.
# -- You can transfer personal data to countries outside the EU or international organisations only if you provide appropriate safeguards and ensure that individuals have enforceable rights and effective legal remedies.
# The safeguards can be provided without needing specific approval from a supervisory authority through:
# - Legally binding instruments between public bodies;
# - Binding corporate rules;
# - Standard data protection clauses by the Commission;
# - Standard data protection clauses adopted by a supervisory authority and approved by the Commission;
# - An approved code of conduct with binding commitments in the third country;
# - An approved certification mechanism with binding commitments in the third country.
# If authorisation from a supervisory authority is needed, safeguards may include:
# - Contractual clauses between you and the data receiver outside the EU;
# - Administrative arrangements between public bodies with enforceable rights for individuals.
# The supervisory authority must use the consistency mechanism for cases requiring its authorisation. Existing authorisations based on old rules remain valid until changed or repealed by a supervisory authority. Commission decisions under the old directive stay in effect until updated or repealed by a new Commission Decision.
# -- If you, as a business, plan to use binding corporate rules (BCRs) for international data transfers within your group of companies, these rules must first be approved by the relevant data protection authority. BCRs need to be legally enforceable across your group and give individuals rights concerning their personal data processing. The BCRs should detail your group’s structure, data transfer specifics, including types of data and processing purposes, affirm their binding nature, adhere to core data protection principles, specify individual rights and means for their exercise, including compensation mechanisms for rule breaches, and outline your liability for any breach by group members outside the EU.
# Moreover, BCRs should clarify how information about them is communicated to individuals, assign responsibility for compliance monitoring (potentially to a Data Protection Officer), describe internal complaint and compliance verification mechanisms, including data protection audits, and detail the process for updating BCRs and liaising with supervisory authorities about changes or compliance issues. They must also address cooperation with supervisory authorities, report on local legal obligations conflicting with BCRs' guarantees, and ensure relevant personnel receive data protection training.
# The European Commission may issue further guidelines on the format and procedures for managing BCR-related information exchanges between your business, other entities, and supervisory authorities.
# -- If a court, tribunal, or administrative authority outside the EU asks you to transfer or disclose personal information, you can only comply if there's an international agreement (like a mutual legal assistance treaty) between the EU or its Member State and that non-EU country. This must be done without ignoring other legal grounds for transferring personal data outlined in GDPR.
# -- In the absence of specific international data transfer agreements or safeguards:
# - You may transfer personal data abroad if the individual has explicitly agreed, aware of potential risks.
# - Transfers are allowed if necessary for contract performance with or in the interest of the individual, or for important public interest reasons.
# - Transfers can occur for establishing, exercising, or defending legal claims, protecting vital interests of individuals unable to consent, or from registers open to public consultation under certain conditions.
# - If none of these conditions apply, occasional transfers for compelling legitimate interests may be possible, provided you've assessed the situation, implemented suitable safeguards, informed the supervisory authority, and notified the individual.
# - Transfers from public registers cannot involve all personal data and must be to those with a legitimate interest.
# - Certain derogations do not apply to public authorities exercising official functions.
# - The applicable public interest must be recognised by law.
# - Member States can restrict data transfers for public interest reasons, notifying the Commission of such provisions.
# - Document your assessment and safeguards as per Article 30's record-keeping requirements.

# %%
concent_index
# Out:
#    section_reference                                               text  \
# 0                  2  Consent must be freely given, specific, inform...
# 1                  3  Consent must meet four criteria: freely given,...
# 2                3.1  To be valid, consent must be given freely. Thi...
# 3              3.1.1  Freely given consent requires a genuine choice...
# 4              3.1.2  Consent must be freely given. Bundling consent...
# ..               ...                                                ...
# 92               7.3  What rights does an individual have when proce...
# 93               7.3  What rights to data does an individual have if...
# 94               7.3  How does withdrawing consent affect an individ...
# 95                 8  How should existing consents be reviewed to en...
# 96                 8  What happens if the current consent mechanisms...
#
#       source                                          embedding document
# 0    summary  [-0.03871389850974083, -0.028905309736728668, ...  Concent
# 1    summary  [-0.015930110588669777, -0.01131503377109766, ...  Concent
# 2    summary  [-0.031091932207345963, -0.00736756669357419, ...  Concent
# 3    summary  [-0.03908756002783775, -0.04293598607182503, -...  Concent
# 4    summary  [-0.02875448577105999, -0.024869825690984726, ...  Concent
# ..       ...                                                ...      ...
# 92  question  [-0.02233157679438591, -0.050518155097961426, ...  Concent
# 93  question  [-0.06421481817960739, -0.0555371418595314, -0...  Concent
# 94  question  [-0.049304455518722534, -0.04337126389145851, ...  Concent
# 95  question  [-0.02116905152797699, -0.0059234024956822395,...  Concent
# 96  question  [-0.028242340311408043, -0.05475907772779465, ...  Concent
#
# [97 rows x 5 columns]

# %%
covid_index['section_reference'] = covid_index['section_reference'].astype(str)

# %%
online_index['section_reference'] = online_index['section_reference'].astype(str)
online_index
save_parquet_data(online_index, index_file, key)

# %%
file = "../inputs/index/article_47_bcr.parquet"
#df_index.to_parquet(file, engine = "pyarrow")
save_parquet_data(index_df, file, key)

# %%
from src.index_tools import update_text_in_index, add_to_index

index_df = article_47_index
#index_df = gdpr_index

text_to_change = "What points need to be addressed in the Binding Corporate Rules for Controllers (BCR-C)"
changed_text = "What points need to be addressed in the Binding Corporate Rules for controllers?"
embedding_model = model
embedding_dimensions = dimensions

index_df = update_text_in_index(openai_client = openai_client, index_df = index_df, text_to_change = text_to_change, changed_text = changed_text, embedding_model = embedding_model, embedding_dimensions = embedding_dimensions)
# Out:
#    section_reference                                               text  \
# 0                1.1  You can use binding corporate rules (BCRs) for...
# 1                1.5  Binding Corporate Rules for controllers (BCR-C...
# 2                1.6  You must comply with EU data protection legisl...
# 3                1.7  You must use Binding Corporate Rules (BCR) as ...
# 4                1.8  Binding Corporate Rules (BCRs) need approval f...
# ..               ...                                                ...
# 82               3.6  What agreements must be made regarding the han...
# 83               3.7  What expectations are set for members of Bindi...
# 84               3.8  What obligations are there to keep Binding Cor...
# 85               3.9  What definitions must be included in the Bindi...
# 86          Analysis  What points need to be addressed in the Bindin...
#
#       source                                          embedding  \
# 0    summary  [-0.009783994406461716, -0.06066862493753433, ...
# 1    summary  [-0.017316676676273346, -0.021807707846164703,...
# 2    summary  [-0.07271231710910797, -0.06814079731702805, -...
# 3    summary  [-0.017403494566679, -0.08751912415027618, -0....
# 4    summary  [-0.004610632546246052, -0.043068330734968185,...
# ..       ...                                                ...
# 82  question  [-0.04174955189228058, -0.0986546203494072, -0...
# 83  question  [-0.04039411619305611, -0.08921048790216446, -...
# 84  question  [-0.04588606581091881, -0.06260394304990768, -...
# 85  question  [-0.010924087837338448, -0.03873256593942642, ...
# 86  question  [-0.0038541764952242374, -0.05298667028546333,...
#
#           document
# 0   Article_47_BCR
# 1   Article_47_BCR
# 2   Article_47_BCR
# 3   Article_47_BCR
# 4   Article_47_BCR
# ..             ...
# 82  Article_47_BCR
# 83  Article_47_BCR
# 84  Article_47_BCR
# 85  Article_47_BCR
# 86  Article_47_BCR
#
# [87 rows x 5 columns]

# %%
import importlib
import src.index_tools
importlib.reload(src.index_tools)
from src.index_tools import add_to_index

index_df = article_47_index
text = "What happens if local laws conflict with the standards of binding corporate rules?"
section_reference = "3.5.4.1"
source = "question"
document = "Article_47_BCR"

index_df = add_to_index(openai_client, index_df, text, section_reference, source, document, embedding_model, embedding_dimensions)

# %%
from src.index_tools import remove_from_index

text_to_delete = "What happens if local laws conflict with the standards of binding corporate rules?"
article_47_index = remove_from_index(article_47_index, text_to_delete)

# %%
article_47_index = index_df
article_47_index[article_47_index["section_reference"] == "3.5.4.1"]
# Out:
#    section_reference                                               text  \
# 25           3.5.4.1  You must ensure that the Binding Corporate Rul...
# 79           3.5.4.1  What should the Binding Corporate Rules-Contro...
# 87           3.5.4.1  What happens if local laws conflict with the s...
#
#       source                                          embedding  \
# 25   summary  [-0.018655141815543175, -0.05344023182988167, ...
# 79  question  [-0.014255059882998466, -0.07780193537473679, ...
# 87  question  [-0.02774774841964245, -0.06760360300540924, -...
#
#           document
# 25  Article_47_BCR
# 79  Article_47_BCR
# 87  Article_47_BCR

# %%
save_parquet_data(index_df, "../inputs/index/gdpr.parquet", key)

# %%
index_df[index_df['document'] == "article_30_5"]
# Out:
#                                                   text  \
# 147  Under what conditions could you be exempt from...
#
#                                              embedding    source  \
# 147  [-0.03439036011695862, -0.0008122794097289443,...  question
#
#     section_reference      document
# 147               all  article_30_5

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')

path_to_file = "../inputs/index/article_30_5.parquet"
index = load_parquet_data(path_to_file, key)

# %%
#index["document"] = "Article_30_5"
index
# Out:
#   section_reference  ...      document
# 0               all  ...  Article_30_5
# 1               all  ...  Article_30_5
# 2               all  ...  Article_30_5
# 3               all  ...  Article_30_5
# 4               all  ...  Article_30_5
# 5               all  ...  Article_30_5
# 6               all  ...  Article_30_5
# 7               all  ...  Article_30_5
#
# [8 rows x 5 columns]

# %%
save_parquet_data(index, path_to_file, key)
