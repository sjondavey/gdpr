# %%
import logging
log_level = 25
logging.basicConfig(level=log_level) # root logger

# %%
class_name = "OnlineServices"
summary_file = "../tmp/online_services_summary.csv"
question_file = "../tmp/online_services_question.csv"

path_to_manual_as_csv_file = "../inputs/documents/online_services.parquet"
index_file = "../inputs/index/online_services.parquet"

# %%
import re
import pandas as pd

import sys
sys.path.append('E:/Code/chat/gdpr')

import importlib
import gdpr_rag.documents.online_services
importlib.reload(gdpr_rag.documents.online_services)
from gdpr_rag.documents.online_services import OnlineServices

path_to_manual_as_csv_file = "../inputs/documents/online_services.parquet"

doc = OnlineServices(path_to_manual_as_csv_file)

# %%
from regulations_rag.regulation_table_of_content import StandardTableOfContent
reference_checker = doc.reference_checker
df = pd.read_parquet(path_to_manual_as_csv_file, engine='pyarrow')
toc = StandardTableOfContent(root_node_name = "transparency", reference_checker = reference_checker, regulation_df = df)

# %%
toc.print_tree()
# Out:
# transparency []
# |-- 1 [PART 1 - INTRODUCTION ]
# |   |-- .1 [Background ]
# |   +-- .2 [Scope of these guidelines ]
# |-- 2 [PART 2 - ANALYSIS OF ARTICLE 6(1)(B)  ]
# |   |-- .1 [General observations ]
# |   |-- .2 [Interaction of Article 6(1)(b) with other lawful bases for processing ]
# |   |-- .3 [Scope of Article 6(1)(b) ]
# |   |-- .4 [Necessity ]
# |   |-- .5 [Necessary for performance of a contract with the data subject ]
# |   |-- .6 [Termination of contract ]
# |   +-- .7 [Necessary for taking steps prior to entering into a contract ]
# +-- 3 [PART 3 - APPLICABILITY OF ARTICLE 6(1)(B) IN SPECIFIC SITUATIONS ]
#     |-- .1 [Processing for 'service improvement'[^25]
# [^25] Online services may also need to take into account Directive (EU) 2019/770 of the European Parliament and of the Council of 20 May 2019 on certain aspects concerning contracts for the supply of digital content and digital services (OJ L 136, 22.05.2019, p. 1), which will apply as from 1 January 2022.]
#     |-- .2 [Processing for 'fraud prevention' ]
#     |-- .3 [Processing for online behavioural advertising ]
#     +-- .4 [Processing for personalisation of content[^34]
# [^34] Online services may also need to take into account Directive (EU) 2019/770 of the European Parliament and of the Council of 20 May 2019 on certain aspects concerning contracts for the supply of digital content and digital services (OJ L 136, 22.05.2019, p. 1), which will apply as from 1 January 2022.]

# %%
sys.path.append('E:/Code/chat/gdpr')

from anytree import Node, PreOrderIter
from regulations_rag.embeddings import num_tokens_from_string

all_nodes = list(PreOrderIter(toc.root))
all_node_names = [node.full_node_name for node in all_nodes if node.full_node_name != ""]
split_df = pd.DataFrame(all_node_names, columns = ["section_reference"])
for index, row in split_df.iterrows():
    text = doc.get_text(row['section_reference'])
    split_df.at[index, 'text'] = text
    split_df.at[index, 'token_count'] = num_tokens_from_string(text)
split_df["token_count"] = split_df["token_count"].astype(int)

split_df = split_df.drop([0, 1, 2]) # Introduction
split_df = split_df[split_df["token_count"] > 25] 
split_df.reset_index(drop=True, inplace=True)
split_df
# Out:
#    section_reference                                               text  \
# 0                2.1  2 PART 2 - ANALYSIS OF ARTICLE 6(1)(B)  \n\n2....
# 1                2.2  2 PART 2 - ANALYSIS OF ARTICLE 6(1)(B)  \n\n2....
# 2                2.3  2 PART 2 - ANALYSIS OF ARTICLE 6(1)(B)  \n\n2....
# 3                2.4  2 PART 2 - ANALYSIS OF ARTICLE 6(1)(B)  \n\n2....
# 4                2.5  2 PART 2 - ANALYSIS OF ARTICLE 6(1)(B)  \n\n2....
# 5                2.6  2 PART 2 - ANALYSIS OF ARTICLE 6(1)(B)  \n\n2....
# 6                2.7  2 PART 2 - ANALYSIS OF ARTICLE 6(1)(B)  \n\n2....
# 7                3.1  3 PART 3 - APPLICABILITY OF ARTICLE 6(1)(B) IN...
# 8                3.2  3 PART 3 - APPLICABILITY OF ARTICLE 6(1)(B) IN...
# 9                3.3  3 PART 3 - APPLICABILITY OF ARTICLE 6(1)(B) IN...
# 10               3.4  3 PART 3 - APPLICABILITY OF ARTICLE 6(1)(B) IN...
#
#     token_count
# 0           984
# 1           749
# 2            93
# 3           754
# 4          2180
# 5           746
# 6           421
# 7           305
# 8           231
# 9           841
# 10          475

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')
#index_df = load_parquet_data("../inputs/index_gdpr.parquet", key)

# %%
from openai import OpenAI
openai_client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),)

import sys
sys.path.append('E:/Code/chat/gdpr')
import importlib
import src.summarise_and_question
importlib.reload(src.summarise_and_question)
from src.summarise_and_question import get_summary_and_questions_for

# %%
if os.path.exists(summary_file):
    df_summary = pd.read_csv(summary_file, sep="|", encoding = "utf-8")
else:
    df_summary = pd.DataFrame([], columns = ["section_reference", "text", "source", "embedding", "document"])
    df_summary["section_reference"] = split_df["section_reference"]
    # df_summary["text"] = split_df["text"]
    df_summary["source"] = "summary"
    df_summary["document"] = class_name

first_empty_index = df_summary[df_summary['text'].isna()].index.min()

if pd.isna(first_empty_index):
    #print("No empty embeddings found.")
    first_empty_index = 0
index = first_empty_index

if os.path.exists(question_file):
    df_questions = pd.read_csv(question_file, sep="|", encoding = "utf-8")
else:
    df_questions = pd.DataFrame([], columns = ["section_reference", "text", "source", "embedding", "document"])
    df_questions["section_reference"] = split_df["section_reference"]
    # df_questions["text"] = split_df["text"]
    df_questions["source"] = "question"
    df_questions["document"] = class_name

first_empty_index = df_questions[df_questions['text'].isna()].index.min()

if pd.isna(first_empty_index):
    #print("No empty embeddings found.")
    first_empty_index = 0

if index != first_empty_index:
    print("The index in the summary and questions files do not match. This needs to be fixed")
else:
    [print(f"Picking up at index {index}")]
# Out:
# Picking up at index 0

# %%
model = "gpt-4o"

reference = df_summary.iloc[index]["section_reference"]

reg_text = doc.get_text(reference)
print("##############")
print(reg_text)
print("##############")

model_summary, model_questions = get_summary_and_questions_for(openai_client = openai_client, text = reg_text, model = model)

#format output
print(f'# index: {index}, section_reference: {df_summary.iloc[index]["section_reference"]}')
print()
print(f'df_summary.loc[index, "text"] = "{model_summary}"')
print()
print(f'df_questions.loc[index, "text"] = "{model_questions}"')
# Out:
# ##############
# 3 PART 3 - APPLICABILITY OF ARTICLE 6(1)(B) IN SPECIFIC SITUATIONS
#
# 3.4 Processing for personalisation of content[^34]
# 57. The EDPB acknowledges that personalisation of content may (but does not always) constitute an intrinsic and expected element of certain online services, and therefore may be regarded as necessary for the performance of the contract with the service user in some cases. Whether such processing can be regarded as an intrinsic aspect of an online service, will depend on the nature of the service provided, the expectations of the average data subject in light not only of the terms of service but also the way the service is promoted to users, and whether the service can be provided without personalisation. Where personalisation of content is not objectively necessary for the purpose of the underlying contract, for example where personalised content delivery is intended to increase user engagement with a service but is not an integral part of using the service, data controllers should consider an alternative lawful basis where applicable.
# Example 7
# An online hotel search engine monitors past bookings of users in order to create a profile of their typical expenditure. This profile is subsequently used to recommend particular hotels to the user when returning search results. In this case, profiling of user's past behaviour and financial data would not be objectively necessary for the performance of a contract, i.e. the provision of hospitality services based on particular search criteria provided by the user. Therefore, Article 6(1)(b) would not be applicable to this processing activity.
# Example 8
# An online marketplace allows potential buyers to browse for and purchase products. The marketplace wishes to display personalised product suggestions based on which listings the potential buyers have previously viewed on the platform in order to increase interactivity. This personalisation it is not objectively necessary to provide the marketplace service. Thus, such processing of personal data cannot rely on Article 6(1)(b) as a legal basis.
#
# [^34] Online services may also need to take into account Directive (EU) 2019/770 of the European Parliament and of the Council of 20 May 2019 on certain aspects concerning contracts for the supply of digital content and digital services (OJ L 136, 22.05.2019, p. 1), which will apply as from 1 January 2022.
# ##############
# # index: 10, section_reference: 3.4
#
# df_summary.loc[index, "text"] = "Content personalisation can sometimes be considered an essential element of certain online services, making it necessary for fulfilling a contract with a user. This depends on the type of service, user expectations based on service terms and promotions, and whether the service can function without personalisation. If personalisation is not crucial for the contract, like increasing user engagement without being integral to the service, you should find an alternative legal basis for processing.
#
# Example 7: A hotel search engine using past bookings to recommend hotels to users does not qualify as necessary for contract performance since profiling user's past behaviour and financial data is not essential for providing search results.
#
# Example 8: An online marketplace suggesting products based on users' previous views to increase interactivity is not necessary for providing its services. Hence, processing personal data for this purpose cannot use Article 6(1)(b) as a legal basis."
#
# df_questions.loc[index, "text"] = "What does it mean when personalisation of content is considered necessary for a service?|How do expectations of individuals influence whether personalisation is necessary?|Can personalisation of content always be justified as necessary for a contract?|What should you do if personalisation is not necessary for a service?|What are examples of personalisation not being necessary for an online service?|How does profiling user's past behaviour relate to the necessity of personalisation?|Is personalised product suggestion generally necessary to provide an online marketplace service?"

# %%
model_summary
# Out:
# "Content personalisation can sometimes be considered an essential element of certain online services, making it necessary for fulfilling a contract with a user. This depends on the type of service, user expectations based on service terms and promotions, and whether the service can function without personalisation. If personalisation is not crucial for the contract, like increasing user engagement without being integral to the service, you should find an alternative legal basis for processing. \n\nExample 7: A hotel search engine using past bookings to recommend hotels to users does not qualify as necessary for contract performance since profiling user's past behaviour and financial data is not essential for providing search results.\n\nExample 8: An online marketplace suggesting products based on users' previous views to increase interactivity is not necessary for providing its services. Hence, processing personal data for this purpose cannot use Article 6(1)(b) as a legal basis."

# %%
# index: 10, section_reference: 3.4

df_summary.loc[index, "text"] = "Content personalisation can sometimes be considered an essential element of certain online services, making it necessary for fulfilling a contract with a user. This depends on the type of service, user expectations based on service terms and promotions, and whether the service can function without personalisation. If personalisation is not crucial for the contract, like increasing user engagement without being integral to the service, you should find an alternative legal basis for processing. \n\nExample: A hotel search engine using past bookings to recommend hotels to users does not qualify as necessary for contract performance since profiling user's past behaviour and financial data is not essential for providing search results.\n\nExample: An online marketplace suggesting products based on users' previous views to increase interactivity is not necessary for providing its services. Hence, processing personal data for this purpose cannot use Article 6(1)(b) as a legal basis."

df_questions.loc[index, "text"] = "When can content personalisation be considered necessary for a contract?|What factors determine if personalisation is an intrinsic part of an online service?"



index = index + 1
print(f"You have completed {(index / len(df_summary) * 100):.2f}% of the work")
if index < len(df_summary):
    print(f"The next section is:\n{doc.get_text(df_summary.iloc[index]['section_reference'])}")
else:
    print("All done")
# Out:
# You have completed 100.00% of the work
# All done

# %%
df_questions
# Out:
#     section_reference    source  embedding        document  \
# 0                 2.1  question        NaN  OnlineServices
# 1                 2.1  question        NaN  OnlineServices
# 2                 2.1  question        NaN  OnlineServices
# 3                 2.1  question        NaN  OnlineServices
# 4                 2.2  question        NaN  OnlineServices
# 5                 2.2  question        NaN  OnlineServices
# 6                 2.2  question        NaN  OnlineServices
# 7                 2.2  question        NaN  OnlineServices
# 8                 2.3  question        NaN  OnlineServices
# 9                 2.3  question        NaN  OnlineServices
# 10                2.3  question        NaN  OnlineServices
# 11                2.4  question        NaN  OnlineServices
# 12                2.4  question        NaN  OnlineServices
# 13                2.4  question        NaN  OnlineServices
# 14                2.5  question        NaN  OnlineServices
# 15                2.5  question        NaN  OnlineServices
# 16                2.5  question        NaN  OnlineServices
# 17                2.5  question        NaN  OnlineServices
# 18                2.6  question        NaN  OnlineServices
# 19                2.6  question        NaN  OnlineServices
# 20                2.6  question        NaN  OnlineServices
# 21                2.6  question        NaN  OnlineServices
# 22                2.7  question        NaN  OnlineServices
# 23                2.7  question        NaN  OnlineServices
# 24                3.1  question        NaN  OnlineServices
# 25                3.1  question        NaN  OnlineServices
# 26                3.2  question        NaN  OnlineServices
# 27                3.2  question        NaN  OnlineServices
# 28                3.2  question        NaN  OnlineServices
# 29                3.3  question        NaN  OnlineServices
# 30                3.3  question        NaN  OnlineServices
# 31                3.4  question        NaN  OnlineServices
# 32                3.4  question        NaN  OnlineServices
#
#                                                  text
# 0   What are the key considerations for processing...
# 1   How do fairness and reasonable expectations of...
# 2   What must you consider when processing childre...
# 3   Why must the purposes for data collection be c...
# 4   When might consent be a more appropriate legal...
# 5   What are the key requirements for identifying ...
# 6   How does the principle of fairness affect the ...
# 7   What is the difference between accepting terms...
# 8                 When is Article 6(1)(b) applicable?
# 9   When is processing considered necessary for pe...
# 10  When is processing considered necessary for pr...
# 11  What does 'necessary for the performance of a ...
# 12               What is the meaning of 'necessity'?
# 13   How do you determine if the processing is 'ne...
# 14  When can you process personal data to fulfil a...
# 15  What criteria must be met to use a contract as...
# 16  Can processing be necessary for a contract eve...
# 17  What should you assess to determine if data pr...
# 18  What should you consider before starting to pr...
# 19  What steps should you take if a contract is te...
# 20  How should you handle personal data for admini...
# 21  What are the requirements for erasing personal...
# 22  Why might data be processed before a contract ...
# 23  Can you process data for marketing purposes un...
# 24  Is the collection of user engagement data nece...
# 25  What lawful bases can service providers rely o...
# 26  Under what conditions can personal data be pro...
# 27   Can monitoring and profiling for fraud preven...
# 28   When is processing for fraud prevention consi...
# 29  Can online behavioural advertising be consider...
# 30  Does an individual have the right to object to...
# 31  When can content personalisation be considered...
# 32  What factors determine if personalisation is a...

# %%
df_summary.to_csv(summary_file, sep = "|", encoding = "utf-8", index = False, na_rep="")

df_questions.to_csv(question_file, sep = "|", encoding = "utf-8", index = False, na_rep="")

# %%
import pandas as pd
df_summary = pd.read_csv(summary_file, sep = "|", encoding = "utf-8")

df_questions = pd.read_csv(question_file, sep = "|", encoding = "utf-8")

# %%
df_questions = df_questions.drop("text", axis=1).join(df_questions["text"].str.split("|", expand=True).stack().reset_index(level=1, drop=True).rename("text"))
df_questions = df_questions[df_questions["text"] != ""]
df_questions.reset_index(drop=True, inplace=True)

# %%
df_index = pd.concat([df_summary, df_questions], ignore_index = True)
df_index
# Out:
#     section_reference                                               text  \
# 0                 2.1  Consider the lawful basis for processing under...
# 1                 2.2  When processing is not 'necessary for the perf...
# 2                 2.3  Article 6(1)(b) applies when the processing is...
# 3                 2.4  Processing must be necessary for both performa...
# 4                 2.5  To rely on Article 6(1)(b) for processing pers...
# 5                 2.6  Identify the appropriate legal basis for proce...
# 6                 2.7  Processing personal data is permissible if nec...
# 7                 3.1  Processing data for service improvement cannot...
# 8                 3.2  Processing for fraud prevention purposes may i...
# 9                 3.3  Processing personal data for online behavioura...
# 10                3.4  Content personalisation can sometimes be consi...
# 11                2.1  What are the key considerations for processing...
# 12                2.1  How do fairness and reasonable expectations of...
# 13                2.1  What must you consider when processing childre...
# 14                2.1  Why must the purposes for data collection be c...
# 15                2.2  When might consent be a more appropriate legal...
# 16                2.2  What are the key requirements for identifying ...
# 17                2.2  How does the principle of fairness affect the ...
# 18                2.2  What is the difference between accepting terms...
# 19                2.3                When is Article 6(1)(b) applicable?
# 20                2.3  When is processing considered necessary for pe...
# 21                2.3  When is processing considered necessary for pr...
# 22                2.4  What does 'necessary for the performance of a ...
# 23                2.4               What is the meaning of 'necessity'?
# 24                2.4   How do you determine if the processing is 'ne...
# 25                2.5  When can you process personal data to fulfil a...
# 26                2.5  What criteria must be met to use a contract as...
# 27                2.5  Can processing be necessary for a contract eve...
# 28                2.5  What should you assess to determine if data pr...
# 29                2.6  What should you consider before starting to pr...
# 30                2.6  What steps should you take if a contract is te...
# 31                2.6  How should you handle personal data for admini...
# 32                2.6  What are the requirements for erasing personal...
# 33                2.7  Why might data be processed before a contract ...
# 34                2.7  Can you process data for marketing purposes un...
# 35                3.1  Is the collection of user engagement data nece...
# 36                3.1  What lawful bases can service providers rely o...
# 37                3.2  Under what conditions can personal data be pro...
# 38                3.2   Can monitoring and profiling for fraud preven...
# 39                3.2   When is processing for fraud prevention consi...
# 40                3.3  Can online behavioural advertising be consider...
# 41                3.3  Does an individual have the right to object to...
# 42                3.4  When can content personalisation be considered...
# 43                3.4  What factors determine if personalisation is a...
#
#       source  embedding        document
# 0    summary        NaN  OnlineServices
# 1    summary        NaN  OnlineServices
# 2    summary        NaN  OnlineServices
# 3    summary        NaN  OnlineServices
# 4    summary        NaN  OnlineServices
# 5    summary        NaN  OnlineServices
# 6    summary        NaN  OnlineServices
# 7    summary        NaN  OnlineServices
# 8    summary        NaN  OnlineServices
# 9    summary        NaN  OnlineServices
# 10   summary        NaN  OnlineServices
# 11  question        NaN  OnlineServices
# 12  question        NaN  OnlineServices
# 13  question        NaN  OnlineServices
# 14  question        NaN  OnlineServices
# 15  question        NaN  OnlineServices
# 16  question        NaN  OnlineServices
# 17  question        NaN  OnlineServices
# 18  question        NaN  OnlineServices
# 19  question        NaN  OnlineServices
# 20  question        NaN  OnlineServices
# 21  question        NaN  OnlineServices
# 22  question        NaN  OnlineServices
# 23  question        NaN  OnlineServices
# 24  question        NaN  OnlineServices
# 25  question        NaN  OnlineServices
# 26  question        NaN  OnlineServices
# 27  question        NaN  OnlineServices
# 28  question        NaN  OnlineServices
# 29  question        NaN  OnlineServices
# 30  question        NaN  OnlineServices
# 31  question        NaN  OnlineServices
# 32  question        NaN  OnlineServices
# 33  question        NaN  OnlineServices
# 34  question        NaN  OnlineServices
# 35  question        NaN  OnlineServices
# 36  question        NaN  OnlineServices
# 37  question        NaN  OnlineServices
# 38  question        NaN  OnlineServices
# 39  question        NaN  OnlineServices
# 40  question        NaN  OnlineServices
# 41  question        NaN  OnlineServices
# 42  question        NaN  OnlineServices
# 43  question        NaN  OnlineServices

# %%
from regulations_rag.embeddings import get_ada_embedding
model = "text-embedding-3-large"
dimensions = 1024

#df_index = df_questions
df_index['embedding'] = pd.NA  # Initialize the column to hold NA values
df_index['embedding'] = df_index['embedding'].astype(object)  # Ensure the column type is object
increment = 10
for i in range(0, len(df_index), increment):
    chunk = df_index.iloc[i:i+increment].copy()
    chunk["embedding"] = chunk["text"].apply(lambda x: get_ada_embedding(openai_client, x, model, dimensions))
    df_index.loc[chunk.index, "embedding"] = chunk["embedding"]
    print(f"Completed {i+increment} lines")
# Out:
# Completed 10 lines
# Completed 20 lines
# Completed 30 lines
# Completed 40 lines
# Completed 50 lines

# %%
df_index.to_parquet(index_file, engine = "pyarrow")
save_parquet_data(df_index, index_file, key)

# %%
df_index
#df_index["document"] = "Article_47_BCR"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_index
#       2 #df_index["document"] = "Article_47_BCR"
#
# NameError: name 'df_index' is not defined

# %%
gdpr_index = load_parquet_data("../inputs/index/gdpr.parquet", key)
online_index = load_parquet_data("../inputs/index/online_services.parquet", key)

for index, row in gdpr_index[gdpr_index['section_reference'].str.startswith('5')].iterrows():
    print(f"-- {row['text']}")


# for index, row in index_df[index_df["section_reference"] == '30'].iterrows():
#     print(f"* {row['text']}")
# Out:
# -- What are the principles associated with personal data?
# -- When can I collect personal data?
# -- Once I have collected personal data, are there ongoing requirements?
# -- What measures are required to secure personal data under GDPR?
# -- Who is responsible for demonstrating compliance with GDPR's principles?
# -- Can I use personal data that my company has already collected?
# -- What steps must be taken to improve international cooperation in data protection?
# -- How does international mutual assistance enhance data protection enforcement?
# -- In what ways can relevant stakeholders be involved in international data protection efforts?
# -- How is the exchange and documentation of data protection practices promoted internationally?
# -- What actions are taken to address jurisdictional conflicts in data protection with third countries?
# -- What is the role of a supervisory authority?
# -- How do supervisory authorities contribute to GDPR?
# -- Can a Member State have more than one supervisory authority?
# -- How is cooperation between supervisory authorities and the Commission ensured?
# -- What is required of Member States regarding their supervisory authorities and the Commission?
# -- How independent must supervisory authorities be in their role?
# -- What measures are in place to protect supervisory authorities from external influence?
# -- Are members of supervisory authorities allowed to have other occupations?
# -- What resources must be provided to supervisory authorities?
# -- Who is in charge of the staff within a supervisory authority?
# -- How is the financial independence of supervisory authorities ensured?
# -- How are members of the supervisory authority appointed?
# -- What qualifications and skills do members of the supervisory authority need?
# -- How does a member's tenure on the supervisory authority end?
# -- Under what circumstances can a member of the supervisory authority be dismissed?
# -- How are supervisory authorities established in each Member State?
# -- What are the requirements to become a member of a supervisory authority?
# -- How is a member of a supervisory authority appointed?
# -- What is the minimum duration of tenure for a member of a supervisory authority?
# -- Can members of supervisory authorities be reappointed, and if so, how many times?
# -- What rules exist regarding the conduct and obligations of supervisory authority members and staff during and post-tenure?
# -- Are members and staff of supervisory authorities required to maintain confidentiality of information?
# -- Who is responsible for ensuring compliance within a Member State?
# -- In what areas do supervisory authorities have jurisdiction?
# -- When does a specific Member State's supervisory authority take charge?
# -- Are there any exceptions to the supervisory authority's jurisdiction?
# -- Who is responsible for acting as the lead supervisory authority in cross-border processing cases?
# -- When can local supervisory authorities handle complaints or possible infringements?
# -- What should a local supervisory authority do if a case touches only its Member State or affects individuals there significantly?
# -- How is it decided whether the lead or local supervisory authority will handle a case?
# -- What happens if the lead supervisory authority chooses to handle a case?
# -- What is the role of the lead supervisory authority in cross-border processing?
# -- Who acts as the main point of contact for you in cases of cross-border processing?
# -- What are the responsibilities of supervisory authorities?
# -- How do supervisory authorities assist in increasing public awareness about data protection?
# -- What role do supervisory authorities play in advising government bodies about data protection?
# -- How do supervisory authorities promote compliance awareness among organisations?
# -- Can individuals get help from supervisory authorities regarding their data protection rights?
# -- How are complaints from individuals handled and investigated by supervisory authorities?
# -- In what ways do supervisory authorities cooperate with each other?
# -- What investigations can supervisory authorities conduct?
# -- How do supervisory authorities keep up with technology and commercial practices affecting data protection?
# -- What is the process for adopting standard contractual clauses by supervisory authorities?
# -- How do supervisory authorities contribute to the development of data protection impact assessment (DPIA)s?
# -- What advice do supervisory authorities offer regarding data processing operations?
# -- How do supervisory authorities encourage and evaluate codes of conduct and certification mechanisms?
# -- What is involved in the accreditation process of monitoring and certification bodies by supervisory authorities?
# -- How do supervisory authorities approve international data transfer mechanisms?
# -- How is the submission of complaints to supervisory authorities made easier for individuals?
# -- Are there any fees for individuals seeking help from supervisory authorities?
# -- Under what circumstances can supervisory authorities refuse to act on a request?
# -- What powers do supervisory authorities have to gather information?
# -- How can supervisory authorities enforce compliance with GDPR?
# -- What types of corrective actions can supervisory authorities impose on businesses?
# -- What are the roles of supervisory authorities in advising and certifying GDPR compliance?
# -- What safeguards are in place when supervisory authorities exercise their powers?
# -- Can supervisory authorities initiate legal proceedings for GDPR infringements?
# -- Can Member States grant additional powers to their supervisory authorities?
# -- Who is responsible for creating an annual report on data protection activities?
# -- What might be included in the annual report on data protection activities?
# -- To whom must the annual report on data protection activities be transmitted?
# -- Is the annual report on data protection activities available to the public?
# -- Personal data must be processed lawfully, fairly, and transparently, collected for specific and legitimate purposes, and not used incompatibly with those purposes. It should be adequate, relevant, and limited to necessary data, accurate and updated as needed, with inaccurate data erased or rectified promptly. Data should only be kept as long as necessary for its initial purposes, though it can be stored longer for public interest, research, or statistical purposes if safeguard measures are in place. It must be secured against unauthorised access, loss, or damage. The controller is responsible for ensuring and demonstrating compliance with these principles.
# -- The Commission and supervisory authorities are tasked with developing mechanisms to support international cooperation on data protection enforcement. They will offer mutual assistance in data protection law enforcement, including notification and information exchanges, with necessary protections for personal data. Additionally, there will be engagement with stakeholders to advance global cooperation in enforcing data protection laws and promoting the sharing and documenting of data protection practices and legislation, including dealing with jurisdictional conflicts with non-EU countries.
# -- Each Member State must establish one or more independent authorities responsible for ensuring GDPR compliance to protect individual rights regarding personal data and to support the free movement of personal data within the EU. These authorities must work together to apply GDPR consistently across the EU. If a Member State has multiple authorities, it must select one to represent them in the Board and outline how to comply with consistency rules.
# -- Supervisory authorities must act independently when carrying out their tasks and exercising their rights under this regulation. They must not be influenced externally and cannot take instructions from anyone. They are not allowed to engage in any activity that conflicts with their duties during their term. Each supervisory authority must be provided with adequate resources, staff, and budget by their Member State to perform effectively, with safeguards in place to maintain their independence.
# -- Member States must ensure each supervisory authority member is appointed through a transparent process by their parliament, government, head of State, or an independent appointing body as per their law. Appointees must possess necessary qualifications, experience, and skills in data protection. A member's term ends upon reaching their term limit, resignation, or mandatory retirement according to national law, and they can only be dismissed in cases of serious misconduct or inability to perform their duties.
# -- Member States must legislate to:
# - Establish each supervisory authority,
# - Define qualifications and eligibility for supervisory authority membership,
# - Set rules and procedures for appointing members,
# - Ensure member terms last at least four years, with possible exceptions for the first appointment to maintain independence via staggered terms,
# - Determine if members can be reappointed and for how many terms,
# - Establish conditions and prohibitions for members and staff during and after their tenure, including employment termination rules.
# Members and staff of supervisory authorities must keep professional secrets during and after their terms, particularly concerning confidential information acquired during their duties, including reports of GDPR infringements.
# -- Supervisory authorities are responsible for overseeing GDPR compliance within their own Member State. For processing by public authorities or private entities under specific conditions, the supervisory authority of that Member State is competent. Supervisory authorities do not oversee court operations when courts are acting in their judicial capacity.
# -- For cross-border processing, the supervisory authority where your main or sole establishment is located will act as your lead supervisory authority. However, local supervisory authorities can address complaints or possible breaches that are specific to their Member State or significantly impact individuals within their Member State. When such a case arises, the local supervisory authority must promptly inform your lead supervisory authority. The lead authority then has three weeks to decide if it will handle the case via Article 60's procedure. If the lead authority opts to take the case, it will consider any decision drafts from the informing local authority. Conversely, if the lead authority decides not to take the case, the informing local authority will proceed according to Articles 61 and 62. Throughout this process, for cross-border processing issues, the lead supervisory authority will be your primary point of contact.
# -- Supervisory authorities are responsible for monitoring and enforcing GDPR within their territories, which includes promoting understanding of GDPR to the public, advising governmental and legislative bodies on data protection matters, and increasing awareness among you about your obligations under GDPR. They also provide information to individuals about their rights, handle and investigate complaints related to GDPR, cooperate and share information with other supervisory authorities to ensure consistent application of GDPR, and monitor developments that affect personal data protection.
# They are also tasked with adopting standard contractual clauses, maintaining a list for data protection impact assessment (DPIA)s, advising on processing operations that require consultation, encouraging codes of conduct and certification mechanisms, conducting periodic reviews of certifications, drafting and publishing accreditation criteria, conducting accreditations, authorising contractual clauses and provisions, approving binding corporate rules, contributing to the activities of the Board, keeping records of GDPR infringements and taken measures, and performing other related tasks.
# Supervisory authorities must facilitate easy submission of complaints, including through electronic means. Their services to individuals and data protection officers are generally free, but they can charge a fee or refuse requests deemed manifestly unfounded or excessive, provided they prove the basis for such decision.
# -- Supervisory authorities have the right to request information from you, carry out data protection audits, review certifications related to data protection, notify you of GDPR infringements, access personal data and premises for investigation, and enforce corrective measures such as issuing warnings, reprimands, compliance orders, communicate data breaches to individuals, limit or ban processing activities, rectify or erase personal data, withdraw certifications, impose administrative fines, and suspend data flows to third countries or international organisations. They can also provide advice, issue opinions on data protection matters, authorise specific types of data processing, accredit certification bodies, issue certifications, and approve codes of conduct and binding corporate rules. These powers are to be exercised with due process and judicial remedy options available. Supervisory authorities can also bring GDPR infringements to judicial attention and engage in legal proceedings to enforce the regulation. Member States may grant additional powers to supervisory authorities, provided these do not affect the operation of GDPR enforcement mechanisms.
# -- Supervisory authorities must create an annual report detailing their activities. This can include information on reported violations and actions taken. These reports must be sent to the national parliament, government, and specific authorities set by national laws. They must also be available to the public, the Commission, and the Board.

# %%
online_index['section_reference'] = online_index['section_reference'].astype(str)
online_index
save_parquet_data(online_index, index_file, key)

# %%
file = "../inputs/index/article_47_bcr.parquet"
#df_index.to_parquet(file, engine = "pyarrow")
save_parquet_data(index_df, file, key)

# %%
from src.index_tools import update_text_in_index, add_to_index

index_df = article_47_index
#index_df = gdpr_index

text_to_change = "What points need to be addressed in the Binding Corporate Rules for Controllers (BCR-C)"
changed_text = "What points need to be addressed in the Binding Corporate Rules for controllers?"
embedding_model = model
embedding_dimensions = dimensions

index_df = update_text_in_index(openai_client = openai_client, index_df = index_df, text_to_change = text_to_change, changed_text = changed_text, embedding_model = embedding_model, embedding_dimensions = embedding_dimensions)
# Out:
#    section_reference                                               text  \
# 0                1.1  You can use binding corporate rules (BCRs) for...
# 1                1.5  Binding Corporate Rules for controllers (BCR-C...
# 2                1.6  You must comply with EU data protection legisl...
# 3                1.7  You must use Binding Corporate Rules (BCR) as ...
# 4                1.8  Binding Corporate Rules (BCRs) need approval f...
# ..               ...                                                ...
# 82               3.6  What agreements must be made regarding the han...
# 83               3.7  What expectations are set for members of Bindi...
# 84               3.8  What obligations are there to keep Binding Cor...
# 85               3.9  What definitions must be included in the Bindi...
# 86          Analysis  What points need to be addressed in the Bindin...
#
#       source                                          embedding  \
# 0    summary  [-0.009783994406461716, -0.06066862493753433, ...
# 1    summary  [-0.017316676676273346, -0.021807707846164703,...
# 2    summary  [-0.07271231710910797, -0.06814079731702805, -...
# 3    summary  [-0.017403494566679, -0.08751912415027618, -0....
# 4    summary  [-0.004610632546246052, -0.043068330734968185,...
# ..       ...                                                ...
# 82  question  [-0.04174955189228058, -0.0986546203494072, -0...
# 83  question  [-0.04039411619305611, -0.08921048790216446, -...
# 84  question  [-0.04588606581091881, -0.06260394304990768, -...
# 85  question  [-0.010924087837338448, -0.03873256593942642, ...
# 86  question  [-0.0038541764952242374, -0.05298667028546333,...
#
#           document
# 0   Article_47_BCR
# 1   Article_47_BCR
# 2   Article_47_BCR
# 3   Article_47_BCR
# 4   Article_47_BCR
# ..             ...
# 82  Article_47_BCR
# 83  Article_47_BCR
# 84  Article_47_BCR
# 85  Article_47_BCR
# 86  Article_47_BCR
#
# [87 rows x 5 columns]

# %%
import importlib
import src.index_tools
importlib.reload(src.index_tools)
from src.index_tools import add_to_index

index_df = article_47_index
text = "What happens if local laws conflict with the standards of binding corporate rules?"
section_reference = "3.5.4.1"
source = "question"
document = "Article_47_BCR"

index_df = add_to_index(openai_client, index_df, text, section_reference, source, document, embedding_model, embedding_dimensions)

# %%
from src.index_tools import remove_from_index

text_to_delete = "What happens if local laws conflict with the standards of binding corporate rules?"
article_47_index = remove_from_index(article_47_index, text_to_delete)

# %%
article_47_index = index_df
article_47_index[article_47_index["section_reference"] == "3.5.4.1"]
# Out:
#    section_reference                                               text  \
# 25           3.5.4.1  You must ensure that the Binding Corporate Rul...
# 79           3.5.4.1  What should the Binding Corporate Rules-Contro...
# 87           3.5.4.1  What happens if local laws conflict with the s...
#
#       source                                          embedding  \
# 25   summary  [-0.018655141815543175, -0.05344023182988167, ...
# 79  question  [-0.014255059882998466, -0.07780193537473679, ...
# 87  question  [-0.02774774841964245, -0.06760360300540924, -...
#
#           document
# 25  Article_47_BCR
# 79  Article_47_BCR
# 87  Article_47_BCR

# %%
save_parquet_data(index_df, "../inputs/index/gdpr.parquet", key)

# %%
index_df[index_df['document'] == "article_30_5"]
# Out:
#                                                   text  \
# 147  Under what conditions could you be exempt from...
#
#                                              embedding    source  \
# 147  [-0.03439036011695862, -0.0008122794097289443,...  question
#
#     section_reference      document
# 147               all  article_30_5

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')

path_to_file = "../inputs/index/article_30_5.parquet"
index = load_parquet_data(path_to_file, key)

# %%
#index["document"] = "Article_30_5"
index
# Out:
#   section_reference  ...      document
# 0               all  ...  Article_30_5
# 1               all  ...  Article_30_5
# 2               all  ...  Article_30_5
# 3               all  ...  Article_30_5
# 4               all  ...  Article_30_5
# 5               all  ...  Article_30_5
# 6               all  ...  Article_30_5
# 7               all  ...  Article_30_5
#
# [8 rows x 5 columns]

# %%
save_parquet_data(index, path_to_file, key)
