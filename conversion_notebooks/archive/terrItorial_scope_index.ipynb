# %%
import logging
log_level = 25
logging.basicConfig(level=log_level) # root logger

# %%
class_name = "TerritorialScope"
summary_file = "../tmp/territorial_scope_summary.csv"
question_file = "../tmp/territorial_scope_question.csv"

path_to_manual_as_csv_file = "../inputs/documents/territorial_scope.parquet"
index_file = "../inputs/index/territorial_scope.parquet"

# %%
import re
import pandas as pd

import sys
sys.path.append('E:/Code/chat/gdpr')

import importlib
import gdpr_rag.documents.territorial_scope
importlib.reload(gdpr_rag.documents.territorial_scope)
from gdpr_rag.documents.territorial_scope import TerritorialScope


doc = TerritorialScope(path_to_manual_as_csv_file)

# %%
from regulations_rag.regulation_table_of_content import StandardTableOfContent
reference_checker = doc.reference_checker
df = pd.read_parquet(path_to_manual_as_csv_file, engine='pyarrow')
toc = StandardTableOfContent(root_node_name = "territorial_scope", reference_checker = reference_checker, regulation_df = df)

# %%
toc.print_tree()
# Out:
# territorial_scope []
# |-- INTRODUCTION [INTRODUCTION    ]
# |-- 1 [APPLICATION OF THE ESTABLISHMENT CRITERION - ART 3(1)    ]
# |   |-- .a ["An establishment in the Union"  ]
# |   |-- .b [Processing of personal data carried out "in the context of the activities of" an  establishment   ]
# |   |-- .c [Application of the GDPR to the establishment of a controller or a processor in the Union, regardless of whether the processing takes place in the Union or not  ]
# |   +-- .d [Application of the establishment criterion to controller and processor  ]
# |-- 2 [APPLICATION OF THE TARGETING CRITERION - ART 3(2)  ]
# |   |-- .a [Data subjects in the Union  ]
# |   |-- .b [Offering of goods or services, irrespective of whether a payment of the data subject  ]
# |   |-- .c [Monitoring of data subjects' behaviour   ]
# |   |-- .d [Processor not established in the Union  ]
# |   +-- .e [Interaction with other GDPR provisions and other legislations  ]
# |-- 3 [PROCESSING IN A PLACE WHERE MEMBER STATE LAW APPLIES BY  VIRTUE OF PUBLIC INTERNATIONAL LAW  ]
# +-- 4 [REPRESENTATIVE OF CONTROLLERS OR PROCESSORS NOT  ESTABLISHED IN THE UNION  ]
#     |-- .a [Designation of a representative  ]
#     |-- .b [Exemptions from the designation obligation[^31]
# [^31] Part of the criteria and interpretation laid down in G29 WP243 rev.1 (Data Protection Officer) - endorsed by  the EDPB can be used as a basis for the exemptions to the designation obligation.]
#     |-- .c [Establishment in one of the Member States where the data subjects whose personal  data are processed   ]
#     +-- .d [Obligations and responsibilities of the representative  ]

# %%
sys.path.append('E:/Code/chat/gdpr')

from anytree import Node, PreOrderIter
from regulations_rag.embeddings import num_tokens_from_string

all_nodes = list(PreOrderIter(toc.root))
all_node_names = [node.full_node_name for node in all_nodes if node.full_node_name != ""]
split_df = pd.DataFrame(all_node_names, columns = ["section_reference"])
for index, row in split_df.iterrows():
    text = doc.get_text(row['section_reference'])
    split_df.at[index, 'text'] = text
    split_df.at[index, 'token_count'] = num_tokens_from_string(text)
split_df["token_count"] = split_df["token_count"].astype(int)

split_df = split_df.drop([0]) # Introduction
#split_df = split_df[split_df["token_count"] > 25] 
split_df.reset_index(drop=True, inplace=True)
split_df
# Out:
#    section_reference                                               text  \
# 0                  1  1 APPLICATION OF THE ESTABLISHMENT CRITERION -...
# 1                1.a  1 APPLICATION OF THE ESTABLISHMENT CRITERION -...
# 2                1.b  1 APPLICATION OF THE ESTABLISHMENT CRITERION -...
# 3                1.c  1 APPLICATION OF THE ESTABLISHMENT CRITERION -...
# 4                1.d  1 APPLICATION OF THE ESTABLISHMENT CRITERION -...
# 5                  2  2 APPLICATION OF THE TARGETING CRITERION - ART...
# 6                2.a  2 APPLICATION OF THE TARGETING CRITERION - ART...
# 7                2.b  2 APPLICATION OF THE TARGETING CRITERION - ART...
# 8                2.c  2 APPLICATION OF THE TARGETING CRITERION - ART...
# 9                2.d  2 APPLICATION OF THE TARGETING CRITERION - ART...
# 10               2.e  2 APPLICATION OF THE TARGETING CRITERION - ART...
# 11                 3  3 PROCESSING IN A PLACE WHERE MEMBER STATE LAW...
# 12                 4  4 REPRESENTATIVE OF CONTROLLERS OR PROCESSORS ...
# 13               4.a  4 REPRESENTATIVE OF CONTROLLERS OR PROCESSORS ...
# 14               4.b  4 REPRESENTATIVE OF CONTROLLERS OR PROCESSORS ...
# 15               4.c  4 REPRESENTATIVE OF CONTROLLERS OR PROCESSORS ...
# 16               4.d  4 REPRESENTATIVE OF CONTROLLERS OR PROCESSORS ...
#
#     token_count
# 0           321
# 1          1462
# 2          1034
# 3           493
# 4          2204
# 5           849
# 6           790
# 7          1691
# 8           769
# 9           370
# 10          198
# 11          486
# 12          321
# 13         1250
# 14          804
# 15          244
# 16          870

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')
#index_df = load_parquet_data("../inputs/index_gdpr.parquet", key)

# %%
from openai import OpenAI
openai_client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),)

import sys
sys.path.append('E:/Code/chat/gdpr')
import importlib
import src.summarise_and_question
importlib.reload(src.summarise_and_question)
from src.summarise_and_question import get_summary_and_questions_for

# %%
if os.path.exists(summary_file):
    df_summary = pd.read_csv(summary_file, sep="|", encoding = "utf-8")
else:
    df_summary = pd.DataFrame([], columns = ["section_reference", "text", "source", "embedding", "document"])
    df_summary["section_reference"] = split_df["section_reference"]
    # df_summary["text"] = split_df["text"]
    df_summary["source"] = "summary"
    df_summary["document"] = class_name

first_empty_index = df_summary[df_summary['text'].isna()].index.min()

if pd.isna(first_empty_index):
    #print("No empty embeddings found.")
    first_empty_index = 0
index = first_empty_index

if os.path.exists(question_file):
    df_questions = pd.read_csv(question_file, sep="|", encoding = "utf-8")
else:
    df_questions = pd.DataFrame([], columns = ["section_reference", "text", "source", "embedding", "document"])
    df_questions["section_reference"] = split_df["section_reference"]
    # df_questions["text"] = split_df["text"]
    df_questions["source"] = "question"
    df_questions["document"] = class_name

first_empty_index = df_questions[df_questions['text'].isna()].index.min()

if pd.isna(first_empty_index):
    #print("No empty embeddings found.")
    first_empty_index = 0

if index != first_empty_index:
    print("The index in the summary and questions files do not match. This needs to be fixed")
else:
    [print(f"Picking up at index {index}")]
# Out:
# Picking up at index 0

# %%
model = "gpt-4o"

reference = df_summary.iloc[index]["section_reference"]

reg_text = doc.get_text(reference)
print("##############")
print(reg_text)
print("##############")

model_summary, model_questions = get_summary_and_questions_for(openai_client = openai_client, text = reg_text, model = model)

#format output
print(f'# index: {index}, section_reference: {df_summary.iloc[index]["section_reference"]}')
print()
print(f'df_summary.loc[index, "text"] = "{model_summary}"')
print()
print(f'df_questions.loc[index, "text"] = "{model_questions}"')
# Out:
# ##############
# 4 REPRESENTATIVE OF CONTROLLERS OR PROCESSORS NOT  ESTABLISHED IN THE UNION
#
# 4.d Obligations and responsibilities of the representative
# The representative in the Union acts on behalf of the controller or processor it represents with regard  to the controller or processor's obligations under the GDPR. This implies notably the obligations  relating to the exercise of data subject rights, and in this regard and as already stated, the identity and  contact details of the representative must be provided to data subjects in accordance with articles 13  and 14. While not itself responsible for complying with data subject rights, the representative must  facilitate the communication between data subjects and the controller or processor represented, in  order to make the exercise of data subjects' rights are effective.
# As per Article 30, the controller or processor's representative shall in particular maintain a record of  processing activities under the responsibility of the controller or processor. The EDPB considers that,  while the maintenance of this record is an obligation imposed on both the controller or processer and  the representative,, the controller or processor not established in the Union is responsible for the  primary content and update of the record and must simultaneously provide its representative with all  accurate and updated information so that the record can also be kept and made available by the  representative at all time At the same time, it is the representative´s own responsibility to be able to  provide it in line with Article 27, e.g. when being addressed by a supervisory authority according to  Art. 27(4).
# As clarified by recital 80, the representative should also perform its tasks according to the mandate  received from the controller or processor, including cooperating with the competent supervisory  authorities with regard to any action taken to ensure compliance with this Regulation. In practice, this  means that a supervisory authority would contact the representative in connection with any matter  relating to the compliance obligations of a controller or processor established outside the Union, and  the representative shall be able to facilitate any informational or procedural exchange between a  requesting supervisory authority and a controller or processor established outside the Union.
# With the help of a team if necessary, the representative in the Union must therefore be in a position  to efficiently communicate with data subjects and cooperate with the supervisory authorities  concerned. This means that this communication should in principle take place in the language or  languages used by the supervisory authorities and the data subjects concerned or, should this result  in a disproportionate effort, that other means and techniques shall be used by the representative in  order to ensure the effectiveness of communication. The availability of a representative is therefore  essential in order to ensure that data subjects and supervisory authorities will be able to establish  contact easily with the non-EU controller or processor. In line with Recital 80 and Article 27(5), the  designation of a representative in the Union does not affect the responsibility and liability of the  controller or of the processor under the GDPR and shall be without prejudice to legal actions which  could be initiated against the controller or the processor themselves. The GDPR does not establish a substitutive liability of the representative in place of the controller or processor it represents in the  Union.
# It should however be noted that the concept of the representative was introduced precisely with the  aim of facilitating the liaison with and ensuring effective enforcement of the GDPR against controllers  or processors that fall under Article 3(2) of the GDPR. To this end, it was the intention to enable  supervisory authorities to initiate enforcement proceedings through the representative designated by  the controllers or processors not established in the Union. This includes the possibility for supervisory  authorities to address corrective measures or administrative fines and penalties imposed on the  controller or processor not established in the Union to the representative, in accordance with articles  58(2) and 83 of the GDPR. The possibility to hold a representative directly liable is however limited to  its direct obligations referred to in articles 30 and article 58(1) a of the GDPR
# The EDPB furthermore highlights that article 50 of the GDPR notably aims at facilitating the  enforcement of legislation in relation to third countries and international organisation, and that the  development of further international cooperation mechanisms in this regard is currently being  considered.
# ##############
# # index: 16, section_reference: 4.d
#
# df_summary.loc[index, "text"] = "The representative in the Union acts on behalf of you regarding your obligations under GDPR, particularly those related to the exercise of individual rights. The representative's contact details must be provided to individuals according to Articles 13 and 14. While not responsible for complying with individual rights, the representative must facilitate communication between individuals and you.
#
# The representative must maintain a record of processing activities, though you are responsible for the primary content and updates of this record. The representative must ensure the record is available when requested by a supervisory authority.
#
# The representative should perform tasks according to the mandate received from you, including cooperating with supervisory authorities. Supervisory authorities would contact the representative for any compliance matters, and the representative should facilitate communication between them and you.
#
# The representative in the Union must efficiently communicate with individuals and cooperate with supervisory authorities, using appropriate languages or other methods to ensure effective communication. The representative's availability is essential for easy contact with the non-EU controller or processor.
#
# The representative does not assume your responsibility and liability under GDPR. Supervisory authorities can initiate enforcement proceedings through the representative and address corrective measures or penalties to the representative, but direct liability is limited to specific obligations in Articles 30 and 58(1)(a).
#
# Article 50 aims to facilitate legislation enforcement related to third countries and international organisations, with further international cooperation mechanisms being considered."
#
# df_questions.loc[index, "text"] = "Who does the representative in the Union act on behalf of?|How does the representative support individuals' rights?|What must the representative provide to individuals under Articles 13 and 14?|What record must the representative maintain under Article 30?|Who is responsible for the primary content and updates of the record?|What is the representative's responsibility when addressed by a supervisory authority?|How should the representative handle communication with data subjects and supervisory authorities?|Does the designation of a representative affect the responsibility and liability of the controller or processor?|Why was the concept of the representative introduced?|Can supervisory authorities address corrective measures or administrative fines to the representative?|Is the representative directly liable under GDPR?"

# %%
model_summary
# Out:
# "The representative in the Union acts on behalf of you regarding your obligations under GDPR, particularly those related to the exercise of individual rights. The representative's contact details must be provided to individuals according to Articles 13 and 14. While not responsible for complying with individual rights, the representative must facilitate communication between individuals and you.\n\nThe representative must maintain a record of processing activities, though you are responsible for the primary content and updates of this record. The representative must ensure the record is available when requested by a supervisory authority.\n\nThe representative should perform tasks according to the mandate received from you, including cooperating with supervisory authorities. Supervisory authorities would contact the representative for any compliance matters, and the representative should facilitate communication between them and you.\n\nThe representative in the Union must efficiently communicate with individuals and cooperate with supervisory authorities, using appropriate languages or other methods to ensure effective communication. The representative's availability is essential for easy contact with the non-EU controller or processor.\n\nThe representative does not assume your responsibility and liability under GDPR. Supervisory authorities can initiate enforcement proceedings through the representative and address corrective measures or penalties to the representative, but direct liability is limited to specific obligations in Articles 30 and 58(1)(a).\n\nArticle 50 aims to facilitate legislation enforcement related to third countries and international organisations, with further international cooperation mechanisms being considered."

# %%
# index: 16, section_reference: 4.d

df_summary.loc[index, "text"] = "The representative in the Union acts on behalf of you regarding your obligations under GDPR, particularly those related to the exercise of individual rights. The representative's contact details must be provided to individuals according to Articles 13 and 14. While not responsible for complying with individual rights, the representative must facilitate communication between individuals and you.\n\nThe representative must maintain a record of processing activities, though you are responsible for the primary content and updates of this record. The representative must ensure the record is available when requested by a supervisory authority.\n\nThe representative should perform tasks according to the mandate received from you, including cooperating with supervisory authorities. Supervisory authorities would contact the representative for any compliance matters, and the representative should facilitate communication between them and you.\n\nThe representative in the Union must efficiently communicate with individuals and cooperate with supervisory authorities, using appropriate languages or other methods to ensure effective communication. The representative's availability is essential for easy contact with the non-EU controller or processor.\n\nThe representative does not assume your responsibility and liability under GDPR. Supervisory authorities can initiate enforcement proceedings through the representative and address corrective measures or penalties to the representative, but direct liability is limited to specific obligations in Articles 30 and 58(1)(a).\n\nArticle 50 aims to facilitate legislation enforcement related to third countries and international organisations, with further international cooperation mechanisms being considered."

df_questions.loc[index, "text"] = "Who does the representative in the Union act on behalf of?|How does the representative support individuals' rights?|What must the representative provide to individuals?|What record must the representative maintain?|Who is responsible for the primary content and updates of the record?|What is the representative's responsibility when addressed by a supervisory authority?|How should the representative handle communication with data subjects and supervisory authorities?"



index = index + 1
print(f"You have completed {(index / len(df_summary) * 100):.2f}% of the work")
if index < len(df_summary):
    print(f"The next section is:\n{doc.get_text(df_summary.iloc[index]['section_reference'])}")
else:
    print("All done")
# Out:
# You have completed 100.00% of the work
# All done

# %%
df_summary
# Out:
#    section_reference                                               text  \
# 0                  1  The GDPR applies to the processing of personal...
# 1                1.a  To determine if an entity has an establishment...
# 2                1.b  Processing personal data in the context of any...
# 3                1.c  The GDPR applies to the processing of personal...
# 4                1.d  When processing activities fall under the scop...
# 5                  2  If you are not established in the EU, the GDPR...
# 6                2.a  The GDPR applies to personal data of individua...
# 7                2.b  To determine if offering goods or services tri...
# 8                2.c  When an individual's behaviour within the EU i...
# 9                2.d  If you target individuals in the EU, the GDPR ...
# 10               2.e  Entities not established in the EU must comply...
# 11                 3  The GDPR applies to the processing of personal...
# 12                 4  If you are not established in the Union but su...
# 13               4.a  Designate a representative in the EU through a...
# 14               4.b  You may be exempt from the obligation to desig...
# 15               4.c  If you are not established in the EU but proce...
# 16               4.d  The representative in the Union acts on behalf...
#
#      source embedding          document
# 0   summary       NaN  TerritorialScope
# 1   summary       NaN  TerritorialScope
# 2   summary       NaN  TerritorialScope
# 3   summary       NaN  TerritorialScope
# 4   summary       NaN  TerritorialScope
# 5   summary       NaN  TerritorialScope
# 6   summary       NaN  TerritorialScope
# 7   summary       NaN  TerritorialScope
# 8   summary       NaN  TerritorialScope
# 9   summary       NaN  TerritorialScope
# 10  summary       NaN  TerritorialScope
# 11  summary       NaN  TerritorialScope
# 12  summary       NaN  TerritorialScope
# 13  summary       NaN  TerritorialScope
# 14  summary       NaN  TerritorialScope
# 15  summary       NaN  TerritorialScope
# 16  summary       NaN  TerritorialScope

# %%
df_summary.to_csv(summary_file, sep = "|", encoding = "utf-8", index = False, na_rep="")

df_questions.to_csv(question_file, sep = "|", encoding = "utf-8", index = False, na_rep="")

# %%
import pandas as pd
df_summary = pd.read_csv(summary_file, sep = "|", encoding = "utf-8")

df_questions = pd.read_csv(question_file, sep = "|", encoding = "utf-8")

# %%
df_questions = df_questions.drop("text", axis=1).join(df_questions["text"].str.split("|", expand=True).stack().reset_index(level=1, drop=True).rename("text"))
df_questions = df_questions[df_questions["text"] != ""]
df_questions.reset_index(drop=True, inplace=True)

# %%
df_index = pd.concat([df_summary, df_questions], ignore_index = True)
df_index
# Out:
#    section_reference                                               text  \
# 0                  1  The GDPR applies to the processing of personal...
# 1                1.a  To determine if an entity has an establishment...
# 2                1.b  Processing personal data in the context of any...
# 3                1.c  The GDPR applies to the processing of personal...
# 4                1.d  When processing activities fall under the scop...
# ..               ...                                                ...
# 79               4.d  What must the representative provide to indivi...
# 80               4.d      What record must the representative maintain?
# 81               4.d  Who is responsible for the primary content and...
# 82               4.d  What is the representative's responsibility wh...
# 83               4.d  How should the representative handle communica...
#
#       source  embedding          document
# 0    summary        NaN  TerritorialScope
# 1    summary        NaN  TerritorialScope
# 2    summary        NaN  TerritorialScope
# 3    summary        NaN  TerritorialScope
# 4    summary        NaN  TerritorialScope
# ..       ...        ...               ...
# 79  question        NaN  TerritorialScope
# 80  question        NaN  TerritorialScope
# 81  question        NaN  TerritorialScope
# 82  question        NaN  TerritorialScope
# 83  question        NaN  TerritorialScope
#
# [84 rows x 5 columns]

# %%
from regulations_rag.embeddings import get_ada_embedding
model = "text-embedding-3-large"
dimensions = 1024

#df_index = df_questions
df_index['embedding'] = pd.NA  # Initialize the column to hold NA values
df_index['embedding'] = df_index['embedding'].astype(object)  # Ensure the column type is object
increment = 10
for i in range(0, len(df_index), increment):
    chunk = df_index.iloc[i:i+increment].copy()
    chunk["embedding"] = chunk["text"].apply(lambda x: get_ada_embedding(openai_client, x, model, dimensions))
    df_index.loc[chunk.index, "embedding"] = chunk["embedding"]
    print(f"Completed {i+increment} lines")
# Out:
# Completed 10 lines
# Completed 20 lines
# Completed 30 lines
# Completed 40 lines
# Completed 50 lines
# Completed 60 lines
# Completed 70 lines
# Completed 80 lines
# Completed 90 lines

# %%
df_index.to_parquet(index_file, engine = "pyarrow")
save_parquet_data(df_index, index_file, key)

# %%
df_index
#df_index["document"] = "Article_47_BCR"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_index
#       2 #df_index["document"] = "Article_47_BCR"
#
# NameError: name 'df_index' is not defined

# %%
gdpr_index = load_parquet_data("../inputs/index/gdpr.parquet", key)
scope_index = load_parquet_data("../inputs/index/territorial_scope.parquet", key)

for index, row in gdpr_index[gdpr_index['section_reference'].str.startswith('3')].iterrows():
    print(f"-- {row['text']}")


# for index, row in index_df[index_df["section_reference"] == '30'].iterrows():
#     print(f"* {row['text']}")
# Out:
# -- When does GDPR apply to non-EU entities?
# -- I am not based in the EU. Does GDPR apply to me?
# -- What records must you keep about your data processing activities?
# -- What details do records of data processing need to include?
# -- Are there any specific requirements for the records of data processing to be kept by a data processor?
# -- In what form should records of data processing be maintained?
# -- Who might request access to records of data processing, and what is your responsibility?
# -- What is required from you in terms of cooperation with the supervisory authority?
# -- What measures should you implement to ensure the security of processing personal data?
# -- How do you determine the appropriate level of security needed for personal data?
# -- Can following a code of conduct or obtaining a certification help demonstrate compliance with data security requirements?
# -- What steps should you take to ensure that individuals processing personal data under your authority only do so based on your instructions?
# -- What action should you take if a personal data breach occurs?
# -- How soon must you notify the appropriate authority when a data breach is discovered?
# -- Is there any situation where you might not need to notify a supervisory authority about a data breach?
# -- What information must you include when reporting a data breach?
# -- What should be done if all details about a breach can't be reported immediately?
# -- Why is it important to document all personal data breaches and the response to them?
# -- When should you inform individuals about a personal data breach?
# -- What information should be included when notifying an individual about a personal data breach?
# -- Under what conditions can you avoid informing individuals about a personal data breach?
# -- What happens if you don't voluntarily notify individuals about a personal data breach?
# -- When must you conduct a data protection impact assessment (DPIA)?
# -- Who should you consult when carrying out a data protection impact assessment (DPIA)?
# -- What triggers the requirement for a data protection impact assessment (DPIA)?
# -- How do supervisory authorities contribute to the data protection impact assessment (DPIA) process?
# -- What content is required in a data protection impact assessment (DPIA)?
# -- Should individuals' views be considered in the assessment process?
# -- What happens when processing activities are already regulated by Union or Member State law?
# -- How often should you review the data protection impact assessment (DPIA)?
# -- When should you consult the supervisory authority before processing data?
# -- What happens if the supervisory authority thinks your processing infringes GDPR?
# -- How long does the supervisory authority have to provide advice after a consultation request?
# -- What information must you provide to the supervisory authority when consulting them?
# -- Are there circumstances where national law overrides the GDPR consultation requirements?
# -- When must you designate a data protection officer?
# -- Can multiple organisations share a data protection officer?
# -- What criteria must a data protection officer meet?
# -- Can a data protection officer be employed directly or work under a service contract?
# -- How should the contact details of the data protection officer be shared?
# -- What types of processing activities require you to appoint a data protection officer?
# -- Is it mandatory for public authorities or bodies to have a data protection officer?
# -- How does the scale of data processing affect the requirement to appoint a data protection officer?
# -- What kind of support should you provide to your data protection officer?
# -- Who does the data protection officer report to?
# -- Can individuals contact the data protection officer directly?
# -- Is the data protection officer required to keep information confidential?
# -- Can the data protection officer have other roles in the organisation?
# -- What responsibilities does the data protection officer have?
# -- How does the data protection officer help you comply with GDPR and other data protection laws?
# -- What role does the data protection officer play in staff training and audits?
# -- What is the data protection officer's involvement in data protection impact assessment (DPIA)s?
# -- How does the data protection officer interact with the supervisory authority?
# -- In performing their duties, how does the data protection officer assess risk?
# -- The Regulation applies to the processing of personal data by entities within the Union, regardless of where the processing occurs. It also applies to entities outside the Union processing personal data of individuals in the Union if related to offering goods/services in the Union or monitoring their behaviour within it. Additionally, it covers processing by entities not based in the Union but in places where Member State law applies due to public international law.
# -- You must maintain a record of all processing activities for which you are responsible. This record must include:
# - Your name and contact details, and if relevant, those of any joint controllers, your representative, and your data protection officer.
# - The purposes for processing the data.
# - Descriptions of the individuals and types of personal data you are processing.
# - Categories of recipients to whom the data has been or will be disclosed, including any in third countries or international organisations.
# - If relevant, any transfers of personal data to third countries or international organisations, the identification of these, and documentation of suitable safeguards.
# - Where possible, the planned time limits for erasing the different types of data.
# - Where possible, a description of the technical and organisational security measures you have in place.
# Processors acting on your behalf must keep similar records for the activities they carry out, including their and your contact details, the processing they perform for you, any data transfers to third countries or international organisations and their security measures.
# These records must be in written form, which can include electronic formats, and you must make them available to the supervisory authority upon request.
# If your organisation employs fewer than 250 persons, you are exempt from these requirements unless your data processing is likely to risk individuals' rights and freedoms, is not occasional, or involves special categories of data or criminal conviction and offence data.
# -- You, the processor, and any representatives must cooperate with the supervisory authority when asked to help it do its job.
# -- You must implement technical and organisational measures to ensure data security, considering factors like the current technology, implementation costs, processing nature, scope, context, purposes, and risk to individuals' rights and freedoms. Measures may include data pseudonymisation and encryption, ensuring processing systems' confidentiality, integrity, availability, and resilience, restoring data access after incidents, and regularly testing the measures' effectiveness. The security level should reflect processing risks, especially concerning data loss, destruction, alteration, unauthorised access or disclosure. Demonstrating compliance can involve adhering to approved codes of conduct or certification mechanisms. Also, ensure that anyone under your or your processor's authority only processes personal data on your instructions unless the law requires otherwise.
# -- If there is a personal data breach, you must notify the supervisory authority promptly and, if possible, within 72 hours of becoming aware of it, unless the breach is unlikely to pose a risk to individuals' rights and freedoms. If notification exceeds 72 hours, explain the reasons for the delay. Processors must inform you immediately upon detecting a breach. The notification must detail the breach's nature, including the categories and approximate numbers of individuals and records affected, provide contact information of your data protection officer or another contact point, outline the likely consequences, and describe the actions you have taken or propose to take to address the breach and any measures to lessen its effects. If all information cannot be provided at once, it should be delivered in phases without unnecessary delay. Document all breaches, including their facts, effects, and remedial actions taken to allow the supervisory authority to check your compliance with this article.
# -- When a personal data breach might significantly affect individuals' rights and freedoms, you must notify those affected without unnecessary delay. The notification must be straightforward and contain specifics on the breach's nature. However, you don't need to notify individuals if:
# 1. You've applied adequate security measures that make the affected personal data inaccessible or unreadable to unauthorised persons, such as encryption.
# 2. You've taken steps after the breach to ensure that the high risk to individuals' rights and freedoms is no longer likely.
# 3. Informing each individual would require an unreasonably high effort, in which case a public announcement or similar broad-reaching communication must be made.
# If you haven't informed the affected individuals, the supervisory authority will assess the risk level of the breach. It can either require you to notify the individuals or agree that one of the above exceptions applies.
# -- Before starting any processing activities that use new technologies and are likely to pose a high risk to individuals' rights and freedoms, you must conduct a data protection impact assessment (DPIA). This is particularly mandatory for:
# - Automated processing including profiling that significantly affects individuals.
# - Large-scale processing of special categories of data or data concerning criminal convictions.
# - Systematic monitoring of a publicly accessible area on a large scale.
# You should consult your data protection officer when conducting this assessment. The assessment must include a systematic description of the processing operations and their purposes, an evaluation of necessity and proportionality, a risk assessment to individuals’ rights and freedoms, and the measures to address these risks including safeguards and compliance mechanisms.
# You should also consider any relevant approved codes of conduct to evaluate the impact of your processing operations. Where appropriate, take into account the views of the affected individuals or their representatives on the intended processing, ensuring this does not harm commercial or public interests or the security of processing operations.
# If the processing has a legal basis in Union or Member State law, and a data protection impact assessment has already been part of a general impact assessment under that law, you may not need to conduct another assessment unless considered necessary by the Member State.
# Whenever there’s a change in the risk posed by the processing operations, reassess the processing to ensure alignment with the initial data protection impact assessment.
# -- You must consult the supervisory authority before processing if a data protection impact assessment (DPIA) shows that the processing could result in a high risk without measures to mitigate it. If the supervisory authority believes the planned processing would breach the regulation, especially if risks are not properly identified or mitigated, they must provide written advice within up to eight weeks, extendable by six weeks for complex cases. They'll inform you of any extension and reasons within one month. During consultation, you must give the supervisory authority information about processing responsibilities, purposes, means, measures to protect individuals' rights, contact details of the data protection officer, the impact assessment, and any other requested information. Member States must consult the supervisory authority when preparing legislative or regulatory measures related to processing. Additionally, Member State laws may require you to get prior authorisation from the supervisory authority for processing related to public interest tasks, including social protection and public health.
# -- You must appoint a data protection officer (DPO) if you're a public authority or body (excluding courts acting in their judicial capacity), if your core activities require regular and systematic monitoring of individuals on a large scale, or if you process special categories of data or personal data relating to criminal convictions and offences on a large scale. A group of undertakings can appoint a single DPO as long as they are easily accessible from each establishment. Public authorities or bodies can also designate a single DPO across multiple authorities or bodies, considering their organisation and size. Even if not required by the criteria, you or associations representing you may appoint a DPO; this appointment can be mandatory as specified by Union or Member State law. The DPO must be chosen for their expert knowledge of data protection law and practices. They can be an employee or work under a service contract. You must publish and communicate the DPO's contact details to the supervisory authority.
# -- You must involve your data protection officer (DPO) promptly in all matters related to personal data protection. Support your DPO by providing necessary resources for their tasks, including access to personal data and processing operations, and help maintain their knowledge. Ensure your DPO can carry out their duties without interference, and they cannot be dismissed or penalised for performing their tasks. They must report directly to your highest management level. Individuals can contact the DPO about any issues related to their personal data processing or their rights. Your DPO must keep information confidential, as required by law. The DPO can have other responsibilities, provided they don't lead to a conflict of interest.
# -- Your data protection officer (DPO) must perform the following tasks:
# - Inform and advise you, your processors, and relevant employees about their obligations under GDPR and other relevant data protection laws.
# - Monitor compliance with GDPR, other data protection laws, and your data protection policies. This includes assigning responsibilities, training staff involved in processing personal data, and conducting audits.
# - Provide advice regarding data protection impact assessments (DPIAs) and oversee their implementation.
# - Cooperate with the data protection authority.
# - Serve as the point of contact for the data protection authority for processing-related issues, including prior consultations, and consult on any other relevant matters.
# The DPO must consider the risk associated with processing activities, taking into account the types of personal data handled, processing scope, context, and purposes.

# %%
online_index['section_reference'] = online_index['section_reference'].astype(str)
online_index
save_parquet_data(online_index, index_file, key)

# %%
file = "../inputs/index/article_47_bcr.parquet"
#df_index.to_parquet(file, engine = "pyarrow")
save_parquet_data(index_df, file, key)

# %%
from src.index_tools import update_text_in_index, add_to_index

index_df = article_47_index
#index_df = gdpr_index

text_to_change = "What points need to be addressed in the Binding Corporate Rules for Controllers (BCR-C)"
changed_text = "What points need to be addressed in the Binding Corporate Rules for controllers?"
embedding_model = model
embedding_dimensions = dimensions

index_df = update_text_in_index(openai_client = openai_client, index_df = index_df, text_to_change = text_to_change, changed_text = changed_text, embedding_model = embedding_model, embedding_dimensions = embedding_dimensions)
# Out:
#    section_reference                                               text  \
# 0                1.1  You can use binding corporate rules (BCRs) for...
# 1                1.5  Binding Corporate Rules for controllers (BCR-C...
# 2                1.6  You must comply with EU data protection legisl...
# 3                1.7  You must use Binding Corporate Rules (BCR) as ...
# 4                1.8  Binding Corporate Rules (BCRs) need approval f...
# ..               ...                                                ...
# 82               3.6  What agreements must be made regarding the han...
# 83               3.7  What expectations are set for members of Bindi...
# 84               3.8  What obligations are there to keep Binding Cor...
# 85               3.9  What definitions must be included in the Bindi...
# 86          Analysis  What points need to be addressed in the Bindin...
#
#       source                                          embedding  \
# 0    summary  [-0.009783994406461716, -0.06066862493753433, ...
# 1    summary  [-0.017316676676273346, -0.021807707846164703,...
# 2    summary  [-0.07271231710910797, -0.06814079731702805, -...
# 3    summary  [-0.017403494566679, -0.08751912415027618, -0....
# 4    summary  [-0.004610632546246052, -0.043068330734968185,...
# ..       ...                                                ...
# 82  question  [-0.04174955189228058, -0.0986546203494072, -0...
# 83  question  [-0.04039411619305611, -0.08921048790216446, -...
# 84  question  [-0.04588606581091881, -0.06260394304990768, -...
# 85  question  [-0.010924087837338448, -0.03873256593942642, ...
# 86  question  [-0.0038541764952242374, -0.05298667028546333,...
#
#           document
# 0   Article_47_BCR
# 1   Article_47_BCR
# 2   Article_47_BCR
# 3   Article_47_BCR
# 4   Article_47_BCR
# ..             ...
# 82  Article_47_BCR
# 83  Article_47_BCR
# 84  Article_47_BCR
# 85  Article_47_BCR
# 86  Article_47_BCR
#
# [87 rows x 5 columns]

# %%
import importlib
import src.index_tools
importlib.reload(src.index_tools)
from src.index_tools import add_to_index

index_df = article_47_index
text = "What happens if local laws conflict with the standards of binding corporate rules?"
section_reference = "3.5.4.1"
source = "question"
document = "Article_47_BCR"

index_df = add_to_index(openai_client, index_df, text, section_reference, source, document, embedding_model, embedding_dimensions)

# %%
from src.index_tools import remove_from_index

text_to_delete = "What happens if local laws conflict with the standards of binding corporate rules?"
article_47_index = remove_from_index(article_47_index, text_to_delete)

# %%
article_47_index = index_df
article_47_index[article_47_index["section_reference"] == "3.5.4.1"]
# Out:
#    section_reference                                               text  \
# 25           3.5.4.1  You must ensure that the Binding Corporate Rul...
# 79           3.5.4.1  What should the Binding Corporate Rules-Contro...
# 87           3.5.4.1  What happens if local laws conflict with the s...
#
#       source                                          embedding  \
# 25   summary  [-0.018655141815543175, -0.05344023182988167, ...
# 79  question  [-0.014255059882998466, -0.07780193537473679, ...
# 87  question  [-0.02774774841964245, -0.06760360300540924, -...
#
#           document
# 25  Article_47_BCR
# 79  Article_47_BCR
# 87  Article_47_BCR

# %%
save_parquet_data(index_df, "../inputs/index/gdpr.parquet", key)

# %%
index_df[index_df['document'] == "article_30_5"]
# Out:
#                                                   text  \
# 147  Under what conditions could you be exempt from...
#
#                                              embedding    source  \
# 147  [-0.03439036011695862, -0.0008122794097289443,...  question
#
#     section_reference      document
# 147               all  article_30_5

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')

path_to_file = "../inputs/index/article_30_5.parquet"
index = load_parquet_data(path_to_file, key)

# %%
#index["document"] = "Article_30_5"
index
# Out:
#   section_reference  ...      document
# 0               all  ...  Article_30_5
# 1               all  ...  Article_30_5
# 2               all  ...  Article_30_5
# 3               all  ...  Article_30_5
# 4               all  ...  Article_30_5
# 5               all  ...  Article_30_5
# 6               all  ...  Article_30_5
# 7               all  ...  Article_30_5
#
# [8 rows x 5 columns]

# %%
save_parquet_data(index, path_to_file, key)
