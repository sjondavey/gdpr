# %%
import logging
log_level = 25
logging.basicConfig(level=log_level) # root logger

# %%
class_name = "Codes"
summary_file = "../tmp/codes_summary.csv"
question_file = "../tmp/codes_question.csv"

path_to_manual_as_csv_file = "../inputs/documents/codes.parquet"
index_file = "../inputs/index/codes.parquet"

# %%
import re
import pandas as pd

import sys
sys.path.append('E:/Code/chat/gdpr')

import importlib
import gdpr_rag.documents.codes
importlib.reload(gdpr_rag.documents.codes)
from gdpr_rag.documents.codes import Codes

path_to_manual_as_csv_file = "../inputs/documents/codes.parquet"

doc = Codes(path_to_manual_as_csv_file)

# %%
from regulations_rag.regulation_table_of_content import StandardTableOfContent
reference_checker = doc.reference_checker
df = pd.read_parquet(path_to_manual_as_csv_file, engine='pyarrow')
toc = StandardTableOfContent(root_node_name = "transparency", reference_checker = reference_checker, regulation_df = df)

# %%
toc.print_tree()
# Out:
# transparency []
# |-- 1 [INTRODUCTION  ]
# |   +-- .1 [Scope of these guidelines]
# |-- 2 [DEFINITIONS]
# |-- 3 [WHAT ARE CODES ?]
# |-- 4 [WHAT ARE THE BENEFITS OF CODES?]
# |-- 5 [ADMISSIBILITY OF A DRAFT CODE[^29]
# [^29] This also applies for all codes (national and transnational) as well as amended or extended codes.]
# |   |-- .1 [Explanatory statement and supporting documentation]
# |   |-- .2 [Representative]
# |   |-- .3 [Processing Scope ]
# |   |-- .4 [Territorial scope]
# |   |-- .5 [Submission to a CompSA]
# |   |-- .6 [Oversight of mechanisms]
# |   |-- .7 [Monitoring body]
# |   |-- .8 [Consultation]
# |   |-- .9 [National legislation]
# |   |-- .10 [Language]
# |   +-- .11 [Checklist]
# |-- 6 [CRITERIA FOR APPROVING CODES]
# |   |-- .1 [Meets a particular need]
# |   |-- .2 [Facilitates the effective application of the GDPR]
# |   |-- .3 [Specifies the application of the GDPR]
# |   |-- .4 [Provides sufficient safeguards]
# |   +-- .5 [Provides mechanisms which will allow for effective oversight ]
# |-- 7 [SUBMISSION, ADMISSIBILITY AND APPROVAL[^53] (NATIONAL CODE)
# [^53] Including amending and extending codes previously approved.]
# |   |-- .1 [Submission]
# |   |-- .2 [Admissibility of a Code]
# |   +-- .3 [Approval]
# |-- 8 [SUBMISSION, ADMISSIBILITY AND APPROVAL[^60] (TRANSNATIONAL CODE)
# [^60] Including amending and extending codes previously approved.]
# |   |-- .1 [Submission]
# |   |-- .2 [Admissibility of a Code]
# |   |-- .3 [Cooperation]
# |   |-- .4 [Refusal]
# |   |-- .5 [Preparation for submission to the Board]
# |   |-- .6 [The Board]
# |   +-- .7 [Approval]
# |-- 9 [ENGAGEMENT]
# |-- 10 [THE ROLE OF THE COMMISSION]
# |-- 11 [MONITORING OF A CODE]
# |-- 12 [ACCREDITATION REQUIREMENTS FOR MONITORING BODIES]
# |   |-- .1 [Independence]
# |   |-- .2 [Conflict of interest[^75]
# [^75] Impartiality of function, i.e. the ability to act autonomously.]
# |   |-- .3 [Expertise]
# |   |-- .4 [Established procedures and structures]
# |   |-- .5 [Transparent complaints handling]
# |   |-- .6 [Communication with the competent supervisory authority]
# |   |-- .7 [Review Mechanisms]
# |   +-- .8 [Legal status]
# |-- 13 [APPROVED CODES]
# |-- 14 [REVOCATION OF A MONITORING BODY]
# |-- 15 [PUBLIC SECTOR CODES]
# |-- APPENDIX 1 [DISTINCTION BETWEEN NATIONAL AND TRANSNATIONAL CODES]
# |-- APPENDIX 2 [CHOOSING A COMPSA  ]
# |-- APPENDIX 3 [CHECKLIST FOR SUBMISSION  ]
# +-- APPENDIX 4 [TRANSNATIONAL CODE FLOW CHART]

# %%
sys.path.append('E:/Code/chat/gdpr')

from anytree import Node, PreOrderIter
from regulations_rag.embeddings import num_tokens_from_string

all_nodes = list(PreOrderIter(toc.root))
all_node_names = [node.full_node_name for node in all_nodes if node.full_node_name != ""]
split_df = pd.DataFrame(all_node_names, columns = ["section_reference"])
for index, row in split_df.iterrows():
    text = doc.get_text(row['section_reference'])
    split_df.at[index, 'text'] = text
    split_df.at[index, 'token_count'] = num_tokens_from_string(text)
split_df["token_count"] = split_df["token_count"].astype(int)

split_df = split_df[split_df["token_count"] > 31] 
split_df = split_df.drop([0, 1, 2]) # Introduction
split_df.reset_index(drop=True, inplace=True)
split_df
# Out:
#    section_reference                                               text  \
# 0                  3  3 WHAT ARE CODES ?\n7. GDPR codes are voluntar...
# 1                  4  4 WHAT ARE THE BENEFITS OF CODES?\n11. Codes r...
# 2                  5  5 ADMISSIBILITY OF A DRAFT CODE[^29]\n19. Ther...
# 3                5.1  5 ADMISSIBILITY OF A DRAFT CODE[^29]\n\n5.1 Ex...
# 4                5.2  5 ADMISSIBILITY OF A DRAFT CODE[^29]\n\n5.2 Re...
# 5                5.3  5 ADMISSIBILITY OF A DRAFT CODE[^29]\n\n5.3 Pr...
# 6                5.4  5 ADMISSIBILITY OF A DRAFT CODE[^29]\n\n5.4 Te...
# 7                5.5  5 ADMISSIBILITY OF A DRAFT CODE[^29]\n\n5.5 Su...
# 8                5.6  5 ADMISSIBILITY OF A DRAFT CODE[^29]\n\n5.6 Ov...
# 9                5.7  5 ADMISSIBILITY OF A DRAFT CODE[^29]\n\n5.7 Mo...
# 10               5.8  5 ADMISSIBILITY OF A DRAFT CODE[^29]\n\n5.8 Co...
# 11               5.9  5 ADMISSIBILITY OF A DRAFT CODE[^29]\n\n5.9 Na...
# 12              5.10  5 ADMISSIBILITY OF A DRAFT CODE[^29]\n\n5.10 L...
# 13              5.11  5 ADMISSIBILITY OF A DRAFT CODE[^29]\n\n5.11 C...
# 14                 6  6 CRITERIA FOR APPROVING CODES\n32. Code owner...
# 15               6.1  6 CRITERIA FOR APPROVING CODES\n\n6.1 Meets a ...
# 16               6.2  6 CRITERIA FOR APPROVING CODES\n\n6.2 Facilita...
# 17               6.3  6 CRITERIA FOR APPROVING CODES\n\n6.3 Specifie...
# 18               6.4  6 CRITERIA FOR APPROVING CODES\n\n6.4 Provides...
# 19               6.5  6 CRITERIA FOR APPROVING CODES\n\n6.5 Provides...
# 20               7.1  7 SUBMISSION, ADMISSIBILITY AND APPROVAL[^53] ...
# 21               7.2  7 SUBMISSION, ADMISSIBILITY AND APPROVAL[^53] ...
# 22               7.3  7 SUBMISSION, ADMISSIBILITY AND APPROVAL[^53] ...
# 23               8.1  8 SUBMISSION, ADMISSIBILITY AND APPROVAL[^60] ...
# 24               8.2  8 SUBMISSION, ADMISSIBILITY AND APPROVAL[^60] ...
# 25               8.3  8 SUBMISSION, ADMISSIBILITY AND APPROVAL[^60] ...
# 26               8.4  8 SUBMISSION, ADMISSIBILITY AND APPROVAL[^60] ...
# 27               8.5  8 SUBMISSION, ADMISSIBILITY AND APPROVAL[^60] ...
# 28               8.6  8 SUBMISSION, ADMISSIBILITY AND APPROVAL[^60] ...
# 29               8.7  8 SUBMISSION, ADMISSIBILITY AND APPROVAL[^60] ...
# 30                 9  9 ENGAGEMENT\n58. It is important to note that...
# 31                10  10 THE ROLE OF THE COMMISSION\n59. The Commiss...
# 32                11  11 MONITORING OF A CODE\n60. In order for a co...
# 33              12.1  12 ACCREDITATION REQUIREMENTS FOR MONITORING B...
# 34              12.2  12 ACCREDITATION REQUIREMENTS FOR MONITORING B...
# 35              12.3  12 ACCREDITATION REQUIREMENTS FOR MONITORING B...
# 36              12.4  12 ACCREDITATION REQUIREMENTS FOR MONITORING B...
# 37              12.5  12 ACCREDITATION REQUIREMENTS FOR MONITORING B...
# 38              12.6  12 ACCREDITATION REQUIREMENTS FOR MONITORING B...
# 39              12.7  12 ACCREDITATION REQUIREMENTS FOR MONITORING B...
# 40              12.8  12 ACCREDITATION REQUIREMENTS FOR MONITORING B...
# 41                13  13 APPROVED CODES\n82. Clearly the nature and ...
# 42                14  14 REVOCATION OF A MONITORING BODY\n85. When a...
# 43                15  15 PUBLIC SECTOR CODES\n88. Article 41(6) of t...
# 44        APPENDIX 1  APPENDIX 1 DISTINCTION BETWEEN NATIONAL AND TR...
# 45        APPENDIX 2  APPENDIX 2 CHOOSING A COMPSA  \nCode owners ma...
# 46        APPENDIX 3  APPENDIX 3 CHECKLIST FOR SUBMISSION  \nBefore ...
# 47        APPENDIX 4  APPENDIX 4 TRANSNATIONAL CODE FLOW CHART\n```m...
#
#     token_count
# 0           562
# 1          1481
# 2            95
# 3           257
# 4           218
# 5           103
# 6           118
# 7           157
# 8            96
# 9           224
# 10          276
# 11          104
# 12          186
# 13          132
# 14          184
# 15          191
# 16          287
# 17          563
# 18          239
# 19          408
# 20          206
# 21          210
# 22          280
# 23          298
# 24          239
# 25          424
# 26          141
# 27          127
# 28          239
# 29          175
# 30          359
# 31          148
# 32          287
# 33          597
# 34          247
# 35          183
# 36          329
# 37          472
# 38          187
# 39          101
# 40           93
# 41          216
# 42          341
# 43          119
# 44          237
# 45          404
# 46          352
# 47          350

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')
#index_df = load_parquet_data("../inputs/index_gdpr.parquet", key)

# %%
from openai import OpenAI
openai_client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),)

import sys
sys.path.append('E:/Code/chat/gdpr')
import importlib
import src.summarise_and_question
importlib.reload(src.summarise_and_question)
from src.summarise_and_question import get_summary_and_questions_for

# %%
if os.path.exists(summary_file):
    df_summary = pd.read_csv(summary_file, sep="|", encoding = "utf-8")
else:
    df_summary = pd.DataFrame([], columns = ["section_reference", "text", "source", "embedding", "document"])
    df_summary["section_reference"] = split_df["section_reference"]
    # df_summary["text"] = split_df["text"]
    df_summary["source"] = "summary"
    df_summary["document"] = class_name

first_empty_index = df_summary[df_summary['text'].isna()].index.min()

if pd.isna(first_empty_index):
    #print("No empty embeddings found.")
    first_empty_index = 0
index = first_empty_index

if os.path.exists(question_file):
    df_questions = pd.read_csv(question_file, sep="|", encoding = "utf-8")
else:
    df_questions = pd.DataFrame([], columns = ["section_reference", "text", "source", "embedding", "document"])
    df_questions["section_reference"] = split_df["section_reference"]
    # df_questions["text"] = split_df["text"]
    df_questions["source"] = "question"
    df_questions["document"] = class_name

first_empty_index = df_questions[df_questions['text'].isna()].index.min()

if pd.isna(first_empty_index):
    #print("No empty embeddings found.")
    first_empty_index = 0

if index != first_empty_index:
    print("The index in the summary and questions files do not match. This needs to be fixed")
else:
    [print(f"Picking up at index {index}")]
# Out:
# Picking up at index 0

# %%
model = "gpt-4o"

reference = df_summary.iloc[index]["section_reference"]

reg_text = doc.get_text(reference)
print("##############")
print(reg_text)
print("##############")

model_summary, model_questions = get_summary_and_questions_for(openai_client = openai_client, text = reg_text, model = model)

#format output
print(f'# index: {index}, section_reference: {df_summary.iloc[index]["section_reference"]}')
print()
print(f'df_summary.loc[index, "text"] = "{model_summary}"')
print()
print(f'df_questions.loc[index, "text"] = "{model_questions}"')
# Out:
# ##############
# APPENDIX 3 CHECKLIST FOR SUBMISSION
# Before submitting a draft code to the competent supervisory authority it is important that you ensure the following (where relevant) have been submitted/set out and are appropriately signposted within the documentation:
# 1.Have you provided an explanatory statement and all relevant supporting documentation?
# (Paragraph 20)
# 2.Are you an association or other body representing categories of controllers or processors?
# (Paragraph 21)
# 3.Have you provided details in your submission to substantiate that you are an effective
# representative body that is capable of understanding the needs of your members? (Paragraph
# 22)
# 4.Have you clearly defined the processing activity or sector and the processing problems to
# which the code is intended to address? (Paragraph 23)
# 5.Have you identified the territorial scope of your code and included a list of all concerned SAs
# (where relevant)? (Paragraph 24)
# 6.Have you provided details to justify the identification of the CompSA? (Paragraph 25)
# 7.Have you included mechanisms that allow for the effective monitoring of compliance of the
# code? (Paragraph 26)
# 8.Have you identified a monitoring body and explained how it will fulfil the code monitoring
# requirements? (Paragraph 27)
# 9.Have you included information as to the extent of consultation carried out in developing the
# code? (Paragraph 28)
# 10. Have you provided confirmation that the draft code is compliant with Member State law(s)
# (where relevant)? (Paragraph 29)
# 11. Have you met the language requirements? (Paragraph 30)
# Does your submission include sufficient details to demonstrate the proper application of the GDPR?(Paragraphs 32 - 41)
# ##############
# # index: 45, section_reference: APPENDIX 3
#
# df_summary.loc[index, "text"] = "1. Provide an explanatory statement and all relevant supporting documentation.
# 2. Confirm that you are an association or other body representing categories of controllers or processors.
# 3. Include details to substantiate that you are an effective representative body capable of understanding the needs of your members.
# 4. Clearly define the processing activity or sector and the processing problems the code is intended to address.
# 5. Identify the territorial scope of your code and include a list of all concerned Supervisory Authorities.
# 6. Provide details to justify the identification of the Competent Supervisory Authority.
# 7. Include mechanisms for the effective monitoring of compliance with the code.
# 8. Identify a monitoring body and explain how it will fulfil the code monitoring requirements.
# 9. Include information on the extent of consultation carried out in developing the code.
# 10. Confirm that the draft code is compliant with relevant Member State law(s).
# 11. Ensure you meet the language requirements.
# 12. Demonstrate the proper application of the GDPR with sufficient details."
#
# df_questions.loc[index, "text"] = "Have you provided an explanatory statement and all relevant supporting documentation?|Are you an association or body representing categories of data handlers?|Can you substantiate that you effectively represent your members?|Have you defined the processing activity or problems addressed by the code?|Have you identified the territorial scope and listed concerned Supervisory Authorities (SAs)?|Have you justified the identification of the competent Supervisory Authority (CompSA)?|Have you included mechanisms for monitoring code compliance?|Have you identified a monitoring body and detailed its code monitoring methods?|Have you included details of consultations during the code development?|Have you confirmed compliance with relevant Member State laws?|Have you met the language requirements?|Does your submission demonstrate proper application of the General Data Protection Regulation (GDPR)?"

# %%
model_summary
# Out:
# "Factors to consider when choosing a competent supervisory authority (CompSA) for evaluating a transnational draft code:\n\n- Location with the highest density of processing activities or specific sector.\n- Location with the highest density of individuals affected by the processing activities or specific sector.\n- Code owner's headquarters location.\n- Proposed monitoring body's headquarters location.\n- Initiatives by a supervisory authority in a particular field.\n\nChoosing a CompSA should be a well-considered decision, as the CompSA acts as a single point of contact during the approval process, manages the application procedure, accredits the monitoring body (if relevant), and ensures the approved code is effectively monitored."

# %%
# index: 45, section_reference: APPENDIX 4

df_summary.loc[index, "text"] = "Workflow for the submission of a code"

df_questions.loc[index, "text"] = "Is there a workflow for a Code?"





index = index + 1
print(f"You have completed {(index / len(df_summary) * 100):.2f}% of the work")
if index < len(df_summary):
    print(f"The next section is:\n{doc.get_text(df_summary.iloc[index]['section_reference'])}")
else:
    print("All done")
# Out:
# You have completed 100.00% of the work
# All done

# %%
df_summary
# Out:
#    section_reference                                               text  \
# 0                  3  Codes of conduct are voluntary accountability ...
# 1                  4  Codes are an opportunity to establish practica...
# 2                5.1  Every draft code submitted for approval must i...
# 3                5.2  A code must be submitted by an association, co...
# 4                5.3  A draft code must clearly define its scope, sp...
# 5                5.4  The draft code must specify if it is a nationa...
# 6                5.5  Code owners must ensure that the chosen superv...
# 7                5.6  The draft code must propose mechanisms that en...
# 8                5.7  For a draft code involving the processing acti...
# 9                5.8  A draft code must detail the extent of consult...
# 10               5.9  Code owners must confirm that the draft code c...
# 11              5.10  Submit your code to the competent supervisory ...
# 12              5.11  The chosen CompSA determines if the draft code...
# 13                 6  Code owners must show how their code will supp...
# 14               6.1  Code owners must demonstrate a need for establ...
# 15               6.2  A code needs to demonstrate that it facilitate...
# 16               6.3  For you to approve a code, it must practically...
# 17               6.4  A code must provide sufficient safeguards to e...
# 18               6.5  Ensure the implementation of suitable mechanis...
# 19               7.1  Code owners must formally submit their draft C...
# 20               7.2  If the draft Code does not meet the criteria f...
# 21               7.3  The competent supervisory authority (CompSA) s...
# 22               8.1  Code owners must formally submit their draft c...
# 23               8.2  If your draft code is not accepted due to fail...
# 24               8.3  The CompSA notifies all SAs about the position...
# 25               8.4  If the Competent Supervisory Authority (CompSA...
# 26               8.5  If you intend to approve the draft code, circu...
# 27               8.6  If the matter is referred to the Board, the de...
# 28               8.7  The Board's opinion will be communicated to th...
# 29                 9  During the assessment process, avoid further c...
# 30                10  The Commission can decide via an implementing ...
# 31                11  To approve a national or transnational code, a...
# 32              12.1  You must ensure that the body monitoring the c...
# 33              12.2  Ensure that the tasks and duties of the monito...
# 34              12.3  Code owners must show that the monitoring body...
# 35              12.4  A monitoring body must have governance structu...
# 36              12.5  Establish effective, impartial, and transparen...
# 37              12.6  The framework for a proposed monitoring body m...
# 38              12.7  A code must include appropriate review mechani...
# 39              12.8  The monitoring body must be established in a w...
# 40                13  Appropriate codes must ensure compliance with ...
# 41                14  If a monitoring body fails to comply with GDPR...
# 42                15  Public authorities or bodies are exempt from t...
# 43        APPENDIX 1  A transnational code relates to processing act...
# 44        APPENDIX 2  Factors to consider when choosing a competent ...
# 45        APPENDIX 3              Checklist of the submission of a code
# 46        APPENDIX 4              Workflow for the submission of a code
#
#      source  embedding document
# 0   summary        NaN    Codes
# 1   summary        NaN    Codes
# 2   summary        NaN    Codes
# 3   summary        NaN    Codes
# 4   summary        NaN    Codes
# 5   summary        NaN    Codes
# 6   summary        NaN    Codes
# 7   summary        NaN    Codes
# 8   summary        NaN    Codes
# 9   summary        NaN    Codes
# 10  summary        NaN    Codes
# 11  summary        NaN    Codes
# 12  summary        NaN    Codes
# 13  summary        NaN    Codes
# 14  summary        NaN    Codes
# 15  summary        NaN    Codes
# 16  summary        NaN    Codes
# 17  summary        NaN    Codes
# 18  summary        NaN    Codes
# 19  summary        NaN    Codes
# 20  summary        NaN    Codes
# 21  summary        NaN    Codes
# 22  summary        NaN    Codes
# 23  summary        NaN    Codes
# 24  summary        NaN    Codes
# 25  summary        NaN    Codes
# 26  summary        NaN    Codes
# 27  summary        NaN    Codes
# 28  summary        NaN    Codes
# 29  summary        NaN    Codes
# 30  summary        NaN    Codes
# 31  summary        NaN    Codes
# 32  summary        NaN    Codes
# 33  summary        NaN    Codes
# 34  summary        NaN    Codes
# 35  summary        NaN    Codes
# 36  summary        NaN    Codes
# 37  summary        NaN    Codes
# 38  summary        NaN    Codes
# 39  summary        NaN    Codes
# 40  summary        NaN    Codes
# 41  summary        NaN    Codes
# 42  summary        NaN    Codes
# 43  summary        NaN    Codes
# 44  summary        NaN    Codes
# 45  summary        NaN    Codes
# 46  summary        NaN    Codes

# %%
df_summary.to_csv(summary_file, sep = "|", encoding = "utf-8", index = False, na_rep="")

df_questions.to_csv(question_file, sep = "|", encoding = "utf-8", index = False, na_rep="")

# %%
df_summary = df_summary[df_summary["section_reference"] != "K"]
df_questions = df_questions[df_questions["section_reference"] != "K"]

# %%
import pandas as pd
df_summary = pd.read_csv(summary_file, sep = "|", encoding = "utf-8")

df_questions = pd.read_csv(question_file, sep = "|", encoding = "utf-8")

# %%
df_questions = df_questions.drop("text", axis=1).join(df_questions["text"].str.split("|", expand=True).stack().reset_index(level=1, drop=True).rename("text"))
df_questions = df_questions[df_questions["text"] != ""]
df_questions.reset_index(drop=True, inplace=True)

# %%
df_index = pd.concat([df_summary, df_questions], ignore_index = True)
df_index
# Out:
#     section_reference                                               text  \
# 0                   3  Codes of conduct are voluntary accountability ...
# 1                   4  Codes are an opportunity to establish practica...
# 2                 5.1  Every draft code submitted for approval must i...
# 3                 5.2  A code must be submitted by an association, co...
# 4                 5.3  A draft code must clearly define its scope, sp...
# ..                ...                                                ...
# 120        APPENDIX 1   Can a national code become a transnational code?
# 121        APPENDIX 2  How do code owners choose a competent supervis...
# 122        APPENDIX 2  What factors should be considered when selecti...
# 123        APPENDIX 3                   Is there a checklist for a Code?
# 124        APPENDIX 4                    Is there a workflow for a Code?
#
#        source  embedding document
# 0     summary        NaN    Codes
# 1     summary        NaN    Codes
# 2     summary        NaN    Codes
# 3     summary        NaN    Codes
# 4     summary        NaN    Codes
# ..        ...        ...      ...
# 120  question        NaN    Codes
# 121  question        NaN    Codes
# 122  question        NaN    Codes
# 123  question        NaN    Codes
# 124  question        NaN    Codes
#
# [125 rows x 5 columns]

# %%
from regulations_rag.embeddings import get_ada_embedding
model = "text-embedding-3-large"
dimensions = 1024

#df_index = df_questions
df_index['embedding'] = pd.NA  # Initialize the column to hold NA values
df_index['embedding'] = df_index['embedding'].astype(object)  # Ensure the column type is object
increment = 10
for i in range(0, len(df_index), increment):
    chunk = df_index.iloc[i:i+increment].copy()
    chunk["embedding"] = chunk["text"].apply(lambda x: get_ada_embedding(openai_client, x, model, dimensions))
    df_index.loc[chunk.index, "embedding"] = chunk["embedding"]
    print(f"Completed {i+increment} lines")
# Out:
# Completed 10 lines
# Completed 20 lines
# Completed 30 lines
# Completed 40 lines
# Completed 50 lines
# Completed 60 lines
# Completed 70 lines
# Completed 80 lines
# Completed 90 lines
# Completed 100 lines
# Completed 110 lines
# Completed 120 lines
# Completed 130 lines

# %%
df_index.to_parquet(index_file, engine = "pyarrow")
save_parquet_data(df_index, index_file, key)

# %%
df_index
#df_index["document"] = "Article_47_BCR"
# Out:
#     section_reference                                               text  \
# 0                   3  Codes of conduct are voluntary accountability ...
# 1                   4  Codes are an opportunity to establish practica...
# 2                 5.1  Every draft code submitted for approval must i...
# 3                 5.2  A code must be submitted by an association, co...
# 4                 5.3  A draft code must clearly define its scope, sp...
# ..                ...                                                ...
# 120        APPENDIX 1   Can a national code become a transnational code?
# 121        APPENDIX 2  How do code owners choose a competent supervis...
# 122        APPENDIX 2  What factors should be considered when selecti...
# 123        APPENDIX 3                   Is there a checklist for a Code?
# 124        APPENDIX 4                    Is there a workflow for a Code?
#
#        source                                          embedding document
# 0     summary  [0.00377368344925344, -0.02220195345580578, -0...    Codes
# 1     summary  [-0.010806070640683174, 0.0005761659704148769,...    Codes
# 2     summary  [0.021022645756602287, 0.011024325154721737, -...    Codes
# 3     summary  [0.020343054085969925, -0.0009793692734092474,...    Codes
# 4     summary  [0.020648499950766563, 0.032284095883369446, -...    Codes
# ..        ...                                                ...      ...
# 120  question  [-0.027643537148833275, 0.03155497461557388, -...    Codes
# 121  question  [0.036905426532030106, -0.01979360356926918, -...    Codes
# 122  question  [0.02717580460011959, 0.007003546226769686, -0...    Codes
# 123  question  [0.03202644735574722, -0.007595430593937635, -...    Codes
# 124  question  [-0.010784132406115532, -0.016126025468111038,...    Codes
#
# [125 rows x 5 columns]

# %%
gdpr_index = load_parquet_data("../inputs/index/gdpr.parquet", key)
code_index = load_parquet_data("../inputs/index/data_breach.parquet", key)

for index, row in gdpr_index[gdpr_index['section_reference'].str.startswith('40')].iterrows():
    print(f"-- {row['text']}")


# for index, row in index_df[index_df["section_reference"] == '30'].iterrows():
#     print(f"* {row['text']}")
# Out:
# -- Who is encouraged to create codes of conduct for GDPR compliance?
# -- What purposes do codes of conduct serve?
# -- Can codes of conduct address the protection of children's data?
# -- How can codes of conduct assist with personal data breaches?
# -- Can organisations outside the EU adhere to codes of conduct?
# -- What requirements must a code of conduct meet for approval?
# -- Who approves codes of conduct for local purposes?
# -- How are codes of conduct evaluated for processing activities across multiple Member States?
# -- What role does the Commission play in the validity of codes of conduct?
# -- How is the public informed about approved codes of conduct?
# -- Where can one find a register of approved codes of conduct?
# -- You are encouraged to develop or adopt codes of conduct to help apply GDPR effectively, considering your specific processing activities and the needs if you're a micro, small, or medium-sized enterprise. These codes can address various aspects such as fair processing, legitimate interests, data collection, pseudonymisation, informing individuals, their rights, children's data and consent, security measures, breach notifications, data transfers, and dispute resolution.
# If you're outside the EU but handle data transfers from the EU, adhering to an approved code of conduct can help ensure you provide the necessary safeguards, even making binding commitments to apply these safeguards.
# For a code of conduct to be recognized, it must include enforcement mechanisms overseen by an approved monitoring body, without affecting the supervisory authorities' powers.
# If you're drafting a code of conduct or intending to amend or extend one, you must submit it to the relevant supervisory authority for approval, ensuring it complies with the GDPR and provides sufficient safeguards.
# Approved codes that are specific to one Member State will be registered and published by the supervisory authority. If the code covers multiple Member States, it undergoes a review process by the Board and, if found compliant, is forwarded to the Commission for potential Union-wide validity.
# The Commission is responsible for making codes with general validity widely known while the Board compiles and publishes all approved codes.

# %%
file = "../inputs/index/article_47_bcr.parquet"
#df_index.to_parquet(file, engine = "pyarrow")
save_parquet_data(index_df, file, key)

# %%
from src.index_tools import update_text_in_index, add_to_index

index_df = article_47_index
#index_df = gdpr_index

text_to_change = "What points need to be addressed in the Binding Corporate Rules for Controllers (BCR-C)"
changed_text = "What points need to be addressed in the Binding Corporate Rules for controllers?"
embedding_model = model
embedding_dimensions = dimensions

index_df = update_text_in_index(openai_client = openai_client, index_df = index_df, text_to_change = text_to_change, changed_text = changed_text, embedding_model = embedding_model, embedding_dimensions = embedding_dimensions)
# Out:
#    section_reference                                               text  \
# 0                1.1  You can use binding corporate rules (BCRs) for...
# 1                1.5  Binding Corporate Rules for controllers (BCR-C...
# 2                1.6  You must comply with EU data protection legisl...
# 3                1.7  You must use Binding Corporate Rules (BCR) as ...
# 4                1.8  Binding Corporate Rules (BCRs) need approval f...
# ..               ...                                                ...
# 82               3.6  What agreements must be made regarding the han...
# 83               3.7  What expectations are set for members of Bindi...
# 84               3.8  What obligations are there to keep Binding Cor...
# 85               3.9  What definitions must be included in the Bindi...
# 86          Analysis  What points need to be addressed in the Bindin...
#
#       source                                          embedding  \
# 0    summary  [-0.009783994406461716, -0.06066862493753433, ...
# 1    summary  [-0.017316676676273346, -0.021807707846164703,...
# 2    summary  [-0.07271231710910797, -0.06814079731702805, -...
# 3    summary  [-0.017403494566679, -0.08751912415027618, -0....
# 4    summary  [-0.004610632546246052, -0.043068330734968185,...
# ..       ...                                                ...
# 82  question  [-0.04174955189228058, -0.0986546203494072, -0...
# 83  question  [-0.04039411619305611, -0.08921048790216446, -...
# 84  question  [-0.04588606581091881, -0.06260394304990768, -...
# 85  question  [-0.010924087837338448, -0.03873256593942642, ...
# 86  question  [-0.0038541764952242374, -0.05298667028546333,...
#
#           document
# 0   Article_47_BCR
# 1   Article_47_BCR
# 2   Article_47_BCR
# 3   Article_47_BCR
# 4   Article_47_BCR
# ..             ...
# 82  Article_47_BCR
# 83  Article_47_BCR
# 84  Article_47_BCR
# 85  Article_47_BCR
# 86  Article_47_BCR
#
# [87 rows x 5 columns]

# %%
import importlib
import src.index_tools
importlib.reload(src.index_tools)
from src.index_tools import add_to_index

index_df = article_47_index
text = "What happens if local laws conflict with the standards of binding corporate rules?"
section_reference = "3.5.4.1"
source = "question"
document = "Article_47_BCR"

index_df = add_to_index(openai_client, index_df, text, section_reference, source, document, embedding_model, embedding_dimensions)

# %%
from src.index_tools import remove_from_index

text_to_delete = "What happens if local laws conflict with the standards of binding corporate rules?"
article_47_index = remove_from_index(article_47_index, text_to_delete)

# %%
article_47_index = index_df
article_47_index[article_47_index["section_reference"] == "3.5.4.1"]
# Out:
#    section_reference                                               text  \
# 25           3.5.4.1  You must ensure that the Binding Corporate Rul...
# 79           3.5.4.1  What should the Binding Corporate Rules-Contro...
# 87           3.5.4.1  What happens if local laws conflict with the s...
#
#       source                                          embedding  \
# 25   summary  [-0.018655141815543175, -0.05344023182988167, ...
# 79  question  [-0.014255059882998466, -0.07780193537473679, ...
# 87  question  [-0.02774774841964245, -0.06760360300540924, -...
#
#           document
# 25  Article_47_BCR
# 79  Article_47_BCR
# 87  Article_47_BCR

# %%
save_parquet_data(index_df, "../inputs/index/gdpr.parquet", key)

# %%
index_df[index_df['document'] == "article_30_5"]
# Out:
#                                                   text  \
# 147  Under what conditions could you be exempt from...
#
#                                              embedding    source  \
# 147  [-0.03439036011695862, -0.0008122794097289443,...  question
#
#     section_reference      document
# 147               all  article_30_5

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')

path_to_file = "../inputs/index/article_30_5.parquet"
index = load_parquet_data(path_to_file, key)

# %%
#index["document"] = "Article_30_5"
index
# Out:
#   section_reference  ...      document
# 0               all  ...  Article_30_5
# 1               all  ...  Article_30_5
# 2               all  ...  Article_30_5
# 3               all  ...  Article_30_5
# 4               all  ...  Article_30_5
# 5               all  ...  Article_30_5
# 6               all  ...  Article_30_5
# 7               all  ...  Article_30_5
#
# [8 rows x 5 columns]

# %%
save_parquet_data(index, path_to_file, key)
