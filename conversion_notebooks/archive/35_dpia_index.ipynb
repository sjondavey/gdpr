# %%
import logging
log_level = 25
logging.basicConfig(level=log_level) # root logger

# %%
import re
import pandas as pd

import sys
sys.path.append('E:/Code/chat/gdpr')

import importlib
import gdpr_rag.documents.dpia
importlib.reload(gdpr_rag.documents.dpia)
from gdpr_rag.documents.dpia import DPIA

path_to_manual_as_csv_file = "../inputs/documents/dpia.parquet"

doc = DPIA(path_to_manual_as_csv_file)

# %%
from regulations_rag.regulation_table_of_content import StandardTableOfContent
reference_checker = doc.reference_checker
df = pd.read_parquet("../inputs/documents/dpia.parquet", engine='pyarrow')
toc = StandardTableOfContent(root_node_name = "decisions", reference_checker = reference_checker, regulation_df = df)

# %%
# Remove the annexes from the tree for indexing
annex_1_node = toc.get_node("Annex 1")
annex_1_node.parent = None

toc.print_tree()
# Out:
# decisions []
# |-- I [Introduction  ]
# |-- II [Scope of the Guidelines  ]
# |-- III [DPIA: the Regulation explained  ]
# |   |-- .A [What does a DPIA address? A single processing operation or a set of similar processing operations.   ]
# |   |-- .B [Which processing operations are subject to a DPIA? Apart from exceptions, where they are "likely to result in a high risk".   ]
# |   |   |-- .a [When is a DPIA mandatory? When processing is "likely to result in a high risk".   ]
# |   |   +-- .b [When isn't a DPIA required? When the processing is not "likely to result in a high risk", or a similar DPIA exists, or it has been authorized prior to May 2018, or it has a legal basis, or it is in the list of processing operations for which a DPIA is not required.   ]
# |   |-- .C [What about already existing processing operations? DPIAs are required in some circumstances.  ]
# |   |-- .D [How to carry out a DPIA?   ]
# |   |   |-- .a [At what moment should a DPIA be carried out? Prior to the processing. The DPIA should be carried out "prior to the processing" (Articles 35(1) and 35(10), recitals 90 and 93)[^23]. This is consistent with data protection by design and by default principles (Article 25 and recital 78).
# [^23] Except when it is an already existing processing that has been prior checked by the Supervisory Authority, in which case the DPIA should be carried out before undergoing significant changes.]
# |   |   |-- .b [Who is obliged to carry out the DPIA? The controller, with the DPO and processors.   ]
# |   |   |-- .c [What is the methodology to carry out a DPIA? Different methodologies but common criteria.]
# |   |   +-- .d [Is there an obligation to publish the DPIA? No, but publishing a summary could foster trust, and the full DPIA must be communicated to the supervisory authority in case of prior consultation or if requested by the DPA.   ]
# |   +-- .E [When shall the supervisory authority be consulted? When the residual risks are high.  ]
# |-- IV [Conclusions and recommendations  ]
# +-- Annex 2 [Criteria for an acceptable DPIA   ]

# %%
sys.path.append('E:/Code/chat/gdpr')

from anytree import Node, PreOrderIter
from regulations_rag.embeddings import num_tokens_from_string

all_nodes = list(PreOrderIter(toc.root))
all_node_names = [node.full_node_name for node in all_nodes if node.full_node_name != ""]
split_df = pd.DataFrame(all_node_names, columns = ["section_reference"])
for index, row in split_df.iterrows():
    text = doc.get_text(row['section_reference'])
    split_df.at[index, 'text'] = text
    split_df.at[index, 'token_count'] = num_tokens_from_string(text)
split_df["token_count"] = split_df["token_count"].astype(int)
# from regulations_rag.regulation_table_of_content import split_tree

# split_df = split_tree(node = toc.root, document = doc, table_of_content = toc, token_limit = 1300)

# %%
split_df
# Out:
#    section_reference                                               text  \
# 0                  I  I. Introduction  \nRegulation 2016/679[^1] (GD...
# 1                 II  II. Scope of the Guidelines  \nThese Guideline...
# 2                III  III. DPIA: the Regulation explained  \nThe GDP...
# 3              III.A  III. DPIA: the Regulation explained  \n\nA. Wh...
# 4              III.B  III. DPIA: the Regulation explained  \n\nB. Wh...
# 5            III.B.a  III. DPIA: the Regulation explained  \nB. Whic...
# 6            III.B.b  III. DPIA: the Regulation explained  \nB. Whic...
# 7              III.C  III. DPIA: the Regulation explained  \n\nC. Wh...
# 8              III.D  III. DPIA: the Regulation explained  \n\nD. Ho...
# 9            III.D.a  III. DPIA: the Regulation explained  \nD. How ...
# 10           III.D.b  III. DPIA: the Regulation explained  \nD. How ...
# 11           III.D.c  III. DPIA: the Regulation explained  \nD. How ...
# 12           III.D.d  III. DPIA: the Regulation explained  \nD. How ...
# 13             III.E  III. DPIA: the Regulation explained  \n\nE. Wh...
# 14                IV  IV. Conclusions and recommendations  \nDPIAs a...
# 15           Annex 2  Annex 2. Criteria for an acceptable DPIA   \nT...
#
#     token_count
# 0           831
# 1           682
# 2           475
# 3           579
# 4           101
# 5          2589
# 6           656
# 7           597
# 8            19
# 9           324
# 10          746
# 11         1065
# 12          390
# 13          683
# 14          467
# 15          678

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')
#index_df = load_parquet_data("../inputs/index_gdpr.parquet", key)

# %%
from openai import OpenAI
openai_client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),)

import sys
sys.path.append('E:/Code/chat/gdpr')
import importlib
import src.summarise_and_question
importlib.reload(src.summarise_and_question)
from src.summarise_and_question import get_summary_and_questions_for

# %%
summary_file = "../tmp/dpia_summary.csv"
if os.path.exists(summary_file):
    df_summary = pd.read_csv(summary_file, sep="|", encoding = "utf-8")
else:
    df_summary = pd.DataFrame([], columns = ["section_reference", "text", "source", "embedding", "document"])
    df_summary["section_reference"] = split_df["section_reference"]
    # df_summary["text"] = split_df["text"]
    df_summary["source"] = "summary"
    df_summary["document"] = "DPIA"

first_empty_index = df_summary[df_summary['text'].isna()].index.min()

if pd.isna(first_empty_index):
    #print("No empty embeddings found.")
    first_empty_index = 0
index = first_empty_index

question_file = "../tmp/dpia_question.csv"
if os.path.exists(question_file):
    df_questions = pd.read_csv(question_file, sep="|", encoding = "utf-8")
else:
    df_questions = pd.DataFrame([], columns = ["section_reference", "text", "source", "embedding", "document"])
    df_questions["section_reference"] = split_df["section_reference"]
    # df_questions["text"] = split_df["text"]
    df_questions["source"] = "question"
    df_questions["document"] = "DPIA"

first_empty_index = df_questions[df_questions['text'].isna()].index.min()

if pd.isna(first_empty_index):
    #print("No empty embeddings found.")
    first_empty_index = 0

if index != first_empty_index:
    print("The index in the summary and questions files do not match. This needs to be fixed")
else:
    [print(f"Picking up at index {index}")]
# Out:
# Picking up at index 0

# %%
df_summary = df_summary[df_summary["section_reference"] != "II"]
df_questions = df_questions[df_questions["section_reference"] != "II"]

df_summary = df_summary[df_summary["section_reference"] != "III.B"]
df_questions = df_questions[df_questions["section_reference"] != "III.B"]

df_summary = df_summary[df_summary["section_reference"] != "III.D"]
df_questions = df_questions[df_questions["section_reference"] != "III.D"]

df_summary = df_summary[df_summary["section_reference"] != "IV"]
df_questions = df_questions[df_questions["section_reference"] != "IV"]




df_summary.reset_index(drop=True, inplace=True)
df_questions.reset_index(drop=True, inplace=True)

# %%
model = "gpt-4o"

reference = df_summary.iloc[index]["section_reference"]

reg_text = doc.get_text(reference)
print("##############")
print(reg_text)
print("##############")

model_summary, model_questions = get_summary_and_questions_for(openai_client = openai_client, text = reg_text, model = model)

#format output
print(f'# index: {index}, section_reference: {df_summary.iloc[index]["section_reference"]}')
print()
print(f'df_summary.loc[index, "text"] = "{model_summary}"')
print()
print(f'df_questions.loc[index, "text"] = "{model_questions}"')
# Out:
# ##############
# Annex 2. Criteria for an acceptable DPIA
# The WP29 proposes the following criteria which data controllers can use to assess whether or not a DPIA, or a methodology to carry out a DPIA, is sufficiently comprehensive to comply with the GDPR:
# - a systematic description of the processing is provided (Article 35(7)(a)):
#     - nature, scope, context and purposes of the processing are taken into account (recital 90);
#     - personal data, recipients and period for which the personal data will be stored are recorded;
#     - a functional description of the processing operation is provided;
#     - the assets on which personal data rely (hardware, software, networks, people, paper or paper transmission channels) are identified;
#     - compliance with approved codes of conduct is taken into account (Article 35(8));
# - necessity and proportionality are assessed (Article 35(7)(b)):
#     - measures envisaged to comply with the Regulation are determined (Article 35(7)(d) and recital 90), taking into account:
#         - measures contributing to the proportionality and the necessity of the processing on the basis of:
#             - specified, explicit and legitimate purpose(s) (Article 5(1)(b));
#             - lawfulness of processing (Article 6);
#             - adequate, relevant and limited to what is necessary data (Article 5(1)(c));
#             - limited storage duration (Article 5(1)(e));
#         - measures contributing to the rights of the data subjects:
#             - information provided to the data subject (Articles 12, 13 and 14);
#             - right of access and to data portability (Articles 15 and 20);
#             - right to rectification and to erasure (Articles 16, 17 and 19);
#             - right to object and to restriction of processing (Article 18, 19 and 21);
#             - relationships with processors (Article 28);
#             - safeguards surrounding international transfer(s) (Chapter V);
#             - prior consultation (Article 36).
# - risks to the rights and freedoms of data subjects are managed (Article 35(7)(c)):
#     - origin, nature, particularity and severity of the risks are appreciated (cf. recital 84) or, more specifically, for each risk (illegitimate access, undesired modification, and disappearance of data) from the perspective of the data subjects:
#         - risks sources are taken into account (recital 90);
#         - potential impacts to the rights and freedoms of data subjects are identified in case of events including illegitimate access, undesired modification and disappearance of data;
#         - threats that could lead to illegitimate access, undesired modification and disappearance of data are identified;
#         - likelihood and severity are estimated (recital 90);
#     - measures envisaged to treat those risks are determined (Article 35(7)(d) and recital 90);
# - interested parties are involved:
#     - the advice of the DPO is sought (Article 35(2));
#     - the views of data subjects or their representatives are sought, where appropriate (Article 35(9)).
# ##############
# # index: 11, section_reference: Annex 2
#
# df_summary.loc[index, "text"] = "1. Ensure a systematic description of the processing:
#    - Consider the nature, scope, context, and purposes of the processing.
#    - Record personal data, recipients, and storage period.
#    - Provide a functional description of the processing operation.
#    - Identify the assets on which personal data rely (hardware, software, networks, people, paper, or paper transmission channels).
#    - Consider compliance with approved codes of conduct.
#
# 2. Assess necessity and proportionality:
#    - Determine the measures envisaged to comply with the Regulation.
#    - Ensure measures contribute to the proportionality and necessity of processing:
#      - Based on specified, explicit, and legitimate purpose(s).
#      - Ensure lawfulness of processing.
#      - Data must be adequate, relevant, and limited to what is necessary.
#      - Ensure limited storage duration.
#    - Measures that contribute to individuals' rights:
#      - Provide information to individuals.
#      - Ensure the right of access and data portability.
#      - Ensure the right to rectification and erasure.
#      - Respect the right to object and restriction of processing.
#      - Manage relationships with processors.
#      - Ensure safeguards surrounding international transfers.
#      - Be aware of prior consultation requirements.
#
# 3. Manage risks to the rights and freedoms of individuals:
#    - Appreciate the origin, nature, particularity, and severity of risks.
#    - Take into account risk sources.
#    - Identify potential impacts on individuals’ rights and freedoms (e.g., illegitimate access, undesired modification, disappearance of data).
#    - Identify threats that could lead to these impacts.
#    - Estimate likelihood and severity of risks.
#    - Determine measures to treat the risks.
#
# 4. Involve interested parties:
#    - Seek the advice of the DPO.
#    - Seek the views of individuals or their representatives, where appropriate."
#
# df_questions.loc[index, "text"] = "What is needed for a comprehensive Data Protection Impact Assessment (DPIA)?|How do you describe the processing in a DPIA?|What factors should be considered regarding the data’s lifecycle in a DPIA?|How do you ensure compliance with approved codes of conduct in a DPIA?|How do you assess the necessity and proportionality of processing in a DPIA?|What measures should be included to ensure compliance?|How does the DPIA address the rights of individuals?|How do you manage risks to individuals' rights and freedoms in a DPIA?|What risks should be evaluated in a DPIA?|How do you involve interested parties in the DPIA process?|When should you seek the advice of the Data Protection Officer (DPO) during a DPIA?|Why is it important to consult data subjects or their representatives in a DPIA?"

# %%
df_summary.loc[index, "text"] = "Criteria for an acceptable DPIA"

df_questions.loc[index, "text"] = "What is needed for a comprehensive Data Protection Impact Assessment (DPIA)?|What risks should be evaluated in a DPIA?"





index = index + 1
print(f"You have completed {(index / len(df_summary) * 100):.2f}% of the work")
if index < len(df_summary):
    print(f"The next section is:\n{doc.get_text(df_summary.iloc[index]['section_reference'])}")
else:
    print("All done")
# Out:
# You have completed 100.00% of the work
# All done

# %%
#df_questions.at[9, "section_reference"] ='III.D.d'
df_questions
# Out:
#    section_reference                                               text  \
# 0                  I  What is a Data Protection Impact Assessment (D...
# 1                III  What are the steps involved in managing risks ...
# 2              III.A  What does a Data Protection Impact Assessment ...
# 3            III.B.a  When is it necessary to conduct a Data Protect...
# 4            III.B.b  What are the exceptions to the requirement for...
# 5              III.C  When is a Data Protection Impact Assessment (D...
# 6            III.D.a  When should a Data Protection Impact Assessmen...
# 7            III.D.b  Who is responsible for conducting a Data Prote...
# 8            III.D.c  What are the essential components of a Data Pr...
# 9            III.D.d  Is it mandatory to publish the Data Protection...
# 10             III.E  What should you do if residual risks are high ...
# 11           Annex 2  What is needed for a comprehensive Data Protec...
#
#       source embedding document
# 0   question       NaN     DPIA
# 1   question       NaN     DPIA
# 2   question       NaN     DPIA
# 3   question       NaN     DPIA
# 4   question       NaN     DPIA
# 5   question       NaN     DPIA
# 6   question       NaN     DPIA
# 7   question       NaN     DPIA
# 8   question       NaN     DPIA
# 9   question       NaN     DPIA
# 10  question       NaN     DPIA
# 11  question       NaN     DPIA

# %%
df_summary
# Out:
#    section_reference                                               text  \
# 0                  I  Perform a Data Protection Impact Assessment (D...
# 1                III  You must implement measures to ensure and demo...
# 2              III.A  A Data Protection Impact Assessment (DPIA) can...
# 3            III.B.a  A Data Protection Impact Assessment (DPIA) is ...
# 4            III.B.b  A Data Protection Impact Assessment (DPIA) is ...
# 5              III.C  Carry out a Data Protection Impact Assessment ...
# 6            III.D.a  You must conduct a Data Protection Impact Asse...
# 7            III.D.b  The controller is responsible for ensuring the...
# 8            III.D.c  Describe the processing operations and their p...
# 9            III.D.d  No obligation exists to publish the DPIA, thou...
# 10             III.E  If residual risks remain high after a Data Pro...
# 11           Annex 2                    Criteria for an acceptable DPIA
#
#      source embedding document
# 0   summary       NaN     DPIA
# 1   summary       NaN     DPIA
# 2   summary       NaN     DPIA
# 3   summary       NaN     DPIA
# 4   summary       NaN     DPIA
# 5   summary       NaN     DPIA
# 6   summary       NaN     DPIA
# 7   summary       NaN     DPIA
# 8   summary       NaN     DPIA
# 9   summary       NaN     DPIA
# 10  summary       NaN     DPIA
# 11  summary       NaN     DPIA

# %%
summary_file = "../tmp/dpia_summary.csv"
df_summary.to_csv(summary_file, sep = "|", encoding = "utf-8", index = False, na_rep="")

question_file = "../tmp/dpia_question.csv"
df_questions.to_csv(question_file, sep = "|", encoding = "utf-8", index = False, na_rep="")

# %%
import pandas as pd
summary_file = "../tmp/dpia_summary.csv"
df_summary = pd.read_csv(summary_file, sep = "|", encoding = "utf-8")

question_file = "../tmp/dpia_question.csv"
df_questions = pd.read_csv(question_file, sep = "|", encoding = "utf-8")

# %%
df_questions = df_questions.drop("text", axis=1).join(df_questions["text"].str.split("|", expand=True).stack().reset_index(level=1, drop=True).rename("text"))
df_questions.reset_index(drop=True, inplace=True)

# %%
df_questions = df_questions[df_questions["text"] != ""]
df_questions.reset_index(drop=True, inplace=True)

# %%
df_index = pd.concat([df_summary, df_questions], ignore_index = True)
df_index
# Out:
#    section_reference                                               text  \
# 0                  I  Perform a Data Protection Impact Assessment (D...
# 1                III  You must implement measures to ensure and demo...
# 2              III.A  A Data Protection Impact Assessment (DPIA) can...
# 3            III.B.a  A Data Protection Impact Assessment (DPIA) is ...
# 4            III.B.b  A Data Protection Impact Assessment (DPIA) is ...
# ..               ...                                                ...
# 59             III.E  What should you do if residual risks are high ...
# 60             III.E  What is considered an example of a high residu...
# 61             III.E  When must you consult the supervisory authorit...
# 62           Annex 2  What is needed for a comprehensive Data Protec...
# 63           Annex 2          What risks should be evaluated in a DPIA?
#
#       source  embedding document
# 0    summary        NaN     DPIA
# 1    summary        NaN     DPIA
# 2    summary        NaN     DPIA
# 3    summary        NaN     DPIA
# 4    summary        NaN     DPIA
# ..       ...        ...      ...
# 59  question        NaN     DPIA
# 60  question        NaN     DPIA
# 61  question        NaN     DPIA
# 62  question        NaN     DPIA
# 63  question        NaN     DPIA
#
# [64 rows x 5 columns]

# %%
from openai import OpenAI
openai_client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),)

from regulations_rag.embeddings import get_ada_embedding
model = "text-embedding-3-large"
dimensions = 1024

#df_index = df_questions
df_index['embedding'] = pd.NA  # Initialize the column to hold NA values
df_index['embedding'] = df_index['embedding'].astype(object)  # Ensure the column type is object
increment = 10
for i in range(0, len(df_index), increment):
    chunk = df_index.iloc[i:i+increment].copy()
    chunk["embedding"] = chunk["text"].apply(lambda x: get_ada_embedding(openai_client, x, model, dimensions))
    df_index.loc[chunk.index, "embedding"] = chunk["embedding"]
    print(f"Completed {i+increment} lines")
# Out:
# Completed 10 lines
# Completed 20 lines
# Completed 30 lines
# Completed 40 lines
# Completed 50 lines
# Completed 60 lines
# Completed 70 lines

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')

file = "../inputs/index/dpia.parquet"
df_index.to_parquet(file, engine = "pyarrow")
save_parquet_data(df_index, file, key)

# %%
df_index
#df_index["document"] = "Article_47_BCR"
# Out:
#    section_reference                                               text  \
# 0                  I  Perform a Data Protection Impact Assessment (D...
# 1                III  You must implement measures to ensure and demo...
# 2              III.A  A Data Protection Impact Assessment (DPIA) can...
# 3            III.B.a  A Data Protection Impact Assessment (DPIA) is ...
# 4            III.B.b  A Data Protection Impact Assessment (DPIA) is ...
# ..               ...                                                ...
# 59             III.E  What should you do if residual risks are high ...
# 60             III.E  What is considered an example of a high residu...
# 61             III.E  When must you consult the supervisory authorit...
# 62           Annex 2  What is needed for a comprehensive Data Protec...
# 63           Annex 2          What risks should be evaluated in a DPIA?
#
#       source                                          embedding document
# 0    summary  [-0.0651446282863617, -0.014580177143216133, -...     DPIA
# 1    summary  [-0.06786536425352097, -0.012024881318211555, ...     DPIA
# 2    summary  [-0.04701923951506615, -0.02683098055422306, -...     DPIA
# 3    summary  [-0.04772201552987099, 0.006425258703529835, -...     DPIA
# 4    summary  [-0.02549058012664318, 0.019770581275224686, -...     DPIA
# ..       ...                                                ...      ...
# 59  question  [-0.04703465476632118, -0.05478291213512421, -...     DPIA
# 60  question  [-0.05717877298593521, -0.00804865825921297, -...     DPIA
# 61  question  [-0.026660023257136345, -0.040645912289619446,...     DPIA
# 62  question  [-0.017761580646038055, -0.021252399310469627,...     DPIA
# 63  question  [-0.07735233008861542, -0.01770109124481678, -...     DPIA
#
# [64 rows x 5 columns]

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')

gdpr_index = load_parquet_data("../inputs/index/gdpr.parquet", key)
dpia_index = load_parquet_data("../inputs/index/dpia.parquet", key)

# %%
questions_to_fix = gdpr_index[
    (~gdpr_index["text"].str.contains('DPIA')) & 
    (gdpr_index["text"].str.lower().str.contains('data protection impact assessment'))
]

# %%
len(questions_to_fix)
#questions_to_fix.iloc[0]["text"]
# Out:
# 0

# %%
import re

import sys
sys.path.append('E:/Code/chat/gdpr')
from src.index_tools import update_text_in_index, add_to_index

from openai import OpenAI
openai_client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),)


model = "text-embedding-3-large"
dimensions = 1024

for index, row in questions_to_fix.iterrows():
    s = row['text']
    text_to_change = s
    #changed_text = s.replace("data protection impact assessment", "data protection impact assessment (DPIA)", 1)
    changed_text = re.sub(r"data protection impact assessment", "data protection impact assessment (DPIA)", s, flags=re.IGNORECASE, count=1)

    gdpr_index = update_text_in_index(openai_client = openai_client, index_df = gdpr_index, text_to_change = text_to_change, changed_text = changed_text, embedding_model = model, embedding_dimensions = dimensions)

# %%
section = gdpr_index[gdpr_index["section_reference"] == "35"]

#section
for index, row in section.iterrows():
    print(f"-- {row['text']}")
# Out:
# -- When must you conduct a data protection impact assessment?
# -- Who should you consult when carrying out a data protection impact assessment?
# -- What triggers the requirement for a data protection impact assessment?
# -- How do supervisory authorities contribute to the data protection impact assessment process?
# -- What content is required in a data protection impact assessment?
# -- Should individuals' views be considered in the assessment process?
# -- What happens when processing activities are already regulated by Union or Member State law?
# -- How often should you review the data protection impact assessment?
# -- Before starting any processing activities that use new technologies and are likely to pose a high risk to individuals' rights and freedoms, you must conduct a data protection impact assessment. This is particularly mandatory for:
# - Automated processing including profiling that significantly affects individuals.
# - Large-scale processing of special categories of data or data concerning criminal convictions.
# - Systematic monitoring of a publicly accessible area on a large scale.
# You should consult your data protection officer when conducting this assessment. The assessment must include a systematic description of the processing operations and their purposes, an evaluation of necessity and proportionality, a risk assessment to individuals’ rights and freedoms, and the measures to address these risks including safeguards and compliance mechanisms.
# You should also consider any relevant approved codes of conduct to evaluate the impact of your processing operations. Where appropriate, take into account the views of the affected individuals or their representatives on the intended processing, ensuring this does not harm commercial or public interests or the security of processing operations.
# If the processing has a legal basis in Union or Member State law, and a data protection impact assessment has already been part of a general impact assessment under that law, you may not need to conduct another assessment unless considered necessary by the Member State.
# Whenever there’s a change in the risk posed by the processing operations, reassess the processing to ensure alignment with the initial data protection impact assessment.

# %%
tmp = decision_index[(decision_index["section_reference"]== "I")]
for index, row in tmp.iterrows():
    print(f"-- {row['text']}")
# Out:
# -- Profiling and automated decision-making are increasingly utilised across various sectors such as banking, healthcare, and marketing, driven by technological advancements in big data, AI, and machine learning. These techniques can greatly benefit efficiency and personalisation but also pose risks to individual rights and freedoms due to their potential invasiveness and the issues around transparency and discrimination they can create.
#
# The GDPR seeks to mitigate these risks by implementing specific provisions to protect privacy and other related rights. You must ensure appropriate safeguards when employing profiling and automated decision-making technologies, keeping in mind their potential to impact individuals based on inaccurate data, perpetuate stereotypes, or restrict individual choices.
#
# Particularly under Article 22, you have obligations regarding solely automated decisions that have legal or similarly significant effects on individuals, including the requirement to provide meaningful information about the logic involved, as well as the significance and the envisaged consequences of such processing. There are additional considerations and protections concerning profiling of children and the need for data protection impact assessments when using such technologies.
#
# These guidelines serve to explain the requirements and are supported by best practice recommendations from EU experiences
# -- What are the concerns surrounding profiling and automated decision-making?
# -- How do advances in technology impact profiling and automated decision-making?
# -- What safeguards does the General Data Protection Regulation (GDPR) introduce for profiling and automated decision-making?

# %%
#file = "../inputs/index/dpia.parquet"
file = "../inputs/index/gdpr.parquet"
#df_index.to_parquet(file, engine = "pyarrow")
save_parquet_data(gdpr_index, file, key)

# %%
from src.index_tools import update_text_in_index, add_to_index

index_df = decision_index
#index_df = gdpr_index

text_to_change = "How do automated decision-making and profiling differ?"
changed_text = "What is automated decision-making?"
embedding_model = model
embedding_dimensions = dimensions

index_df = update_text_in_index(openai_client = openai_client, index_df = index_df, text_to_change = text_to_change, changed_text = changed_text, embedding_model = embedding_model, embedding_dimensions = embedding_dimensions)

# %%
import importlib
import src.index_tools
importlib.reload(src.index_tools)
from src.index_tools import add_to_index

index_df = article_47_index
text = "What happens if local laws conflict with the standards of binding corporate rules?"
section_reference = "3.5.4.1"
source = "question"
document = "Article_47_BCR"

index_df = add_to_index(openai_client, index_df, text, section_reference, source, document, embedding_model, embedding_dimensions)

# %%
from src.index_tools import remove_from_index

text_to_delete = "What safeguards does the General Data Protection Regulation (GDPR) introduce for profiling and automated decision-making?"
decision_index = remove_from_index(decision_index, text_to_delete)

# %%
article_47_index = index_df
article_47_index[article_47_index["section_reference"] == "3.5.4.1"]
# Out:
#    section_reference                                               text  \
# 25           3.5.4.1  You must ensure that the Binding Corporate Rul...
# 79           3.5.4.1  What should the Binding Corporate Rules-Contro...
# 87           3.5.4.1  What happens if local laws conflict with the s...
#
#       source                                          embedding  \
# 25   summary  [-0.018655141815543175, -0.05344023182988167, ...
# 79  question  [-0.014255059882998466, -0.07780193537473679, ...
# 87  question  [-0.02774774841964245, -0.06760360300540924, -...
#
#           document
# 25  Article_47_BCR
# 79  Article_47_BCR
# 87  Article_47_BCR

# %%
save_parquet_data(index_df, "../inputs/index/gdpr.parquet", key)

# %%
index_df[index_df['document'] == "article_30_5"]
# Out:
#                                                   text  \
# 147  Under what conditions could you be exempt from...
#
#                                              embedding    source  \
# 147  [-0.03439036011695862, -0.0008122794097289443,...  question
#
#     section_reference      document
# 147               all  article_30_5

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')

path_to_file = "../inputs/index/article_30_5.parquet"
index = load_parquet_data(path_to_file, key)

# %%
#index["document"] = "Article_30_5"
index
# Out:
#   section_reference  ...      document
# 0               all  ...  Article_30_5
# 1               all  ...  Article_30_5
# 2               all  ...  Article_30_5
# 3               all  ...  Article_30_5
# 4               all  ...  Article_30_5
# 5               all  ...  Article_30_5
# 6               all  ...  Article_30_5
# 7               all  ...  Article_30_5
#
# [8 rows x 5 columns]

# %%
save_parquet_data(index, path_to_file, key)
