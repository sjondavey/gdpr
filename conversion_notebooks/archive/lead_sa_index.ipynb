# %%
import logging
log_level = 25
logging.basicConfig(level=log_level) # root logger

# %%
import re
import pandas as pd

import sys
sys.path.append('E:/Code/chat/gdpr')

import importlib
import gdpr_rag.documents.lead_sa
importlib.reload(gdpr_rag.documents.lead_sa)
from gdpr_rag.documents.lead_sa import Lead_SA

path_to_manual_as_csv_file = "../inputs/documents/lead_sa.parquet"

doc = Lead_SA(path_to_manual_as_csv_file)

# %%
from regulations_rag.regulation_table_of_content import StandardTableOfContent
reference_checker = doc.reference_checker
df = pd.read_parquet(path_to_manual_as_csv_file, engine='pyarrow')
toc = StandardTableOfContent(root_node_name = "intl_transfer", reference_checker = reference_checker, regulation_df = df)

# %%
toc.print_tree()
# Out:
# intl_transfer []
# |-- 1 [Identifying a lead supervisory authority: the key concepts.  ]
# |   |-- .1 ['Cross-border processing of personal data'.   ]
# |   |   +-- .1 ['Substantially affects'.  ]
# |   |-- .2 [Lead supervisory authority.  ]
# |   +-- .3 [Main establishment.   ]
# |-- 2 [Steps to identify the lead supervisory authority  ]
# |   |-- .1 [Identify the 'main establishment' for controllers   ]
# |   |   |-- .1 [Criteria for identifying a controller's main establishment in cases where it is not the place of its central administration in the EU.  ]
# |   |   |-- .2 [Groups of undertakings  ]
# |   |   +-- .3 [Joint data controllers  ]
# |   |-- .2 [Borderline cases  ]
# |   +-- .3 [Processor ]
# |-- 3 [Other relevant issues ]
# |   |-- .1 [The role of the 'supervisory authority concerned' ]
# |   |-- .2 [Local processing.  ]
# |   +-- .3 [Companies not established within the EU.   ]
# +-- Annex [Questions to guide the identification of the lead supervisory authority   ]

# %%
sys.path.append('E:/Code/chat/gdpr')

from anytree import Node, PreOrderIter
from regulations_rag.embeddings import num_tokens_from_string

all_nodes = list(PreOrderIter(toc.root))
all_node_names = [node.full_node_name for node in all_nodes if node.full_node_name != ""]
split_df = pd.DataFrame(all_node_names, columns = ["section_reference"])
for index, row in split_df.iterrows():
    text = doc.get_text(row['section_reference'])
    split_df.at[index, 'text'] = text
    split_df.at[index, 'token_count'] = num_tokens_from_string(text)
split_df["token_count"] = split_df["token_count"].astype(int)

split_df = split_df[split_df["token_count"] > 20]
split_df.reset_index(drop=True, inplace=True)
split_df
# Out:
#    section_reference                                               text  \
# 0                1.1  1 Identifying a lead supervisory authority: th...
# 1              1.1.1  1 Identifying a lead supervisory authority: th...
# 2                1.2  1 Identifying a lead supervisory authority: th...
# 3                1.3  1 Identifying a lead supervisory authority: th...
# 4                2.1  2 Steps to identify the lead supervisory autho...
# 5              2.1.1  2 Steps to identify the lead supervisory autho...
# 6              2.1.2  2 Steps to identify the lead supervisory autho...
# 7              2.1.3  2 Steps to identify the lead supervisory autho...
# 8                2.2  2 Steps to identify the lead supervisory autho...
# 9                2.3  2 Steps to identify the lead supervisory autho...
# 10               3.1  3 Other relevant issues \n\n3.1 The role of th...
# 11               3.2  3 Other relevant issues \n\n3.2 Local processi...
# 12               3.3  3 Other relevant issues \n\n3.3 Companies not ...
# 13             Annex  Annex Questions to guide the identification of...
#
#     token_count
# 0           261
# 1           784
# 2           187
# 3           200
# 4           914
# 5           410
# 6           280
# 7           210
# 8           569
# 9           281
# 10          673
# 11           68
# 12          101
# 13          642

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')
#index_df = load_parquet_data("../inputs/index_gdpr.parquet", key)

# %%
from openai import OpenAI
openai_client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),)

import sys
sys.path.append('E:/Code/chat/gdpr')
import importlib
import src.summarise_and_question
importlib.reload(src.summarise_and_question)
from src.summarise_and_question import get_summary_and_questions_for

# %%
summary_file = "../tmp/lead_sa_summary.csv"
if os.path.exists(summary_file):
    df_summary = pd.read_csv(summary_file, sep="|", encoding = "utf-8")
else:
    df_summary = pd.DataFrame([], columns = ["section_reference", "text", "source", "embedding", "document"])
    df_summary["section_reference"] = split_df["section_reference"]
    # df_summary["text"] = split_df["text"]
    df_summary["source"] = "summary"
    df_summary["document"] = "Lead_SA"

first_empty_index = df_summary[df_summary['text'].isna()].index.min()

if pd.isna(first_empty_index):
    #print("No empty embeddings found.")
    first_empty_index = 0
index = first_empty_index

question_file = "../tmp/lead_sa_question.csv"
if os.path.exists(question_file):
    df_questions = pd.read_csv(question_file, sep="|", encoding = "utf-8")
else:
    df_questions = pd.DataFrame([], columns = ["section_reference", "text", "source", "embedding", "document"])
    df_questions["section_reference"] = split_df["section_reference"]
    # df_questions["text"] = split_df["text"]
    df_questions["source"] = "question"
    df_questions["document"] = "Lead_SA"

first_empty_index = df_questions[df_questions['text'].isna()].index.min()

if pd.isna(first_empty_index):
    #print("No empty embeddings found.")
    first_empty_index = 0

if index != first_empty_index:
    print("The index in the summary and questions files do not match. This needs to be fixed")
else:
    [print(f"Picking up at index {index}")]
# Out:
# Picking up at index 0

# %%
model = "gpt-4o"

reference = df_summary.iloc[index]["section_reference"]

reg_text = doc.get_text(reference)
print("##############")
print(reg_text)
print("##############")

model_summary, model_questions = get_summary_and_questions_for(openai_client = openai_client, text = reg_text, model = model)

#format output
print(f'# index: {index}, section_reference: {df_summary.iloc[index]["section_reference"]}')
print()
print(f'df_summary.loc[index, "text"] = "{model_summary}"')
print()
print(f'df_questions.loc[index, "text"] = "{model_questions}"')
# Out:
# ##############
# Annex Questions to guide the identification of the lead supervisory authority
# 1. Is the controller or processor carrying out the cross-border processing of personal data?
# a. Yes, if:
# - the controller or processor is established in more than one Member State and  - the processing of personal data takes place in the context of the activities of
# establishments in more than one Member State.
# In this case, go to section 2.
# b. Yes, if:
# - the processing of personal data takes place in the context of the activities of a data
# controller or processor's single establishment in the Union, but:
# - substantially affects or is likely to substantially affect individuals in more than one
# Member State.
# In this case, the lead authority is the authority for the controller or processor's single
# establishment in a single Member State. This must - by logic - be the controller or processor's main establishment because it is its only establishment.
# 2. How to identify the 'lead supervisory authority'
# a. In a case involving only a controller:
# i. Identify the controller's place of central administration in the EU;
# ii. The supervisory authority of the country where the place of central administration is located is the controller's lead authority.
# However:
# iii. If decisions on the purposes and means of the processing are taken in another establishment in the EU, and that establishment has the power to implement those decisions, then the lead authority is the one located in the country where this establishment is.
# b. In a case involving a controller and a processor:
# i. Check if the controller is established in the EU and subject to the one-stop-shop system. If so,
# ii. Identify the lead supervisory authority of the controller. This authority will also be the  lead supervisory authority for the processor.
# iii.  The (non-lead) supervisory authority competent for the processor will be a 'concerned authority' - see 3 below.
# c. In a case involving only a processor:
# i. Identify the processor's place of central administration in the EU;
# ii. If the processor has no central administration in the EU, identify the
# establishment in the EU where the main processing  activities of the processor take place.
# d. In a case involving joint controllers:
# i. Check if the joint controllers are established in the EU.  ii. Designate among the establishments where decisions on the purposes and means of the processing are taken the establishment which has the power to implement these decisions with respect to all joint controllers. This establishment will then be considered to be the main establishment for the processing carried out by the joint controllers. The lead authority is the one located in the country where this establishment is.
# 3. Are there any 'concerned supervisory authorities'?
# An authority is a 'concerned authority':
# - when the controller or processor has an establishment  on its territory, or:
# - when data subjects on its territory are substantially affected or likely to be substantially affected by the processing, or:
# - when a complaint is received by a particular authority.
# ##############
# # index: 13, section_reference: Annex
#
# df_summary.loc[index, "text"] = "1. Determine if cross-border processing of personal data occurs:
#    a. Yes, if:
#       - Established in more than one Member State, and
#       - Processing occurs in multiple Member States' establishments.
#       Proceed to section 2.
#
#    b. Yes, if:
#       - Processing occurs in a single establishment in the Union, but substantially affects individuals in multiple Member States.
#       The lead authority will be in the Member State of the single establishment.
#
# 2. Identify the 'lead supervisory authority':
#    a. For a controller:
#       i. Identify the place of central administration in the EU.
#       ii. The supervisory authority of this place is the lead authority.
#       iii. If decisions on processing purposes and means are made in another EU establishment with implementation power, the lead authority is in that country.
#
#    b. For a controller and a processor:
#       i. Check if the controller is in the EU and subject to the one-stop-shop system.
#       ii. Identify the controller's lead supervisory authority, which also covers the processor.
#       iii. The processor's competent (non-lead) authority will be a 'concerned authority'.
#
#    c. For a processor:
#       i. Identify the central administration in the EU.
#       ii. If no central administration, identify where the main processing activities occur in the EU.
#
#    d. For joint controllers:
#       i. Check if joint controllers are established in the EU.
#       ii. Designate the establishment that makes and implements decisions for all joint controllers as the main establishment. The lead authority is in the country of this establishment.
#
# 3. Determine 'concerned supervisory authorities':
#    - When the controller or processor has an establishment in its territory, or
#    - When individuals on its territory are substantially affected by processing, or
#    - When a complaint is received by the authority."
#
# df_questions.loc[index, "text"] = "Do you handle personal data across different EU countries?|What defines the lead supervisory authority when operating in multiple countries?|How do you determine the lead supervisory authority if your main office is in the EU?|What if your company makes key decisions in an office separate from your central administration?|Who acts as the lead supervisory authority when a controller and a processor are involved?|What is the role of the supervisory authority when only a processor is involved?|How is the lead supervisory authority determined for joint controllers?|What qualifies an authority as a 'concerned supervisory authority'?"

# %%
model_summary
# Out:
# "The 'supervisory authority concerned' is a supervisory authority involved in personal data processing due to:\n\n(a) The establishment of the controller or processor in its Member State.\n(b) Significant impact on individuals residing in its Member State.\n(c) Complaints received by that authority.\n\nThis ensures other authorities can influence decisions despite the 'lead authority' model. Factors like residency, not citizenship, suffice for involvement. \n\nWhen a lead supervisory authority opts not to handle a case, the concerned one that informed the lead should take over, following the procedures in Article 61 (Mutual assistance) and Article 62 (Joint operations of supervisory authorities). For example, if a French company launches a product affecting only Portuguese individuals, both authorities may agree that the Portuguese authority should lead the matter.\n\nSupervisory authorities may request controllers provide clarifications on corporate arrangements. These authorities should collaborate to ensure satisfactory investigations and outcomes for individuals. Co-operation and mutual decision-making are encouraged, with the consistency mechanism as a last resort. Consensus between supervisory authorities is critical for effective GDPR cooperation and consistency."

# %%
# index: 13, section_reference: Annex

df_summary.loc[index, "text"] = "Workflow to determine the lead supervisory authority"

df_questions.loc[index, "text"] = "How do I determine my lead supervisory authority?"




index = index + 1
print(f"You have completed {(index / len(df_summary) * 100):.2f}% of the work")
if index < len(df_summary):
    print(f"The next section is:\n{doc.get_text(df_summary.iloc[index]['section_reference'])}")
else:
    print("All done")
# Out:
# You have completed 100.00% of the work
# All done

# %%
df_questions
# Out:
#    section_reference    source  embedding document  \
# 0                1.1  question        NaN  Lead_SA
# 1                1.1  question        NaN  Lead_SA
# 2                1.1  question        NaN  Lead_SA
# 3              1.1.1  question        NaN  Lead_SA
# 4              1.1.1  question        NaN  Lead_SA
# 5              1.1.1  question        NaN  Lead_SA
# 6              1.1.1  question        NaN  Lead_SA
# 7                1.2  question        NaN  Lead_SA
# 8                1.2  question        NaN  Lead_SA
# 9                1.2  question        NaN  Lead_SA
# 10               1.3  question        NaN  Lead_SA
# 11               2.1  question        NaN  Lead_SA
# 12               2.1  question        NaN  Lead_SA
# 13               2.1  question        NaN  Lead_SA
# 14             2.1.1  question        NaN  Lead_SA
# 15             2.1.2  question        NaN  Lead_SA
# 16             2.1.2  question        NaN  Lead_SA
# 17             2.1.2  question        NaN  Lead_SA
# 18             2.1.3  question        NaN  Lead_SA
# 19             2.1.3  question        NaN  Lead_SA
# 20               2.2  question        NaN  Lead_SA
# 21               2.2  question        NaN  Lead_SA
# 22               2.2  question        NaN  Lead_SA
# 23               2.3  question        NaN  Lead_SA
# 24               2.3  question        NaN  Lead_SA
# 25               2.3  question        NaN  Lead_SA
# 26               2.3  question        NaN  Lead_SA
# 27               3.1  question        NaN  Lead_SA
# 28               3.1  question        NaN  Lead_SA
# 29               3.1  question        NaN  Lead_SA
# 30               3.2  question        NaN  Lead_SA
# 31               3.2  question        NaN  Lead_SA
# 32               3.2  question        NaN  Lead_SA
# 33               3.3  question        NaN  Lead_SA
# 34               3.3  question        NaN  Lead_SA
# 35             Annex  question        NaN  Lead_SA
#
#                                                  text
# 0   What is the significance of identifying a lead...
# 1    When is identifying a lead supervisory author...
# 2    How does an organisation determine if its act...
# 3   What constitutes 'substantially affecting' ind...
# 4   How do we determine if data processing has a s...
# 5   What are the criteria for considering an effec...
# 6   What examples would Supervisory Authorities co...
# 7               What is a lead supervisory authority?
# 8   What responsibility does the lead supervisory ...
# 9   How is the lead supervisory authority identified?
# 10  What does 'main establishment' mean for an org...
# 11  Can a multinational company have more than one...
# 12  What happens if your organisation has separate...
# 13  Can local supervisory authorities handle speci...
# 14       How do you identify your main establishment?
# 15  How does the central administration location a...
# 16   What happens when different establishments wi...
# 17   How should groups of undertakings identify th...
# 18  How do joint controllers decide their respecti...
# 19  What principle do joint controllers benefit fr...
# 20  Can a lead authority be designated without an ...
# 21  How do supervisory authorities decide the lead...
# 22  What evidence might a company need to provide ...
# 23  What is meant by the main establishment of a p...
# 24  What happens if a processor has no central adm...
# 25  Who is the lead supervisory authority in cases...
# 26  If a processor serves multiple controllers in ...
# 27  What is the role of a concerned supervisory au...
# 28   What happens if a lead supervisory authority ...
# 29   What is the difference between a lead supervi...
# 30            What is local data processing activity?
# 31  How do supervisory authorities handle local da...
# 32  Will public authorities' data processing alway...
# 33  How can companies without an establishment in ...
# 34  How are controllers without an EU presence reg...
# 35  How do I determine my lead supervisory authority?

# %%
summary_file = "../tmp/lead_sa_summary.csv"
df_summary.to_csv(summary_file, sep = "|", encoding = "utf-8", index = False, na_rep="")

question_file = "../tmp/lead_sa_question.csv"
df_questions.to_csv(question_file, sep = "|", encoding = "utf-8", index = False, na_rep="")

# %%
import pandas as pd
summary_file = "../tmp/lead_sa_summary.csv"
df_summary = pd.read_csv(summary_file, sep = "|", encoding = "utf-8")

question_file = "../tmp/lead_sa_question.csv"
df_questions = pd.read_csv(question_file, sep = "|", encoding = "utf-8")

# %%
df_questions = df_questions.drop("text", axis=1).join(df_questions["text"].str.split("|", expand=True).stack().reset_index(level=1, drop=True).rename("text"))
df_questions = df_questions[df_questions["text"] != ""]
df_questions.reset_index(drop=True, inplace=True)

# %%
df_index = pd.concat([df_summary, df_questions], ignore_index = True)
df_index
# Out:
#    section_reference                                               text  \
# 0                1.1  Identifying a lead supervisory authority is re...
# 1              1.1.1  'Cross-border processing of personal data':\n\...
# 2                1.2  The lead supervisory authority is primarily re...
# 3                1.3  Main establishment refers to:\n\n- For you, if...
# 4                2.1  To identify the lead supervisory authority:\n\...
# 5              2.1.1  To identify the lead supervisory authority, fi...
# 6              2.1.2  When processing is handled by a group with hea...
# 7              2.1.3  To identify the lead supervisory authority for...
# 8                2.2  In situations where identifying the main estab...
# 9                2.3  The main establishment of a processor will be ...
# 10               3.1  The 'supervisory authority concerned' is a sup...
# 11               3.2  Local data processing activity is not covered ...
# 12               3.3  The GDPR's cooperation and consistency mechani...
# 13             Annex  Workflow to determine the lead supervisory aut...
# 14               1.1  What is the significance of identifying a lead...
# 15               1.1   When is identifying a lead supervisory author...
# 16               1.1   How does an organisation determine if its act...
# 17             1.1.1  What constitutes 'substantially affecting' ind...
# 18             1.1.1  How do we determine if data processing has a s...
# 19             1.1.1  What are the criteria for considering an effec...
# 20             1.1.1  What examples would Supervisory Authorities co...
# 21               1.2              What is a lead supervisory authority?
# 22               1.2  What responsibility does the lead supervisory ...
# 23               1.2  How is the lead supervisory authority identified?
# 24               1.3  What does 'main establishment' mean for an org...
# 25               2.1  Can a multinational company have more than one...
# 26               2.1  What happens if your organisation has separate...
# 27               2.1  Can local supervisory authorities handle speci...
# 28             2.1.1       How do you identify your main establishment?
# 29             2.1.2  How does the central administration location a...
# 30             2.1.2   What happens when different establishments wi...
# 31             2.1.2   How should groups of undertakings identify th...
# 32             2.1.3  How do joint controllers decide their respecti...
# 33             2.1.3  What principle do joint controllers benefit fr...
# 34               2.2  Can a lead authority be designated without an ...
# 35               2.2  How do supervisory authorities decide the lead...
# 36               2.2  What evidence might a company need to provide ...
# 37               2.3  What is meant by the main establishment of a p...
# 38               2.3  What happens if a processor has no central adm...
# 39               2.3  Who is the lead supervisory authority in cases...
# 40               2.3  If a processor serves multiple controllers in ...
# 41               3.1  What is the role of a concerned supervisory au...
# 42               3.1   What happens if a lead supervisory authority ...
# 43               3.1   What is the difference between a lead supervi...
# 44               3.2            What is local data processing activity?
# 45               3.2  How do supervisory authorities handle local da...
# 46               3.2  Will public authorities' data processing alway...
# 47               3.3  How can companies without an establishment in ...
# 48               3.3  How are controllers without an EU presence reg...
# 49             Annex  How do I determine my lead supervisory authority?
#
#       source  embedding document
# 0    summary        NaN  Lead_SA
# 1    summary        NaN  Lead_SA
# 2    summary        NaN  Lead_SA
# 3    summary        NaN  Lead_SA
# 4    summary        NaN  Lead_SA
# 5    summary        NaN  Lead_SA
# 6    summary        NaN  Lead_SA
# 7    summary        NaN  Lead_SA
# 8    summary        NaN  Lead_SA
# 9    summary        NaN  Lead_SA
# 10   summary        NaN  Lead_SA
# 11   summary        NaN  Lead_SA
# 12   summary        NaN  Lead_SA
# 13   summary        NaN  Lead_SA
# 14  question        NaN  Lead_SA
# 15  question        NaN  Lead_SA
# 16  question        NaN  Lead_SA
# 17  question        NaN  Lead_SA
# 18  question        NaN  Lead_SA
# 19  question        NaN  Lead_SA
# 20  question        NaN  Lead_SA
# 21  question        NaN  Lead_SA
# 22  question        NaN  Lead_SA
# 23  question        NaN  Lead_SA
# 24  question        NaN  Lead_SA
# 25  question        NaN  Lead_SA
# 26  question        NaN  Lead_SA
# 27  question        NaN  Lead_SA
# 28  question        NaN  Lead_SA
# 29  question        NaN  Lead_SA
# 30  question        NaN  Lead_SA
# 31  question        NaN  Lead_SA
# 32  question        NaN  Lead_SA
# 33  question        NaN  Lead_SA
# 34  question        NaN  Lead_SA
# 35  question        NaN  Lead_SA
# 36  question        NaN  Lead_SA
# 37  question        NaN  Lead_SA
# 38  question        NaN  Lead_SA
# 39  question        NaN  Lead_SA
# 40  question        NaN  Lead_SA
# 41  question        NaN  Lead_SA
# 42  question        NaN  Lead_SA
# 43  question        NaN  Lead_SA
# 44  question        NaN  Lead_SA
# 45  question        NaN  Lead_SA
# 46  question        NaN  Lead_SA
# 47  question        NaN  Lead_SA
# 48  question        NaN  Lead_SA
# 49  question        NaN  Lead_SA

# %%
from regulations_rag.embeddings import get_ada_embedding
model = "text-embedding-3-large"
dimensions = 1024

#df_index = df_questions
df_index['embedding'] = pd.NA  # Initialize the column to hold NA values
df_index['embedding'] = df_index['embedding'].astype(object)  # Ensure the column type is object
increment = 10
for i in range(0, len(df_index), increment):
    chunk = df_index.iloc[i:i+increment].copy()
    chunk["embedding"] = chunk["text"].apply(lambda x: get_ada_embedding(openai_client, x, model, dimensions))
    df_index.loc[chunk.index, "embedding"] = chunk["embedding"]
    print(f"Completed {i+increment} lines")
# Out:
# Completed 10 lines
# Completed 20 lines
# Completed 30 lines
# Completed 40 lines
# Completed 50 lines

# %%
file = "../inputs/index/lead_sa.parquet"
df_index.to_parquet(file, engine = "pyarrow")
save_parquet_data(df_index, file, key)

# %%
df_index
#df_index["document"] = "Article_47_BCR"
# Out:
#    section_reference                                               text  \
# 0                1.1  Identifying a lead supervisory authority is re...
# 1              1.1.1  'Cross-border processing of personal data':\n\...
# 2                1.2  The lead supervisory authority is primarily re...
# 3                1.3  Main establishment refers to:\n\n- For you, if...
# 4                2.1  To identify the lead supervisory authority:\n\...
# 5              2.1.1  To identify the lead supervisory authority, fi...
# 6              2.1.2  When processing is handled by a group with hea...
# 7              2.1.3  To identify the lead supervisory authority for...
# 8                2.2  In situations where identifying the main estab...
# 9                2.3  The main establishment of a processor will be ...
# 10               3.1  The 'supervisory authority concerned' is a sup...
# 11               3.2  Local data processing activity is not covered ...
# 12               3.3  The GDPR's cooperation and consistency mechani...
# 13             Annex  Workflow to determine the lead supervisory aut...
# 14               1.1  What is the significance of identifying a lead...
# 15               1.1   When is identifying a lead supervisory author...
# 16               1.1   How does an organisation determine if its act...
# 17             1.1.1  What constitutes 'substantially affecting' ind...
# 18             1.1.1  How do we determine if data processing has a s...
# 19             1.1.1  What are the criteria for considering an effec...
# 20             1.1.1  What examples would Supervisory Authorities co...
# 21               1.2              What is a lead supervisory authority?
# 22               1.2  What responsibility does the lead supervisory ...
# 23               1.2  How is the lead supervisory authority identified?
# 24               1.3  What does 'main establishment' mean for an org...
# 25               2.1  Can a multinational company have more than one...
# 26               2.1  What happens if your organisation has separate...
# 27               2.1  Can local supervisory authorities handle speci...
# 28             2.1.1       How do you identify your main establishment?
# 29             2.1.2  How does the central administration location a...
# 30             2.1.2   What happens when different establishments wi...
# 31             2.1.2   How should groups of undertakings identify th...
# 32             2.1.3  How do joint controllers decide their respecti...
# 33             2.1.3  What principle do joint controllers benefit fr...
# 34               2.2  Can a lead authority be designated without an ...
# 35               2.2  How do supervisory authorities decide the lead...
# 36               2.2  What evidence might a company need to provide ...
# 37               2.3  What is meant by the main establishment of a p...
# 38               2.3  What happens if a processor has no central adm...
# 39               2.3  Who is the lead supervisory authority in cases...
# 40               2.3  If a processor serves multiple controllers in ...
# 41               3.1  What is the role of a concerned supervisory au...
# 42               3.1   What happens if a lead supervisory authority ...
# 43               3.1   What is the difference between a lead supervi...
# 44               3.2            What is local data processing activity?
# 45               3.2  How do supervisory authorities handle local da...
# 46               3.2  Will public authorities' data processing alway...
# 47               3.3  How can companies without an establishment in ...
# 48               3.3  How are controllers without an EU presence reg...
# 49             Annex  How do I determine my lead supervisory authority?
#
#       source                                          embedding document
# 0    summary  [-0.006422937847673893, 0.00971098430454731, -...  Lead_SA
# 1    summary  [-0.01792445220053196, 0.00020537340606097132,...  Lead_SA
# 2    summary  [-0.001868635998107493, 0.002838078886270523, ...  Lead_SA
# 3    summary  [0.0033447048626840115, 0.035395193845033646, ...  Lead_SA
# 4    summary  [-0.00579441711306572, 0.016650624573230743, -...  Lead_SA
# 5    summary  [0.014092209748923779, 0.028814133256673813, -...  Lead_SA
# 6    summary  [0.011525212787091732, 0.020529285073280334, -...  Lead_SA
# 7    summary  [0.010616075247526169, -0.009036075323820114, ...  Lead_SA
# 8    summary  [0.005761819891631603, -0.002088783774524927, ...  Lead_SA
# 9    summary  [0.0022017881274223328, 0.014683345332741737, ...  Lead_SA
# 10   summary  [-0.012191019020974636, -0.006682296749204397,...  Lead_SA
# 11   summary  [0.003946301061660051, -0.013057153671979904, ...  Lead_SA
# 12   summary  [-0.029041651636362076, -0.04219694063067436, ...  Lead_SA
# 13   summary  [-0.020577501505613327, -0.02227405086159706, ...  Lead_SA
# 14  question  [0.009187447838485241, -0.017684033140540123, ...  Lead_SA
# 15  question  [-0.0075327507220208645, -0.006731722038239241...  Lead_SA
# 16  question  [-0.002822083653882146, -0.00893455557525158, ...  Lead_SA
# 17  question  [-0.011421102099120617, -0.011899146251380444,...  Lead_SA
# 18  question  [-0.03549238294363022, -0.007113917265087366, ...  Lead_SA
# 19  question  [-0.0103050097823143, -0.04548851028084755, -0...  Lead_SA
# 20  question  [-0.02947038598358631, -0.03144488111138344, -...  Lead_SA
# 21  question  [0.008255762048065662, 0.0022871727123856544, ...  Lead_SA
# 22  question  [-0.011711101979017258, -0.020156608894467354,...  Lead_SA
# 23  question  [0.00031075155129656196, -0.000753053056541830...  Lead_SA
# 24  question  [0.026966586709022522, 0.0816565752029419, -0....  Lead_SA
# 25  question  [-0.0017122963909059763, -0.00865885242819786,...  Lead_SA
# 26  question  [-0.015271618962287903, -0.028285028412938118,...  Lead_SA
# 27  question  [0.015602503903210163, 0.006743128877133131, -...  Lead_SA
# 28  question  [0.04170332849025726, 0.0513412281870842, -0.0...  Lead_SA
# 29  question  [0.039921436458826065, 0.052316319197416306, -...  Lead_SA
# 30  question  [-0.046282194554805756, -0.021232223138213158,...  Lead_SA
# 31  question  [0.011811294592916965, 0.01510592456907034, -0...  Lead_SA
# 32  question  [0.030475623905658722, -0.07647940516471863, -...  Lead_SA
# 33  question  [0.015581846237182617, -0.04081012308597565, -...  Lead_SA
# 34  question  [0.03295526280999184, 0.04865694046020508, -0....  Lead_SA
# 35  question  [0.03962370753288269, -0.022688696160912514, -...  Lead_SA
# 36  question  [0.05496453493833542, 0.027912316843867302, -0...  Lead_SA
# 37  question  [0.02868865244090557, 0.06625334918498993, -0....  Lead_SA
# 38  question  [-0.007469776552170515, 0.01474964339286089, -...  Lead_SA
# 39  question  [0.01379616092890501, -0.015736091881990433, -...  Lead_SA
# 40  question  [0.014916948042809963, -0.0029637115076184273,...  Lead_SA
# 41  question  [-0.0251203291118145, -0.03277229890227318, -0...  Lead_SA
# 42  question  [-0.034096259623765945, -0.0041763512417674065...  Lead_SA
# 43  question  [0.005946234334260225, -0.006112995557487011, ...  Lead_SA
# 44  question  [-0.02841119095683098, 0.04495241865515709, -0...  Lead_SA
# 45  question  [-0.006543720606714487, -0.00743044214323163, ...  Lead_SA
# 46  question  [-0.013551231473684311, 0.018050745129585266, ...  Lead_SA
# 47  question  [-0.007319706492125988, -0.03038051724433899, ...  Lead_SA
# 48  question  [0.003809127490967512, -0.008433014154434204, ...  Lead_SA
# 49  question  [-0.001063146977685392, -0.014339219778776169,...  Lead_SA

# %%
gdpr_index = load_parquet_data("../inputs/index/gdpr.parquet", key)
lead_sa_index = load_parquet_data("../inputs/index/lead_sa.parquet", key)

for index, row in gdpr_index[gdpr_index['section_reference'].str.startswith('60')].iterrows():
    print(f"-- {row['text']}")


# for index, row in index_df[index_df["section_reference"] == '30'].iterrows():
#     print(f"* {row['text']}")
# Out:
# -- How do supervisory authorities collaborate on GDPR enforcement?
# -- What role does the lead supervisory authority play in GDPR investigations?
# -- How is consensus reached between supervisory authorities under GDPR?
# -- What happens if there is disagreement among supervisory authorities on a draft decision?
# -- What is the process for revising a draft decision when objections are raised?
# -- How are decisions communicated to you and enforced across the European Union?
# -- What options are available if urgent action is needed to protect an individual's interests?
# -- How do supervisory authorities exchange information under GDPR?
# -- The lead supervisory authority must cooperate and share all relevant information with other supervisory authorities to reach a consensus on matters pertaining to you. They may also request assistance or conduct joint operations for investigative or monitoring purposes.
# When drafting decisions involving you, the lead supervisory authority will communicate this to other supervisory authorities and consider their opinions. If any supervisory authority objects to a decision, the lead authority must consider the objection. If unresolved, the issue is escalated to a consistency mechanism. Decisions agreed upon, or unobjected to within specific time frames, are considered accepted by all concerned supervisory authorities.
# Decisions made by the lead supervisory authority are notified to you and all supervisory authorities. If a complaint leads to a decision, the complainant is informed by the supervisory authority with which they lodged the complaint. Different parts of a complaint may have separate decisions.
# Upon receiving a decision, you must implement necessary measures to comply across all your establishments in the EU and inform the lead supervisory authority of these measures, which will then inform other supervisory authorities.
# In urgent cases to protect individuals, an expedited procedure is available.
# Information exchange between supervisory authorities happens electronically in a standardised format.

# %%
file = "../inputs/index/article_47_bcr.parquet"
#df_index.to_parquet(file, engine = "pyarrow")
save_parquet_data(index_df, file, key)

# %%
from src.index_tools import update_text_in_index, add_to_index

index_df = article_47_index
#index_df = gdpr_index

text_to_change = "What points need to be addressed in the Binding Corporate Rules for Controllers (BCR-C)"
changed_text = "What points need to be addressed in the Binding Corporate Rules for controllers?"
embedding_model = model
embedding_dimensions = dimensions

index_df = update_text_in_index(openai_client = openai_client, index_df = index_df, text_to_change = text_to_change, changed_text = changed_text, embedding_model = embedding_model, embedding_dimensions = embedding_dimensions)
# Out:
#    section_reference                                               text  \
# 0                1.1  You can use binding corporate rules (BCRs) for...
# 1                1.5  Binding Corporate Rules for controllers (BCR-C...
# 2                1.6  You must comply with EU data protection legisl...
# 3                1.7  You must use Binding Corporate Rules (BCR) as ...
# 4                1.8  Binding Corporate Rules (BCRs) need approval f...
# ..               ...                                                ...
# 82               3.6  What agreements must be made regarding the han...
# 83               3.7  What expectations are set for members of Bindi...
# 84               3.8  What obligations are there to keep Binding Cor...
# 85               3.9  What definitions must be included in the Bindi...
# 86          Analysis  What points need to be addressed in the Bindin...
#
#       source                                          embedding  \
# 0    summary  [-0.009783994406461716, -0.06066862493753433, ...
# 1    summary  [-0.017316676676273346, -0.021807707846164703,...
# 2    summary  [-0.07271231710910797, -0.06814079731702805, -...
# 3    summary  [-0.017403494566679, -0.08751912415027618, -0....
# 4    summary  [-0.004610632546246052, -0.043068330734968185,...
# ..       ...                                                ...
# 82  question  [-0.04174955189228058, -0.0986546203494072, -0...
# 83  question  [-0.04039411619305611, -0.08921048790216446, -...
# 84  question  [-0.04588606581091881, -0.06260394304990768, -...
# 85  question  [-0.010924087837338448, -0.03873256593942642, ...
# 86  question  [-0.0038541764952242374, -0.05298667028546333,...
#
#           document
# 0   Article_47_BCR
# 1   Article_47_BCR
# 2   Article_47_BCR
# 3   Article_47_BCR
# 4   Article_47_BCR
# ..             ...
# 82  Article_47_BCR
# 83  Article_47_BCR
# 84  Article_47_BCR
# 85  Article_47_BCR
# 86  Article_47_BCR
#
# [87 rows x 5 columns]

# %%
import importlib
import src.index_tools
importlib.reload(src.index_tools)
from src.index_tools import add_to_index

index_df = article_47_index
text = "What happens if local laws conflict with the standards of binding corporate rules?"
section_reference = "3.5.4.1"
source = "question"
document = "Article_47_BCR"

index_df = add_to_index(openai_client, index_df, text, section_reference, source, document, embedding_model, embedding_dimensions)

# %%
from src.index_tools import remove_from_index

text_to_delete = "What happens if local laws conflict with the standards of binding corporate rules?"
article_47_index = remove_from_index(article_47_index, text_to_delete)

# %%
article_47_index = index_df
article_47_index[article_47_index["section_reference"] == "3.5.4.1"]
# Out:
#    section_reference                                               text  \
# 25           3.5.4.1  You must ensure that the Binding Corporate Rul...
# 79           3.5.4.1  What should the Binding Corporate Rules-Contro...
# 87           3.5.4.1  What happens if local laws conflict with the s...
#
#       source                                          embedding  \
# 25   summary  [-0.018655141815543175, -0.05344023182988167, ...
# 79  question  [-0.014255059882998466, -0.07780193537473679, ...
# 87  question  [-0.02774774841964245, -0.06760360300540924, -...
#
#           document
# 25  Article_47_BCR
# 79  Article_47_BCR
# 87  Article_47_BCR

# %%
save_parquet_data(index_df, "../inputs/index/gdpr.parquet", key)

# %%
index_df[index_df['document'] == "article_30_5"]
# Out:
#                                                   text  \
# 147  Under what conditions could you be exempt from...
#
#                                              embedding    source  \
# 147  [-0.03439036011695862, -0.0008122794097289443,...  question
#
#     section_reference      document
# 147               all  article_30_5

# %%
import os
from regulations_rag.standard_regulation_index import load_parquet_data, save_parquet_data
key = os.getenv('encryption_key_gdpr')

path_to_file = "../inputs/index/article_30_5.parquet"
index = load_parquet_data(path_to_file, key)

# %%
#index["document"] = "Article_30_5"
index
# Out:
#   section_reference  ...      document
# 0               all  ...  Article_30_5
# 1               all  ...  Article_30_5
# 2               all  ...  Article_30_5
# 3               all  ...  Article_30_5
# 4               all  ...  Article_30_5
# 5               all  ...  Article_30_5
# 6               all  ...  Article_30_5
# 7               all  ...  Article_30_5
#
# [8 rows x 5 columns]

# %%
save_parquet_data(index, path_to_file, key)
